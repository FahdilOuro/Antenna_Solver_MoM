# %%
"""
Ce fichier analyse comment l'evolutin de la position feed d'une valeur assez 
grandre a une valuer tres petite influence la frequence de raisonnance

Dans ce code, On ne touche Ni a la distance meandre ni a la largeur de la piste meandree
"""
# Out:
# "\nCe fichier analyse comment l'evolutin de la position feed d'une valeur assez \ngrandre a une valuer tres petite influence la frequence de raisonnance\n\nDans ce code, On ne touche Ni a la distance meandre ni a la largeur de la piste meandree\n"

# %%
from utils.ifa_meander_project_v2.geometry import *
from utils.ifa_meander_project_v2.meshing import *
from utils.ifa_meander_project_v2.frequency import *
from utils.ifa_meander_project_v2.simulation import *

# %%
fLow = 700e6
fHigh = 1000e6
fC = 868e6
step = 4e6

frequencies, fc_index, nPoints = generate_frequencies(fLow, fHigh, fC, step)

print(f"Number of frequencies (nPoints): {nPoints}")
print(f"Index of fC: {fc_index}")
# Out:
# Nombre de fréquences (nPoints) : 76
# Index de fC : 42

# %%
mesh_name = "ifa_meander_anlyse_3.msh"
save_mesh_folder = 'data/gmsh_files/'
ifa_meander_mat = 'data/antennas_mesh/ifa_meander_anlyse_3.mat'
ifa_meander_msh = save_mesh_folder + mesh_name

# %%
a = 15 / 1000  # Width
b = 30 / 1000  # Height

terminal_a = 50 / 1000
terminal_b = b
x_t = np.array([-terminal_a, 0, 0, -terminal_a])
y_t = np.array([terminal_b, terminal_b, 0, 0])

# Fix the short feed and the track width
largeur_piste    = a / 10
distance_meandre = a / 10

mesh_size = 18 / 1000

# %%
feed_list = np.linspace(b - 3 * largeur_piste / 2 - 0.5 / 1000, largeur_piste / 2, 50)
print(f"Feed min: {feed_list[-1] * 1000:.2f} mm")
print(f"Feed max: {feed_list[0] * 1000:.2f} mm")

np.save('data/analyse_feed_position/feed_list.npy', feed_list)
# Out:
# Feed min: 0.75 mm
# Feed max: 27.25 mm

# %%
def creation_ifa(largeur, hauteur, width, dist_meandre, feed, x_t, y_t, save_mesh_folder, mesh_name, mesh_size):
    x, y, N, distance_meandre = ifa_creation(largeur, hauteur, width, dist_meandre)
    x_m, y_m = trace_meander(x, y, width)
    feed_wid = width # The track width is the same everywhere
    feed_x = np.array([0, distance_meandre, distance_meandre, 0])
    feed_y = np.array([feed + feed_wid/2, feed + feed_wid/2, feed - feed_wid/2, feed - feed_wid/2])
    antenna_ifa_meander(x_m, y_m, x_t, y_t, feed_x, feed_y, save_mesh_folder, mesh_name, mesh_size)
    extract_msh_to_mat(ifa_meander_msh, ifa_meander_mat)
    return N, distance_meandre

def plot_s11_curve(fLow, fHigh, nPoints, s11_db, fC=None):
    from matplotlib import pyplot as plt
    frequencies = np.linspace(fLow, fHigh, nPoints)
    frequencies_mhz = np.array(frequencies) / 1e6
    s11_db = np.array(s11_db)

    # Find the minimum of S11
    min_index = np.argmin(s11_db)
    f_resonance = frequencies[min_index] / 1e6
    s11_min = s11_db[min_index]

    # Plot
    fig_size = 7
    Fibonacci = (1 + np.sqrt(5)) / 2
    plt.figure(figsize=(fig_size, fig_size / Fibonacci))
    plt.plot(frequencies_mhz, s11_db, label="S11 (dB)", color='blue')
    plt.plot(f_resonance, s11_min, 'ro', 
            label=f"Resonance: {f_resonance:.2f} MHz (S11={s11_min:.2f} dB)")
    
    if fC:
        fC_mhz = fC / 1e6
        idx_fc = np.argmin(np.abs(frequencies - fC))
        s11_fc = s11_db[idx_fc]
        plt.axvline(fC_mhz, color='green', linestyle='--', 
                   label=f"fC = {fC_mhz:.2f} MHz (S11={s11_fc:.2f} dB)")

    plt.xlabel("Frequency (MHz)")
    plt.ylabel("S11 (dB)")
    plt.title("S11 vs Frequency curve")
    plt.grid(True)
    plt.legend()
    plt.tight_layout()
    plt.show()

# %%
iteration = 1
frequences_resonance = []
for feed in feed_list:
    try:
        print(f"\n------------------------------------------------------Iteration N°{iteration}------------------------------------------------------")
        print(f"Meander distance {distance_meandre * 1000} mm")
        print(f"IFA track width {largeur_piste * 1000} mm")
        print(f"Feed position = {feed * 1000} mm\n")
        N_list_elem, new_distance_meandre_elem = creation_ifa(a, b, largeur_piste, distance_meandre, feed, x_t, y_t, save_mesh_folder, mesh_name, mesh_size)
        print(f"Number of meanders {N_list_elem}")
        print(f"New meander distance {new_distance_meandre_elem * 1000} mm")
        feed_point = [0, feed, 0]
        frequence_resonance, s11_db = analysis(frequencies, ifa_meander_mat, feed_point)
        frequences_resonance.append(frequence_resonance)
        if frequence_resonance == fC:
            plot_s11_curve(fLow, fHigh, nPoints, s11_db, fC)

        iteration += 1
    except ValueError as e:
        print(f"Error: {e}")

np.save(f'data/analyse_feed_position/frequences_resonance.npy', frequences_resonance)
# Out:
# ------------------------------------------------------Iteration N°1------------------------------------------------------
# distance meandres 1.5 mm
# Largeur de piste ifa 1.5 mm
# position feed = 27.249999999999996 mm
#
# Number of meanders 5
# New distance meandres 1.5 mm
# Simulation 1/76 | f = 700.00 MHz | S11 = -0.00 dB
# Simulation 2/76 | f = 704.00 MHz | S11 = -0.00 dB
# Simulation 3/76 | f = 708.00 MHz | S11 = -0.00 dB
# Simulation 4/76 | f = 712.00 MHz | S11 = -0.00 dB
# Simulation 5/76 | f = 716.00 MHz | S11 = -0.01 dB
# Simulation 6/76 | f = 720.00 MHz | S11 = -0.01 dB
# Simulation 7/76 | f = 724.00 MHz | S11 = -0.01 dB
# Simulation 8/76 | f = 728.00 MHz | S11 = -0.01 dB
# Simulation 9/76 | f = 732.00 MHz | S11 = -0.01 dB
# Simulation 10/76 | f = 736.00 MHz | S11 = -0.01 dB
# Simulation 11/76 | f = 740.00 MHz | S11 = -0.01 dB
# Simulation 12/76 | f = 744.00 MHz | S11 = -0.01 dB
# Simulation 13/76 | f = 748.00 MHz | S11 = -0.01 dB
# Simulation 14/76 | f = 752.00 MHz | S11 = -0.01 dB
# Simulation 15/76 | f = 756.00 MHz | S11 = -0.01 dB
# Simulation 16/76 | f = 760.00 MHz | S11 = -0.01 dB
# Simulation 17/76 | f = 764.00 MHz | S11 = -0.01 dB
# Simulation 18/76 | f = 768.00 MHz | S11 = -0.01 dB
# Simulation 19/76 | f = 772.00 MHz | S11 = -0.01 dB
# Simulation 20/76 | f = 776.00 MHz | S11 = -0.01 dB
# Simulation 21/76 | f = 780.00 MHz | S11 = -0.01 dB
# Simulation 22/76 | f = 784.00 MHz | S11 = -0.01 dB
# Simulation 23/76 | f = 788.00 MHz | S11 = -0.01 dB
# Simulation 24/76 | f = 792.00 MHz | S11 = -0.01 dB
# Simulation 25/76 | f = 796.00 MHz | S11 = -0.01 dB
# Simulation 26/76 | f = 800.00 MHz | S11 = -0.01 dB
# Simulation 27/76 | f = 804.00 MHz | S11 = -0.02 dB
# Simulation 28/76 | f = 808.00 MHz | S11 = -0.02 dB
# Simulation 29/76 | f = 812.00 MHz | S11 = -0.02 dB
# Simulation 30/76 | f = 816.00 MHz | S11 = -0.02 dB
# Simulation 31/76 | f = 820.00 MHz | S11 = -0.02 dB
# Simulation 32/76 | f = 824.00 MHz | S11 = -0.02 dB
# Simulation 33/76 | f = 828.00 MHz | S11 = -0.02 dB
# Simulation 34/76 | f = 832.00 MHz | S11 = -0.02 dB
# Simulation 35/76 | f = 836.00 MHz | S11 = -0.02 dB
# Simulation 36/76 | f = 840.00 MHz | S11 = -0.03 dB
# Simulation 37/76 | f = 844.00 MHz | S11 = -0.03 dB
# Simulation 38/76 | f = 848.00 MHz | S11 = -0.03 dB
# Simulation 39/76 | f = 852.00 MHz | S11 = -0.03 dB
# Simulation 40/76 | f = 856.00 MHz | S11 = -0.03 dB
# Simulation 41/76 | f = 860.00 MHz | S11 = -0.03 dB
# Simulation 42/76 | f = 864.00 MHz | S11 = -0.04 dB
# Simulation 43/76 | f = 868.00 MHz | S11 = -0.04 dB
# Simulation 44/76 | f = 872.00 MHz | S11 = -0.04 dB
# Simulation 45/76 | f = 876.00 MHz | S11 = -0.04 dB
# Simulation 46/76 | f = 880.00 MHz | S11 = -0.05 dB
# Simulation 47/76 | f = 884.00 MHz | S11 = -0.05 dB
# Simulation 48/76 | f = 888.00 MHz | S11 = -0.05 dB
# Simulation 49/76 | f = 892.00 MHz | S11 = -0.05 dB
# Simulation 50/76 | f = 896.00 MHz | S11 = -0.06 dB
# Simulation 51/76 | f = 900.00 MHz | S11 = -0.06 dB
# Simulation 52/76 | f = 904.00 MHz | S11 = -0.07 dB
# Simulation 53/76 | f = 908.00 MHz | S11 = -0.07 dB
# Simulation 54/76 | f = 912.00 MHz | S11 = -0.07 dB
# Simulation 55/76 | f = 916.00 MHz | S11 = -0.08 dB
# Simulation 56/76 | f = 920.00 MHz | S11 = -0.08 dB
# Simulation 57/76 | f = 924.00 MHz | S11 = -0.09 dB
# Simulation 58/76 | f = 928.00 MHz | S11 = -0.10 dB
# Simulation 59/76 | f = 932.00 MHz | S11 = -0.10 dB
# Simulation 60/76 | f = 936.00 MHz | S11 = -0.11 dB
# Simulation 61/76 | f = 940.00 MHz | S11 = -0.12 dB
# Simulation 62/76 | f = 944.00 MHz | S11 = -0.13 dB
# Simulation 63/76 | f = 948.00 MHz | S11 = -0.14 dB
# Simulation 64/76 | f = 952.00 MHz | S11 = -0.15 dB
# Simulation 65/76 | f = 956.00 MHz | S11 = -0.16 dB
# Simulation 66/76 | f = 960.00 MHz | S11 = -0.17 dB
# Simulation 67/76 | f = 964.00 MHz | S11 = -0.19 dB
# Simulation 68/76 | f = 968.00 MHz | S11 = -0.20 dB
# Simulation 69/76 | f = 972.00 MHz | S11 = -0.22 dB
# Simulation 70/76 | f = 976.00 MHz | S11 = -0.24 dB
# Simulation 71/76 | f = 980.00 MHz | S11 = -0.26 dB
# Simulation 72/76 | f = 984.00 MHz | S11 = -0.28 dB
# Simulation 73/76 | f = 988.00 MHz | S11 = -0.31 dB
# Simulation 74/76 | f = 992.00 MHz | S11 = -0.34 dB
# Simulation 75/76 | f = 996.00 MHz | S11 = -0.37 dB
# Simulation 76/76 | f = 1000.00 MHz | S11 = -0.41 dB
#
# 📡 Résultats de simulation :
# → Fréquence de résonance = 1000.00 MHz
# → Impédance à f_res      = 1.50+26.23j Ω
#
# ------------------------------------------------------Iteration N°2------------------------------------------------------
# distance meandres 1.5 mm
# Largeur de piste ifa 1.5 mm
# position feed = 26.709183673469386 mm
#
# Number of meanders 5
# New distance meandres 1.5 mm
# Simulation 1/76 | f = 700.00 MHz | S11 = -0.00 dB
# Simulation 2/76 | f = 704.00 MHz | S11 = -0.00 dB
# Simulation 3/76 | f = 708.00 MHz | S11 = -0.00 dB
# Simulation 4/76 | f = 712.00 MHz | S11 = -0.00 dB
# Simulation 5/76 | f = 716.00 MHz | S11 = -0.00 dB
# Simulation 6/76 | f = 720.00 MHz | S11 = -0.00 dB
# Simulation 7/76 | f = 724.00 MHz | S11 = -0.00 dB
# Simulation 8/76 | f = 728.00 MHz | S11 = -0.00 dB
# Simulation 9/76 | f = 732.00 MHz | S11 = -0.00 dB
# Simulation 10/76 | f = 736.00 MHz | S11 = -0.00 dB
# Simulation 11/76 | f = 740.00 MHz | S11 = -0.00 dB
# Simulation 12/76 | f = 744.00 MHz | S11 = -0.00 dB
# Simulation 13/76 | f = 748.00 MHz | S11 = -0.00 dB
# Simulation 14/76 | f = 752.00 MHz | S11 = -0.00 dB
# Simulation 15/76 | f = 756.00 MHz | S11 = -0.00 dB
# Simulation 16/76 | f = 760.00 MHz | S11 = -0.00 dB
# Simulation 17/76 | f = 764.00 MHz | S11 = -0.00 dB
# Simulation 18/76 | f = 768.00 MHz | S11 = -0.01 dB
# Simulation 19/76 | f = 772.00 MHz | S11 = -0.01 dB
# Simulation 20/76 | f = 776.00 MHz | S11 = -0.01 dB
# Simulation 21/76 | f = 780.00 MHz | S11 = -0.01 dB
# Simulation 22/76 | f = 784.00 MHz | S11 = -0.01 dB
# Simulation 23/76 | f = 788.00 MHz | S11 = -0.01 dB
# Simulation 24/76 | f = 792.00 MHz | S11 = -0.01 dB
# Simulation 25/76 | f = 796.00 MHz | S11 = -0.01 dB
# Simulation 26/76 | f = 800.00 MHz | S11 = -0.01 dB
# Simulation 27/76 | f = 804.00 MHz | S11 = -0.01 dB
# Simulation 28/76 | f = 808.00 MHz | S11 = -0.01 dB
# Simulation 29/76 | f = 812.00 MHz | S11 = -0.01 dB
# Simulation 30/76 | f = 816.00 MHz | S11 = -0.01 dB
# Simulation 31/76 | f = 820.00 MHz | S11 = -0.01 dB
# Simulation 32/76 | f = 824.00 MHz | S11 = -0.01 dB
# Simulation 33/76 | f = 828.00 MHz | S11 = -0.01 dB
# Simulation 34/76 | f = 832.00 MHz | S11 = -0.01 dB
# Simulation 35/76 | f = 836.00 MHz | S11 = -0.01 dB
# Simulation 36/76 | f = 840.00 MHz | S11 = -0.01 dB
# Simulation 37/76 | f = 844.00 MHz | S11 = -0.01 dB
# Simulation 38/76 | f = 848.00 MHz | S11 = -0.01 dB
# Simulation 39/76 | f = 852.00 MHz | S11 = -0.02 dB
# Simulation 40/76 | f = 856.00 MHz | S11 = -0.02 dB
# Simulation 41/76 | f = 860.00 MHz | S11 = -0.02 dB
# Simulation 42/76 | f = 864.00 MHz | S11 = -0.02 dB
# Simulation 43/76 | f = 868.00 MHz | S11 = -0.02 dB
# Simulation 44/76 | f = 872.00 MHz | S11 = -0.02 dB
# Simulation 45/76 | f = 876.00 MHz | S11 = -0.02 dB
# Simulation 46/76 | f = 880.00 MHz | S11 = -0.02 dB
# Simulation 47/76 | f = 884.00 MHz | S11 = -0.02 dB
# Simulation 48/76 | f = 888.00 MHz | S11 = -0.02 dB
# Simulation 49/76 | f = 892.00 MHz | S11 = -0.03 dB
# Simulation 50/76 | f = 896.00 MHz | S11 = -0.03 dB
# Simulation 51/76 | f = 900.00 MHz | S11 = -0.03 dB
# Simulation 52/76 | f = 904.00 MHz | S11 = -0.03 dB
# Simulation 53/76 | f = 908.00 MHz | S11 = -0.03 dB
# Simulation 54/76 | f = 912.00 MHz | S11 = -0.04 dB
# Simulation 55/76 | f = 916.00 MHz | S11 = -0.04 dB
# Simulation 56/76 | f = 920.00 MHz | S11 = -0.04 dB
# Simulation 57/76 | f = 924.00 MHz | S11 = -0.04 dB
# Simulation 58/76 | f = 928.00 MHz | S11 = -0.05 dB
# Simulation 59/76 | f = 932.00 MHz | S11 = -0.05 dB
# Simulation 60/76 | f = 936.00 MHz | S11 = -0.05 dB
# Simulation 61/76 | f = 940.00 MHz | S11 = -0.05 dB
# Simulation 62/76 | f = 944.00 MHz | S11 = -0.06 dB
# Simulation 63/76 | f = 948.00 MHz | S11 = -0.06 dB
# Simulation 64/76 | f = 952.00 MHz | S11 = -0.07 dB
# Simulation 65/76 | f = 956.00 MHz | S11 = -0.07 dB
# Simulation 66/76 | f = 960.00 MHz | S11 = -0.08 dB
# Simulation 67/76 | f = 964.00 MHz | S11 = -0.08 dB
# Simulation 68/76 | f = 968.00 MHz | S11 = -0.09 dB
# Simulation 69/76 | f = 972.00 MHz | S11 = -0.10 dB
# Simulation 70/76 | f = 976.00 MHz | S11 = -0.10 dB
# Simulation 71/76 | f = 980.00 MHz | S11 = -0.11 dB
# Simulation 72/76 | f = 984.00 MHz | S11 = -0.12 dB
# Simulation 73/76 | f = 988.00 MHz | S11 = -0.13 dB
# Simulation 74/76 | f = 992.00 MHz | S11 = -0.14 dB
# Simulation 75/76 | f = 996.00 MHz | S11 = -0.15 dB
# Simulation 76/76 | f = 1000.00 MHz | S11 = -0.17 dB
#
# 📡 Résultats de simulation :
# → Fréquence de résonance = 1000.00 MHz
# → Impédance à f_res      = 0.57+22.51j Ω
#
# ------------------------------------------------------Iteration N°3------------------------------------------------------
# distance meandres 1.5 mm
# Largeur de piste ifa 1.5 mm
# position feed = 26.16836734693877 mm
#
# Number of meanders 5
# New distance meandres 1.5 mm
# Simulation 1/76 | f = 700.00 MHz | S11 = -0.01 dB
# Simulation 2/76 | f = 704.00 MHz | S11 = -0.01 dB
# Simulation 3/76 | f = 708.00 MHz | S11 = -0.01 dB
# Simulation 4/76 | f = 712.00 MHz | S11 = -0.01 dB
# Simulation 5/76 | f = 716.00 MHz | S11 = -0.01 dB
# Simulation 6/76 | f = 720.00 MHz | S11 = -0.01 dB
# Simulation 7/76 | f = 724.00 MHz | S11 = -0.01 dB
# Simulation 8/76 | f = 728.00 MHz | S11 = -0.01 dB
# Simulation 9/76 | f = 732.00 MHz | S11 = -0.01 dB
# Simulation 10/76 | f = 736.00 MHz | S11 = -0.01 dB
# Simulation 11/76 | f = 740.00 MHz | S11 = -0.01 dB
# Simulation 12/76 | f = 744.00 MHz | S11 = -0.01 dB
# Simulation 13/76 | f = 748.00 MHz | S11 = -0.01 dB
# Simulation 14/76 | f = 752.00 MHz | S11 = -0.02 dB
# Simulation 15/76 | f = 756.00 MHz | S11 = -0.02 dB
# Simulation 16/76 | f = 760.00 MHz | S11 = -0.02 dB
# Simulation 17/76 | f = 764.00 MHz | S11 = -0.02 dB
# Simulation 18/76 | f = 768.00 MHz | S11 = -0.02 dB
# Simulation 19/76 | f = 772.00 MHz | S11 = -0.02 dB
# Simulation 20/76 | f = 776.00 MHz | S11 = -0.02 dB
# Simulation 21/76 | f = 780.00 MHz | S11 = -0.02 dB
# Simulation 22/76 | f = 784.00 MHz | S11 = -0.02 dB
# Simulation 23/76 | f = 788.00 MHz | S11 = -0.02 dB
# Simulation 24/76 | f = 792.00 MHz | S11 = -0.03 dB
# Simulation 25/76 | f = 796.00 MHz | S11 = -0.03 dB
# Simulation 26/76 | f = 800.00 MHz | S11 = -0.03 dB
# Simulation 27/76 | f = 804.00 MHz | S11 = -0.03 dB
# Simulation 28/76 | f = 808.00 MHz | S11 = -0.03 dB
# Simulation 29/76 | f = 812.00 MHz | S11 = -0.03 dB
# Simulation 30/76 | f = 816.00 MHz | S11 = -0.04 dB
# Simulation 31/76 | f = 820.00 MHz | S11 = -0.04 dB
# Simulation 32/76 | f = 824.00 MHz | S11 = -0.04 dB
# Simulation 33/76 | f = 828.00 MHz | S11 = -0.04 dB
# Simulation 34/76 | f = 832.00 MHz | S11 = -0.04 dB
# Simulation 35/76 | f = 836.00 MHz | S11 = -0.05 dB
# Simulation 36/76 | f = 840.00 MHz | S11 = -0.05 dB
# Simulation 37/76 | f = 844.00 MHz | S11 = -0.05 dB
# Simulation 38/76 | f = 848.00 MHz | S11 = -0.05 dB
# Simulation 39/76 | f = 852.00 MHz | S11 = -0.06 dB
# Simulation 40/76 | f = 856.00 MHz | S11 = -0.06 dB
# Simulation 41/76 | f = 860.00 MHz | S11 = -0.07 dB
# Simulation 42/76 | f = 864.00 MHz | S11 = -0.07 dB
# Simulation 43/76 | f = 868.00 MHz | S11 = -0.07 dB
# Simulation 44/76 | f = 872.00 MHz | S11 = -0.08 dB
# Simulation 45/76 | f = 876.00 MHz | S11 = -0.08 dB
# Simulation 46/76 | f = 880.00 MHz | S11 = -0.09 dB
# Simulation 47/76 | f = 884.00 MHz | S11 = -0.09 dB
# Simulation 48/76 | f = 888.00 MHz | S11 = -0.10 dB
# Simulation 49/76 | f = 892.00 MHz | S11 = -0.10 dB
# Simulation 50/76 | f = 896.00 MHz | S11 = -0.11 dB
# Simulation 51/76 | f = 900.00 MHz | S11 = -0.12 dB
# Simulation 52/76 | f = 904.00 MHz | S11 = -0.13 dB
# Simulation 53/76 | f = 908.00 MHz | S11 = -0.13 dB
# Simulation 54/76 | f = 912.00 MHz | S11 = -0.14 dB
# Simulation 55/76 | f = 916.00 MHz | S11 = -0.15 dB
# Simulation 56/76 | f = 920.00 MHz | S11 = -0.16 dB
# Simulation 57/76 | f = 924.00 MHz | S11 = -0.18 dB
# Simulation 58/76 | f = 928.00 MHz | S11 = -0.19 dB
# Simulation 59/76 | f = 932.00 MHz | S11 = -0.20 dB
# Simulation 60/76 | f = 936.00 MHz | S11 = -0.22 dB
# Simulation 61/76 | f = 940.00 MHz | S11 = -0.23 dB
# Simulation 62/76 | f = 944.00 MHz | S11 = -0.25 dB
# Simulation 63/76 | f = 948.00 MHz | S11 = -0.27 dB
# Simulation 64/76 | f = 952.00 MHz | S11 = -0.29 dB
# Simulation 65/76 | f = 956.00 MHz | S11 = -0.31 dB
# Simulation 66/76 | f = 960.00 MHz | S11 = -0.34 dB
# Simulation 67/76 | f = 964.00 MHz | S11 = -0.37 dB
# Simulation 68/76 | f = 968.00 MHz | S11 = -0.40 dB
# Simulation 69/76 | f = 972.00 MHz | S11 = -0.43 dB
# Simulation 70/76 | f = 976.00 MHz | S11 = -0.47 dB
# Simulation 71/76 | f = 980.00 MHz | S11 = -0.51 dB
# Simulation 72/76 | f = 984.00 MHz | S11 = -0.56 dB
# Simulation 73/76 | f = 988.00 MHz | S11 = -0.61 dB
# Simulation 74/76 | f = 992.00 MHz | S11 = -0.67 dB
# Simulation 75/76 | f = 996.00 MHz | S11 = -0.74 dB
# Simulation 76/76 | f = 1000.00 MHz | S11 = -0.81 dB
#
# 📡 Résultats de simulation :
# → Fréquence de résonance = 1000.00 MHz
# → Impédance à f_res      = 4.00+42.02j Ω
#
# ------------------------------------------------------Iteration N°4------------------------------------------------------
# distance meandres 1.5 mm
# Largeur de piste ifa 1.5 mm
# position feed = 25.62755102040816 mm
#
# Number of meanders 5
# New distance meandres 1.5 mm
# Simulation 1/76 | f = 700.00 MHz | S11 = -0.01 dB
# Simulation 2/76 | f = 704.00 MHz | S11 = -0.01 dB
# Simulation 3/76 | f = 708.00 MHz | S11 = -0.01 dB
# Simulation 4/76 | f = 712.00 MHz | S11 = -0.01 dB
# Simulation 5/76 | f = 716.00 MHz | S11 = -0.01 dB
# Simulation 6/76 | f = 720.00 MHz | S11 = -0.01 dB
# Simulation 7/76 | f = 724.00 MHz | S11 = -0.01 dB
# Simulation 8/76 | f = 728.00 MHz | S11 = -0.01 dB
# Simulation 9/76 | f = 732.00 MHz | S11 = -0.02 dB
# Simulation 10/76 | f = 736.00 MHz | S11 = -0.02 dB
# Simulation 11/76 | f = 740.00 MHz | S11 = -0.02 dB
# Simulation 12/76 | f = 744.00 MHz | S11 = -0.02 dB
# Simulation 13/76 | f = 748.00 MHz | S11 = -0.02 dB
# Simulation 14/76 | f = 752.00 MHz | S11 = -0.02 dB
# Simulation 15/76 | f = 756.00 MHz | S11 = -0.02 dB
# Simulation 16/76 | f = 760.00 MHz | S11 = -0.02 dB
# Simulation 17/76 | f = 764.00 MHz | S11 = -0.02 dB
# Simulation 18/76 | f = 768.00 MHz | S11 = -0.02 dB
# Simulation 19/76 | f = 772.00 MHz | S11 = -0.03 dB
# Simulation 20/76 | f = 776.00 MHz | S11 = -0.03 dB
# Simulation 21/76 | f = 780.00 MHz | S11 = -0.03 dB
# Simulation 22/76 | f = 784.00 MHz | S11 = -0.03 dB
# Simulation 23/76 | f = 788.00 MHz | S11 = -0.03 dB
# Simulation 24/76 | f = 792.00 MHz | S11 = -0.03 dB
# Simulation 25/76 | f = 796.00 MHz | S11 = -0.03 dB
# Simulation 26/76 | f = 800.00 MHz | S11 = -0.04 dB
# Simulation 27/76 | f = 804.00 MHz | S11 = -0.04 dB
# Simulation 28/76 | f = 808.00 MHz | S11 = -0.04 dB
# Simulation 29/76 | f = 812.00 MHz | S11 = -0.04 dB
# Simulation 30/76 | f = 816.00 MHz | S11 = -0.05 dB
# Simulation 31/76 | f = 820.00 MHz | S11 = -0.05 dB
# Simulation 32/76 | f = 824.00 MHz | S11 = -0.05 dB
# Simulation 33/76 | f = 828.00 MHz | S11 = -0.05 dB
# Simulation 34/76 | f = 832.00 MHz | S11 = -0.06 dB
# Simulation 35/76 | f = 836.00 MHz | S11 = -0.06 dB
# Simulation 36/76 | f = 840.00 MHz | S11 = -0.06 dB
# Simulation 37/76 | f = 844.00 MHz | S11 = -0.07 dB
# Simulation 38/76 | f = 848.00 MHz | S11 = -0.07 dB
# Simulation 39/76 | f = 852.00 MHz | S11 = -0.07 dB
# Simulation 40/76 | f = 856.00 MHz | S11 = -0.08 dB
# Simulation 41/76 | f = 860.00 MHz | S11 = -0.08 dB
# Simulation 42/76 | f = 864.00 MHz | S11 = -0.09 dB
# Simulation 43/76 | f = 868.00 MHz | S11 = -0.09 dB
# Simulation 44/76 | f = 872.00 MHz | S11 = -0.10 dB
# Simulation 45/76 | f = 876.00 MHz | S11 = -0.11 dB
# Simulation 46/76 | f = 880.00 MHz | S11 = -0.11 dB
# Simulation 47/76 | f = 884.00 MHz | S11 = -0.12 dB
# Simulation 48/76 | f = 888.00 MHz | S11 = -0.13 dB
# Simulation 49/76 | f = 892.00 MHz | S11 = -0.13 dB
# Simulation 50/76 | f = 896.00 MHz | S11 = -0.14 dB
# Simulation 51/76 | f = 900.00 MHz | S11 = -0.15 dB
# Simulation 52/76 | f = 904.00 MHz | S11 = -0.16 dB
# Simulation 53/76 | f = 908.00 MHz | S11 = -0.17 dB
# Simulation 54/76 | f = 912.00 MHz | S11 = -0.19 dB
# Simulation 55/76 | f = 916.00 MHz | S11 = -0.20 dB
# Simulation 56/76 | f = 920.00 MHz | S11 = -0.21 dB
# Simulation 57/76 | f = 924.00 MHz | S11 = -0.23 dB
# Simulation 58/76 | f = 928.00 MHz | S11 = -0.24 dB
# Simulation 59/76 | f = 932.00 MHz | S11 = -0.26 dB
# Simulation 60/76 | f = 936.00 MHz | S11 = -0.28 dB
# Simulation 61/76 | f = 940.00 MHz | S11 = -0.30 dB
# Simulation 62/76 | f = 944.00 MHz | S11 = -0.33 dB
# Simulation 63/76 | f = 948.00 MHz | S11 = -0.35 dB
# Simulation 64/76 | f = 952.00 MHz | S11 = -0.38 dB
# Simulation 65/76 | f = 956.00 MHz | S11 = -0.41 dB
# Simulation 66/76 | f = 960.00 MHz | S11 = -0.45 dB
# Simulation 67/76 | f = 964.00 MHz | S11 = -0.49 dB
# Simulation 68/76 | f = 968.00 MHz | S11 = -0.53 dB
# Simulation 69/76 | f = 972.00 MHz | S11 = -0.58 dB
# Simulation 70/76 | f = 976.00 MHz | S11 = -0.63 dB
# Simulation 71/76 | f = 980.00 MHz | S11 = -0.69 dB
# Simulation 72/76 | f = 984.00 MHz | S11 = -0.75 dB
# Simulation 73/76 | f = 988.00 MHz | S11 = -0.83 dB
# Simulation 74/76 | f = 992.00 MHz | S11 = -0.91 dB
# Simulation 75/76 | f = 996.00 MHz | S11 = -1.00 dB
# Simulation 76/76 | f = 1000.00 MHz | S11 = -1.11 dB
#
# 📡 Résultats de simulation :
# → Fréquence de résonance = 1000.00 MHz
# → Impédance à f_res      = 6.50+50.70j Ω
#
# ------------------------------------------------------Iteration N°5------------------------------------------------------
# distance meandres 1.5 mm
# Largeur de piste ifa 1.5 mm
# position feed = 25.08673469387755 mm
#
# Number of meanders 5
# New distance meandres 1.5 mm
# Simulation 1/76 | f = 700.00 MHz | S11 = -0.01 dB
# Simulation 2/76 | f = 704.00 MHz | S11 = -0.01 dB
# Simulation 3/76 | f = 708.00 MHz | S11 = -0.01 dB
# Simulation 4/76 | f = 712.00 MHz | S11 = -0.01 dB
# Simulation 5/76 | f = 716.00 MHz | S11 = -0.02 dB
# Simulation 6/76 | f = 720.00 MHz | S11 = -0.02 dB
# Simulation 7/76 | f = 724.00 MHz | S11 = -0.02 dB
# Simulation 8/76 | f = 728.00 MHz | S11 = -0.02 dB
# Simulation 9/76 | f = 732.00 MHz | S11 = -0.02 dB
# Simulation 10/76 | f = 736.00 MHz | S11 = -0.02 dB
# Simulation 11/76 | f = 740.00 MHz | S11 = -0.02 dB
# Simulation 12/76 | f = 744.00 MHz | S11 = -0.02 dB
# Simulation 13/76 | f = 748.00 MHz | S11 = -0.02 dB
# Simulation 14/76 | f = 752.00 MHz | S11 = -0.02 dB
# Simulation 15/76 | f = 756.00 MHz | S11 = -0.03 dB
# Simulation 16/76 | f = 760.00 MHz | S11 = -0.03 dB
# Simulation 17/76 | f = 764.00 MHz | S11 = -0.03 dB
# Simulation 18/76 | f = 768.00 MHz | S11 = -0.03 dB
# Simulation 19/76 | f = 772.00 MHz | S11 = -0.03 dB
# Simulation 20/76 | f = 776.00 MHz | S11 = -0.03 dB
# Simulation 21/76 | f = 780.00 MHz | S11 = -0.04 dB
# Simulation 22/76 | f = 784.00 MHz | S11 = -0.04 dB
# Simulation 23/76 | f = 788.00 MHz | S11 = -0.04 dB
# Simulation 24/76 | f = 792.00 MHz | S11 = -0.04 dB
# Simulation 25/76 | f = 796.00 MHz | S11 = -0.04 dB
# Simulation 26/76 | f = 800.00 MHz | S11 = -0.05 dB
# Simulation 27/76 | f = 804.00 MHz | S11 = -0.05 dB
# Simulation 28/76 | f = 808.00 MHz | S11 = -0.05 dB
# Simulation 29/76 | f = 812.00 MHz | S11 = -0.05 dB
# Simulation 30/76 | f = 816.00 MHz | S11 = -0.06 dB
# Simulation 31/76 | f = 820.00 MHz | S11 = -0.06 dB
# Simulation 32/76 | f = 824.00 MHz | S11 = -0.06 dB
# Simulation 33/76 | f = 828.00 MHz | S11 = -0.07 dB
# Simulation 34/76 | f = 832.00 MHz | S11 = -0.07 dB
# Simulation 35/76 | f = 836.00 MHz | S11 = -0.07 dB
# Simulation 36/76 | f = 840.00 MHz | S11 = -0.08 dB
# Simulation 37/76 | f = 844.00 MHz | S11 = -0.08 dB
# Simulation 38/76 | f = 848.00 MHz | S11 = -0.09 dB
# Simulation 39/76 | f = 852.00 MHz | S11 = -0.09 dB
# Simulation 40/76 | f = 856.00 MHz | S11 = -0.10 dB
# Simulation 41/76 | f = 860.00 MHz | S11 = -0.11 dB
# Simulation 42/76 | f = 864.00 MHz | S11 = -0.11 dB
# Simulation 43/76 | f = 868.00 MHz | S11 = -0.12 dB
# Simulation 44/76 | f = 872.00 MHz | S11 = -0.13 dB
# Simulation 45/76 | f = 876.00 MHz | S11 = -0.13 dB
# Simulation 46/76 | f = 880.00 MHz | S11 = -0.14 dB
# Simulation 47/76 | f = 884.00 MHz | S11 = -0.15 dB
# Simulation 48/76 | f = 888.00 MHz | S11 = -0.16 dB
# Simulation 49/76 | f = 892.00 MHz | S11 = -0.17 dB
# Simulation 50/76 | f = 896.00 MHz | S11 = -0.18 dB
# Simulation 51/76 | f = 900.00 MHz | S11 = -0.20 dB
# Simulation 52/76 | f = 904.00 MHz | S11 = -0.21 dB
# Simulation 53/76 | f = 908.00 MHz | S11 = -0.22 dB
# Simulation 54/76 | f = 912.00 MHz | S11 = -0.24 dB
# Simulation 55/76 | f = 916.00 MHz | S11 = -0.26 dB
# Simulation 56/76 | f = 920.00 MHz | S11 = -0.28 dB
# Simulation 57/76 | f = 924.00 MHz | S11 = -0.30 dB
# Simulation 58/76 | f = 928.00 MHz | S11 = -0.32 dB
# Simulation 59/76 | f = 932.00 MHz | S11 = -0.34 dB
# Simulation 60/76 | f = 936.00 MHz | S11 = -0.37 dB
# Simulation 61/76 | f = 940.00 MHz | S11 = -0.40 dB
# Simulation 62/76 | f = 944.00 MHz | S11 = -0.43 dB
# Simulation 63/76 | f = 948.00 MHz | S11 = -0.47 dB
# Simulation 64/76 | f = 952.00 MHz | S11 = -0.51 dB
# Simulation 65/76 | f = 956.00 MHz | S11 = -0.55 dB
# Simulation 66/76 | f = 960.00 MHz | S11 = -0.60 dB
# Simulation 67/76 | f = 964.00 MHz | S11 = -0.65 dB
# Simulation 68/76 | f = 968.00 MHz | S11 = -0.71 dB
# Simulation 69/76 | f = 972.00 MHz | S11 = -0.78 dB
# Simulation 70/76 | f = 976.00 MHz | S11 = -0.85 dB
# Simulation 71/76 | f = 980.00 MHz | S11 = -0.94 dB
# Simulation 72/76 | f = 984.00 MHz | S11 = -1.03 dB
# Simulation 73/76 | f = 988.00 MHz | S11 = -1.14 dB
# Simulation 74/76 | f = 992.00 MHz | S11 = -1.27 dB
# Simulation 75/76 | f = 996.00 MHz | S11 = -1.41 dB
# Simulation 76/76 | f = 1000.00 MHz | S11 = -1.56 dB
#
# 📡 Résultats de simulation :
# → Fréquence de résonance = 1000.00 MHz
# → Impédance à f_res      = 11.37+61.23j Ω
#
# ------------------------------------------------------Iteration N°6------------------------------------------------------
# distance meandres 1.5 mm
# Largeur de piste ifa 1.5 mm
# position feed = 24.54591836734694 mm
#
# Number of meanders 5
# New distance meandres 1.5 mm
# Simulation 1/76 | f = 700.00 MHz | S11 = -0.01 dB
# Simulation 2/76 | f = 704.00 MHz | S11 = -0.01 dB
# Simulation 3/76 | f = 708.00 MHz | S11 = -0.01 dB
# Simulation 4/76 | f = 712.00 MHz | S11 = -0.02 dB
# Simulation 5/76 | f = 716.00 MHz | S11 = -0.02 dB
# Simulation 6/76 | f = 720.00 MHz | S11 = -0.02 dB
# Simulation 7/76 | f = 724.00 MHz | S11 = -0.02 dB
# Simulation 8/76 | f = 728.00 MHz | S11 = -0.02 dB
# Simulation 9/76 | f = 732.00 MHz | S11 = -0.02 dB
# Simulation 10/76 | f = 736.00 MHz | S11 = -0.02 dB
# Simulation 11/76 | f = 740.00 MHz | S11 = -0.02 dB
# Simulation 12/76 | f = 744.00 MHz | S11 = -0.02 dB
# Simulation 13/76 | f = 748.00 MHz | S11 = -0.02 dB
# Simulation 14/76 | f = 752.00 MHz | S11 = -0.03 dB
# Simulation 15/76 | f = 756.00 MHz | S11 = -0.03 dB
# Simulation 16/76 | f = 760.00 MHz | S11 = -0.03 dB
# Simulation 17/76 | f = 764.00 MHz | S11 = -0.03 dB
# Simulation 18/76 | f = 768.00 MHz | S11 = -0.03 dB
# Simulation 19/76 | f = 772.00 MHz | S11 = -0.03 dB
# Simulation 20/76 | f = 776.00 MHz | S11 = -0.04 dB
# Simulation 21/76 | f = 780.00 MHz | S11 = -0.04 dB
# Simulation 22/76 | f = 784.00 MHz | S11 = -0.04 dB
# Simulation 23/76 | f = 788.00 MHz | S11 = -0.04 dB
# Simulation 24/76 | f = 792.00 MHz | S11 = -0.04 dB
# Simulation 25/76 | f = 796.00 MHz | S11 = -0.05 dB
# Simulation 26/76 | f = 800.00 MHz | S11 = -0.05 dB
# Simulation 27/76 | f = 804.00 MHz | S11 = -0.05 dB
# Simulation 28/76 | f = 808.00 MHz | S11 = -0.05 dB
# Simulation 29/76 | f = 812.00 MHz | S11 = -0.06 dB
# Simulation 30/76 | f = 816.00 MHz | S11 = -0.06 dB
# Simulation 31/76 | f = 820.00 MHz | S11 = -0.06 dB
# Simulation 32/76 | f = 824.00 MHz | S11 = -0.07 dB
# Simulation 33/76 | f = 828.00 MHz | S11 = -0.07 dB
# Simulation 34/76 | f = 832.00 MHz | S11 = -0.08 dB
# Simulation 35/76 | f = 836.00 MHz | S11 = -0.08 dB
# Simulation 36/76 | f = 840.00 MHz | S11 = -0.09 dB
# Simulation 37/76 | f = 844.00 MHz | S11 = -0.09 dB
# Simulation 38/76 | f = 848.00 MHz | S11 = -0.10 dB
# Simulation 39/76 | f = 852.00 MHz | S11 = -0.10 dB
# Simulation 40/76 | f = 856.00 MHz | S11 = -0.11 dB
# Simulation 41/76 | f = 860.00 MHz | S11 = -0.12 dB
# Simulation 42/76 | f = 864.00 MHz | S11 = -0.12 dB
# Simulation 43/76 | f = 868.00 MHz | S11 = -0.13 dB
# Simulation 44/76 | f = 872.00 MHz | S11 = -0.14 dB
# Simulation 45/76 | f = 876.00 MHz | S11 = -0.15 dB
# Simulation 46/76 | f = 880.00 MHz | S11 = -0.16 dB
# Simulation 47/76 | f = 884.00 MHz | S11 = -0.17 dB
# Simulation 48/76 | f = 888.00 MHz | S11 = -0.18 dB
# Simulation 49/76 | f = 892.00 MHz | S11 = -0.19 dB
# Simulation 50/76 | f = 896.00 MHz | S11 = -0.21 dB
# Simulation 51/76 | f = 900.00 MHz | S11 = -0.22 dB
# Simulation 52/76 | f = 904.00 MHz | S11 = -0.24 dB
# Simulation 53/76 | f = 908.00 MHz | S11 = -0.25 dB
# Simulation 54/76 | f = 912.00 MHz | S11 = -0.27 dB
# Simulation 55/76 | f = 916.00 MHz | S11 = -0.29 dB
# Simulation 56/76 | f = 920.00 MHz | S11 = -0.32 dB
# Simulation 57/76 | f = 924.00 MHz | S11 = -0.34 dB
# Simulation 58/76 | f = 928.00 MHz | S11 = -0.37 dB
# Simulation 59/76 | f = 932.00 MHz | S11 = -0.40 dB
# Simulation 60/76 | f = 936.00 MHz | S11 = -0.43 dB
# Simulation 61/76 | f = 940.00 MHz | S11 = -0.47 dB
# Simulation 62/76 | f = 944.00 MHz | S11 = -0.51 dB
# Simulation 63/76 | f = 948.00 MHz | S11 = -0.55 dB
# Simulation 64/76 | f = 952.00 MHz | S11 = -0.60 dB
# Simulation 65/76 | f = 956.00 MHz | S11 = -0.66 dB
# Simulation 66/76 | f = 960.00 MHz | S11 = -0.72 dB
# Simulation 67/76 | f = 964.00 MHz | S11 = -0.79 dB
# Simulation 68/76 | f = 968.00 MHz | S11 = -0.87 dB
# Simulation 69/76 | f = 972.00 MHz | S11 = -0.95 dB
# Simulation 70/76 | f = 976.00 MHz | S11 = -1.05 dB
# Simulation 71/76 | f = 980.00 MHz | S11 = -1.17 dB
# Simulation 72/76 | f = 984.00 MHz | S11 = -1.30 dB
# Simulation 73/76 | f = 988.00 MHz | S11 = -1.45 dB
# Simulation 74/76 | f = 992.00 MHz | S11 = -1.62 dB
# Simulation 75/76 | f = 996.00 MHz | S11 = -1.81 dB
# Simulation 76/76 | f = 1000.00 MHz | S11 = -2.04 dB
#
# 📡 Résultats de simulation :
# → Fréquence de résonance = 1000.00 MHz
# → Impédance à f_res      = 16.44+66.04j Ω
#
# ------------------------------------------------------Iteration N°7------------------------------------------------------
# distance meandres 1.5 mm
# Largeur de piste ifa 1.5 mm
# position feed = 24.005102040816322 mm
#
# Number of meanders 5
# New distance meandres 1.5 mm
# Simulation 1/76 | f = 700.00 MHz | S11 = -0.01 dB
# Simulation 2/76 | f = 704.00 MHz | S11 = -0.01 dB
# Simulation 3/76 | f = 708.00 MHz | S11 = -0.01 dB
# Simulation 4/76 | f = 712.00 MHz | S11 = -0.01 dB
# Simulation 5/76 | f = 716.00 MHz | S11 = -0.02 dB
# Simulation 6/76 | f = 720.00 MHz | S11 = -0.02 dB
# Simulation 7/76 | f = 724.00 MHz | S11 = -0.02 dB
# Simulation 8/76 | f = 728.00 MHz | S11 = -0.02 dB
# Simulation 9/76 | f = 732.00 MHz | S11 = -0.02 dB
# Simulation 10/76 | f = 736.00 MHz | S11 = -0.02 dB
# Simulation 11/76 | f = 740.00 MHz | S11 = -0.02 dB
# Simulation 12/76 | f = 744.00 MHz | S11 = -0.02 dB
# Simulation 13/76 | f = 748.00 MHz | S11 = -0.02 dB
# Simulation 14/76 | f = 752.00 MHz | S11 = -0.02 dB
# Simulation 15/76 | f = 756.00 MHz | S11 = -0.03 dB
# Simulation 16/76 | f = 760.00 MHz | S11 = -0.03 dB
# Simulation 17/76 | f = 764.00 MHz | S11 = -0.03 dB
# Simulation 18/76 | f = 768.00 MHz | S11 = -0.03 dB
# Simulation 19/76 | f = 772.00 MHz | S11 = -0.03 dB
# Simulation 20/76 | f = 776.00 MHz | S11 = -0.03 dB
# Simulation 21/76 | f = 780.00 MHz | S11 = -0.03 dB
# Simulation 22/76 | f = 784.00 MHz | S11 = -0.04 dB
# Simulation 23/76 | f = 788.00 MHz | S11 = -0.04 dB
# Simulation 24/76 | f = 792.00 MHz | S11 = -0.04 dB
# Simulation 25/76 | f = 796.00 MHz | S11 = -0.04 dB
# Simulation 26/76 | f = 800.00 MHz | S11 = -0.05 dB
# Simulation 27/76 | f = 804.00 MHz | S11 = -0.05 dB
# Simulation 28/76 | f = 808.00 MHz | S11 = -0.05 dB
# Simulation 29/76 | f = 812.00 MHz | S11 = -0.05 dB
# Simulation 30/76 | f = 816.00 MHz | S11 = -0.06 dB
# Simulation 31/76 | f = 820.00 MHz | S11 = -0.06 dB
# Simulation 32/76 | f = 824.00 MHz | S11 = -0.06 dB
# Simulation 33/76 | f = 828.00 MHz | S11 = -0.07 dB
# Simulation 34/76 | f = 832.00 MHz | S11 = -0.07 dB
# Simulation 35/76 | f = 836.00 MHz | S11 = -0.08 dB
# Simulation 36/76 | f = 840.00 MHz | S11 = -0.08 dB
# Simulation 37/76 | f = 844.00 MHz | S11 = -0.09 dB
# Simulation 38/76 | f = 848.00 MHz | S11 = -0.09 dB
# Simulation 39/76 | f = 852.00 MHz | S11 = -0.10 dB
# Simulation 40/76 | f = 856.00 MHz | S11 = -0.10 dB
# Simulation 41/76 | f = 860.00 MHz | S11 = -0.11 dB
# Simulation 42/76 | f = 864.00 MHz | S11 = -0.12 dB
# Simulation 43/76 | f = 868.00 MHz | S11 = -0.12 dB
# Simulation 44/76 | f = 872.00 MHz | S11 = -0.13 dB
# Simulation 45/76 | f = 876.00 MHz | S11 = -0.14 dB
# Simulation 46/76 | f = 880.00 MHz | S11 = -0.15 dB
# Simulation 47/76 | f = 884.00 MHz | S11 = -0.16 dB
# Simulation 48/76 | f = 888.00 MHz | S11 = -0.17 dB
# Simulation 49/76 | f = 892.00 MHz | S11 = -0.18 dB
# Simulation 50/76 | f = 896.00 MHz | S11 = -0.20 dB
# Simulation 51/76 | f = 900.00 MHz | S11 = -0.21 dB
# Simulation 52/76 | f = 904.00 MHz | S11 = -0.23 dB
# Simulation 53/76 | f = 908.00 MHz | S11 = -0.24 dB
# Simulation 54/76 | f = 912.00 MHz | S11 = -0.26 dB
# Simulation 55/76 | f = 916.00 MHz | S11 = -0.28 dB
# Simulation 56/76 | f = 920.00 MHz | S11 = -0.30 dB
# Simulation 57/76 | f = 924.00 MHz | S11 = -0.33 dB
# Simulation 58/76 | f = 928.00 MHz | S11 = -0.36 dB
# Simulation 59/76 | f = 932.00 MHz | S11 = -0.39 dB
# Simulation 60/76 | f = 936.00 MHz | S11 = -0.42 dB
# Simulation 61/76 | f = 940.00 MHz | S11 = -0.46 dB
# Simulation 62/76 | f = 944.00 MHz | S11 = -0.50 dB
# Simulation 63/76 | f = 948.00 MHz | S11 = -0.54 dB
# Simulation 64/76 | f = 952.00 MHz | S11 = -0.59 dB
# Simulation 65/76 | f = 956.00 MHz | S11 = -0.65 dB
# Simulation 66/76 | f = 960.00 MHz | S11 = -0.71 dB
# Simulation 67/76 | f = 964.00 MHz | S11 = -0.79 dB
# Simulation 68/76 | f = 968.00 MHz | S11 = -0.87 dB
# Simulation 69/76 | f = 972.00 MHz | S11 = -0.96 dB
# Simulation 70/76 | f = 976.00 MHz | S11 = -1.07 dB
# Simulation 71/76 | f = 980.00 MHz | S11 = -1.19 dB
# Simulation 72/76 | f = 984.00 MHz | S11 = -1.33 dB
# Simulation 73/76 | f = 988.00 MHz | S11 = -1.49 dB
# Simulation 74/76 | f = 992.00 MHz | S11 = -1.68 dB
# Simulation 75/76 | f = 996.00 MHz | S11 = -1.90 dB
# Simulation 76/76 | f = 1000.00 MHz | S11 = -2.16 dB
#
# 📡 Résultats de simulation :
# → Fréquence de résonance = 1000.00 MHz
# → Impédance à f_res      = 17.91+67.36j Ω
#
# ------------------------------------------------------Iteration N°8------------------------------------------------------
# distance meandres 1.5 mm
# Largeur de piste ifa 1.5 mm
# position feed = 23.46428571428571 mm
#
# Number of meanders 5
# New distance meandres 1.5 mm
# Simulation 1/76 | f = 700.00 MHz | S11 = -0.02 dB
# Simulation 2/76 | f = 704.00 MHz | S11 = -0.02 dB
# Simulation 3/76 | f = 708.00 MHz | S11 = -0.02 dB
# Simulation 4/76 | f = 712.00 MHz | S11 = -0.02 dB
# Simulation 5/76 | f = 716.00 MHz | S11 = -0.03 dB
# Simulation 6/76 | f = 720.00 MHz | S11 = -0.03 dB
# Simulation 7/76 | f = 724.00 MHz | S11 = -0.03 dB
# Simulation 8/76 | f = 728.00 MHz | S11 = -0.03 dB
# Simulation 9/76 | f = 732.00 MHz | S11 = -0.03 dB
# Simulation 10/76 | f = 736.00 MHz | S11 = -0.03 dB
# Simulation 11/76 | f = 740.00 MHz | S11 = -0.03 dB
# Simulation 12/76 | f = 744.00 MHz | S11 = -0.04 dB
# Simulation 13/76 | f = 748.00 MHz | S11 = -0.04 dB
# Simulation 14/76 | f = 752.00 MHz | S11 = -0.04 dB
# Simulation 15/76 | f = 756.00 MHz | S11 = -0.04 dB
# Simulation 16/76 | f = 760.00 MHz | S11 = -0.04 dB
# Simulation 17/76 | f = 764.00 MHz | S11 = -0.05 dB
# Simulation 18/76 | f = 768.00 MHz | S11 = -0.05 dB
# Simulation 19/76 | f = 772.00 MHz | S11 = -0.05 dB
# Simulation 20/76 | f = 776.00 MHz | S11 = -0.05 dB
# Simulation 21/76 | f = 780.00 MHz | S11 = -0.06 dB
# Simulation 22/76 | f = 784.00 MHz | S11 = -0.06 dB
# Simulation 23/76 | f = 788.00 MHz | S11 = -0.06 dB
# Simulation 24/76 | f = 792.00 MHz | S11 = -0.07 dB
# Simulation 25/76 | f = 796.00 MHz | S11 = -0.07 dB
# Simulation 26/76 | f = 800.00 MHz | S11 = -0.07 dB
# Simulation 27/76 | f = 804.00 MHz | S11 = -0.08 dB
# Simulation 28/76 | f = 808.00 MHz | S11 = -0.08 dB
# Simulation 29/76 | f = 812.00 MHz | S11 = -0.09 dB
# Simulation 30/76 | f = 816.00 MHz | S11 = -0.09 dB
# Simulation 31/76 | f = 820.00 MHz | S11 = -0.10 dB
# Simulation 32/76 | f = 824.00 MHz | S11 = -0.10 dB
# Simulation 33/76 | f = 828.00 MHz | S11 = -0.11 dB
# Simulation 34/76 | f = 832.00 MHz | S11 = -0.11 dB
# Simulation 35/76 | f = 836.00 MHz | S11 = -0.12 dB
# Simulation 36/76 | f = 840.00 MHz | S11 = -0.13 dB
# Simulation 37/76 | f = 844.00 MHz | S11 = -0.14 dB
# Simulation 38/76 | f = 848.00 MHz | S11 = -0.14 dB
# Simulation 39/76 | f = 852.00 MHz | S11 = -0.15 dB
# Simulation 40/76 | f = 856.00 MHz | S11 = -0.16 dB
# Simulation 41/76 | f = 860.00 MHz | S11 = -0.17 dB
# Simulation 42/76 | f = 864.00 MHz | S11 = -0.18 dB
# Simulation 43/76 | f = 868.00 MHz | S11 = -0.19 dB
# Simulation 44/76 | f = 872.00 MHz | S11 = -0.21 dB
# Simulation 45/76 | f = 876.00 MHz | S11 = -0.22 dB
# Simulation 46/76 | f = 880.00 MHz | S11 = -0.23 dB
# Simulation 47/76 | f = 884.00 MHz | S11 = -0.25 dB
# Simulation 48/76 | f = 888.00 MHz | S11 = -0.26 dB
# Simulation 49/76 | f = 892.00 MHz | S11 = -0.28 dB
# Simulation 50/76 | f = 896.00 MHz | S11 = -0.30 dB
# Simulation 51/76 | f = 900.00 MHz | S11 = -0.32 dB
# Simulation 52/76 | f = 904.00 MHz | S11 = -0.34 dB
# Simulation 53/76 | f = 908.00 MHz | S11 = -0.37 dB
# Simulation 54/76 | f = 912.00 MHz | S11 = -0.40 dB
# Simulation 55/76 | f = 916.00 MHz | S11 = -0.43 dB
# Simulation 56/76 | f = 920.00 MHz | S11 = -0.46 dB
# Simulation 57/76 | f = 924.00 MHz | S11 = -0.49 dB
# Simulation 58/76 | f = 928.00 MHz | S11 = -0.53 dB
# Simulation 59/76 | f = 932.00 MHz | S11 = -0.57 dB
# Simulation 60/76 | f = 936.00 MHz | S11 = -0.62 dB
# Simulation 61/76 | f = 940.00 MHz | S11 = -0.67 dB
# Simulation 62/76 | f = 944.00 MHz | S11 = -0.73 dB
# Simulation 63/76 | f = 948.00 MHz | S11 = -0.79 dB
# Simulation 64/76 | f = 952.00 MHz | S11 = -0.86 dB
# Simulation 65/76 | f = 956.00 MHz | S11 = -0.94 dB
# Simulation 66/76 | f = 960.00 MHz | S11 = -1.03 dB
# Simulation 67/76 | f = 964.00 MHz | S11 = -1.13 dB
# Simulation 68/76 | f = 968.00 MHz | S11 = -1.24 dB
# Simulation 69/76 | f = 972.00 MHz | S11 = -1.36 dB
# Simulation 70/76 | f = 976.00 MHz | S11 = -1.50 dB
# Simulation 71/76 | f = 980.00 MHz | S11 = -1.66 dB
# Simulation 72/76 | f = 984.00 MHz | S11 = -1.83 dB
# Simulation 73/76 | f = 988.00 MHz | S11 = -2.04 dB
# Simulation 74/76 | f = 992.00 MHz | S11 = -2.27 dB
# Simulation 75/76 | f = 996.00 MHz | S11 = -2.54 dB
# Simulation 76/76 | f = 1000.00 MHz | S11 = -2.85 dB
#
# 📡 Résultats de simulation :
# → Fréquence de résonance = 1000.00 MHz
# → Impédance à f_res      = 63.30+116.13j Ω
#
# ------------------------------------------------------Iteration N°9------------------------------------------------------
# distance meandres 1.5 mm
# Largeur de piste ifa 1.5 mm
# position feed = 22.9234693877551 mm
#
# Number of meanders 5
# New distance meandres 1.5 mm
# Simulation 1/76 | f = 700.00 MHz | S11 = -0.02 dB
# Simulation 2/76 | f = 704.00 MHz | S11 = -0.02 dB
# Simulation 3/76 | f = 708.00 MHz | S11 = -0.02 dB
# Simulation 4/76 | f = 712.00 MHz | S11 = -0.02 dB
# Simulation 5/76 | f = 716.00 MHz | S11 = -0.02 dB
# Simulation 6/76 | f = 720.00 MHz | S11 = -0.02 dB
# Simulation 7/76 | f = 724.00 MHz | S11 = -0.02 dB
# Simulation 8/76 | f = 728.00 MHz | S11 = -0.02 dB
# Simulation 9/76 | f = 732.00 MHz | S11 = -0.03 dB
# Simulation 10/76 | f = 736.00 MHz | S11 = -0.03 dB
# Simulation 11/76 | f = 740.00 MHz | S11 = -0.03 dB
# Simulation 12/76 | f = 744.00 MHz | S11 = -0.03 dB
# Simulation 13/76 | f = 748.00 MHz | S11 = -0.03 dB
# Simulation 14/76 | f = 752.00 MHz | S11 = -0.03 dB
# Simulation 15/76 | f = 756.00 MHz | S11 = -0.04 dB
# Simulation 16/76 | f = 760.00 MHz | S11 = -0.04 dB
# Simulation 17/76 | f = 764.00 MHz | S11 = -0.04 dB
# Simulation 18/76 | f = 768.00 MHz | S11 = -0.04 dB
# Simulation 19/76 | f = 772.00 MHz | S11 = -0.04 dB
# Simulation 20/76 | f = 776.00 MHz | S11 = -0.05 dB
# Simulation 21/76 | f = 780.00 MHz | S11 = -0.05 dB
# Simulation 22/76 | f = 784.00 MHz | S11 = -0.05 dB
# Simulation 23/76 | f = 788.00 MHz | S11 = -0.05 dB
# Simulation 24/76 | f = 792.00 MHz | S11 = -0.06 dB
# Simulation 25/76 | f = 796.00 MHz | S11 = -0.06 dB
# Simulation 26/76 | f = 800.00 MHz | S11 = -0.06 dB
# Simulation 27/76 | f = 804.00 MHz | S11 = -0.07 dB
# Simulation 28/76 | f = 808.00 MHz | S11 = -0.07 dB
# Simulation 29/76 | f = 812.00 MHz | S11 = -0.07 dB
# Simulation 30/76 | f = 816.00 MHz | S11 = -0.08 dB
# Simulation 31/76 | f = 820.00 MHz | S11 = -0.08 dB
# Simulation 32/76 | f = 824.00 MHz | S11 = -0.09 dB
# Simulation 33/76 | f = 828.00 MHz | S11 = -0.09 dB
# Simulation 34/76 | f = 832.00 MHz | S11 = -0.10 dB
# Simulation 35/76 | f = 836.00 MHz | S11 = -0.10 dB
# Simulation 36/76 | f = 840.00 MHz | S11 = -0.11 dB
# Simulation 37/76 | f = 844.00 MHz | S11 = -0.12 dB
# Simulation 38/76 | f = 848.00 MHz | S11 = -0.12 dB
# Simulation 39/76 | f = 852.00 MHz | S11 = -0.13 dB
# Simulation 40/76 | f = 856.00 MHz | S11 = -0.14 dB
# Simulation 41/76 | f = 860.00 MHz | S11 = -0.15 dB
# Simulation 42/76 | f = 864.00 MHz | S11 = -0.16 dB
# Simulation 43/76 | f = 868.00 MHz | S11 = -0.17 dB
# Simulation 44/76 | f = 872.00 MHz | S11 = -0.18 dB
# Simulation 45/76 | f = 876.00 MHz | S11 = -0.19 dB
# Simulation 46/76 | f = 880.00 MHz | S11 = -0.20 dB
# Simulation 47/76 | f = 884.00 MHz | S11 = -0.22 dB
# Simulation 48/76 | f = 888.00 MHz | S11 = -0.23 dB
# Simulation 49/76 | f = 892.00 MHz | S11 = -0.25 dB
# Simulation 50/76 | f = 896.00 MHz | S11 = -0.26 dB
# Simulation 51/76 | f = 900.00 MHz | S11 = -0.28 dB
# Simulation 52/76 | f = 904.00 MHz | S11 = -0.30 dB
# Simulation 53/76 | f = 908.00 MHz | S11 = -0.32 dB
# Simulation 54/76 | f = 912.00 MHz | S11 = -0.35 dB
# Simulation 55/76 | f = 916.00 MHz | S11 = -0.37 dB
# Simulation 56/76 | f = 920.00 MHz | S11 = -0.40 dB
# Simulation 57/76 | f = 924.00 MHz | S11 = -0.43 dB
# Simulation 58/76 | f = 928.00 MHz | S11 = -0.47 dB
# Simulation 59/76 | f = 932.00 MHz | S11 = -0.51 dB
# Simulation 60/76 | f = 936.00 MHz | S11 = -0.55 dB
# Simulation 61/76 | f = 940.00 MHz | S11 = -0.60 dB
# Simulation 62/76 | f = 944.00 MHz | S11 = -0.65 dB
# Simulation 63/76 | f = 948.00 MHz | S11 = -0.71 dB
# Simulation 64/76 | f = 952.00 MHz | S11 = -0.77 dB
# Simulation 65/76 | f = 956.00 MHz | S11 = -0.84 dB
# Simulation 66/76 | f = 960.00 MHz | S11 = -0.92 dB
# Simulation 67/76 | f = 964.00 MHz | S11 = -1.01 dB
# Simulation 68/76 | f = 968.00 MHz | S11 = -1.11 dB
# Simulation 69/76 | f = 972.00 MHz | S11 = -1.22 dB
# Simulation 70/76 | f = 976.00 MHz | S11 = -1.35 dB
# Simulation 71/76 | f = 980.00 MHz | S11 = -1.50 dB
# Simulation 72/76 | f = 984.00 MHz | S11 = -1.67 dB
# Simulation 73/76 | f = 988.00 MHz | S11 = -1.86 dB
# Simulation 74/76 | f = 992.00 MHz | S11 = -2.08 dB
# Simulation 75/76 | f = 996.00 MHz | S11 = -2.33 dB
# Simulation 76/76 | f = 1000.00 MHz | S11 = -2.62 dB
#
# 📡 Résultats de simulation :
# → Fréquence de résonance = 1000.00 MHz
# → Impédance à f_res      = 31.41+85.09j Ω
#
# ------------------------------------------------------Iteration N°10------------------------------------------------------
# distance meandres 1.5 mm
# Largeur de piste ifa 1.5 mm
# position feed = 22.382653061224485 mm
#
# Number of meanders 5
# New distance meandres 1.5 mm
# Simulation 1/76 | f = 700.00 MHz | S11 = -0.03 dB
# Simulation 2/76 | f = 704.00 MHz | S11 = -0.03 dB
# Simulation 3/76 | f = 708.00 MHz | S11 = -0.04 dB
# Simulation 4/76 | f = 712.00 MHz | S11 = -0.04 dB
# Simulation 5/76 | f = 716.00 MHz | S11 = -0.04 dB
# Simulation 6/76 | f = 720.00 MHz | S11 = -0.04 dB
# Simulation 7/76 | f = 724.00 MHz | S11 = -0.04 dB
# Simulation 8/76 | f = 728.00 MHz | S11 = -0.05 dB
# Simulation 9/76 | f = 732.00 MHz | S11 = -0.05 dB
# Simulation 10/76 | f = 736.00 MHz | S11 = -0.05 dB
# Simulation 11/76 | f = 740.00 MHz | S11 = -0.05 dB
# Simulation 12/76 | f = 744.00 MHz | S11 = -0.05 dB
# Simulation 13/76 | f = 748.00 MHz | S11 = -0.06 dB
# Simulation 14/76 | f = 752.00 MHz | S11 = -0.06 dB
# Simulation 15/76 | f = 756.00 MHz | S11 = -0.06 dB
# Simulation 16/76 | f = 760.00 MHz | S11 = -0.07 dB
# Simulation 17/76 | f = 764.00 MHz | S11 = -0.07 dB
# Simulation 18/76 | f = 768.00 MHz | S11 = -0.07 dB
# Simulation 19/76 | f = 772.00 MHz | S11 = -0.08 dB
# Simulation 20/76 | f = 776.00 MHz | S11 = -0.08 dB
# Simulation 21/76 | f = 780.00 MHz | S11 = -0.08 dB
# Simulation 22/76 | f = 784.00 MHz | S11 = -0.09 dB
# Simulation 23/76 | f = 788.00 MHz | S11 = -0.09 dB
# Simulation 24/76 | f = 792.00 MHz | S11 = -0.10 dB
# Simulation 25/76 | f = 796.00 MHz | S11 = -0.10 dB
# Simulation 26/76 | f = 800.00 MHz | S11 = -0.11 dB
# Simulation 27/76 | f = 804.00 MHz | S11 = -0.11 dB
# Simulation 28/76 | f = 808.00 MHz | S11 = -0.12 dB
# Simulation 29/76 | f = 812.00 MHz | S11 = -0.12 dB
# Simulation 30/76 | f = 816.00 MHz | S11 = -0.13 dB
# Simulation 31/76 | f = 820.00 MHz | S11 = -0.13 dB
# Simulation 32/76 | f = 824.00 MHz | S11 = -0.14 dB
# Simulation 33/76 | f = 828.00 MHz | S11 = -0.15 dB
# Simulation 34/76 | f = 832.00 MHz | S11 = -0.16 dB
# Simulation 35/76 | f = 836.00 MHz | S11 = -0.16 dB
# Simulation 36/76 | f = 840.00 MHz | S11 = -0.17 dB
# Simulation 37/76 | f = 844.00 MHz | S11 = -0.18 dB
# Simulation 38/76 | f = 848.00 MHz | S11 = -0.19 dB
# Simulation 39/76 | f = 852.00 MHz | S11 = -0.20 dB
# Simulation 40/76 | f = 856.00 MHz | S11 = -0.21 dB
# Simulation 41/76 | f = 860.00 MHz | S11 = -0.22 dB
# Simulation 42/76 | f = 864.00 MHz | S11 = -0.24 dB
# Simulation 43/76 | f = 868.00 MHz | S11 = -0.25 dB
# Simulation 44/76 | f = 872.00 MHz | S11 = -0.26 dB
# Simulation 45/76 | f = 876.00 MHz | S11 = -0.28 dB
# Simulation 46/76 | f = 880.00 MHz | S11 = -0.29 dB
# Simulation 47/76 | f = 884.00 MHz | S11 = -0.31 dB
# Simulation 48/76 | f = 888.00 MHz | S11 = -0.33 dB
# Simulation 49/76 | f = 892.00 MHz | S11 = -0.35 dB
# Simulation 50/76 | f = 896.00 MHz | S11 = -0.37 dB
# Simulation 51/76 | f = 900.00 MHz | S11 = -0.39 dB
# Simulation 52/76 | f = 904.00 MHz | S11 = -0.41 dB
# Simulation 53/76 | f = 908.00 MHz | S11 = -0.44 dB
# Simulation 54/76 | f = 912.00 MHz | S11 = -0.47 dB
# Simulation 55/76 | f = 916.00 MHz | S11 = -0.49 dB
# Simulation 56/76 | f = 920.00 MHz | S11 = -0.53 dB
# Simulation 57/76 | f = 924.00 MHz | S11 = -0.56 dB
# Simulation 58/76 | f = 928.00 MHz | S11 = -0.60 dB
# Simulation 59/76 | f = 932.00 MHz | S11 = -0.64 dB
# Simulation 60/76 | f = 936.00 MHz | S11 = -0.68 dB
# Simulation 61/76 | f = 940.00 MHz | S11 = -0.73 dB
# Simulation 62/76 | f = 944.00 MHz | S11 = -0.78 dB
# Simulation 63/76 | f = 948.00 MHz | S11 = -0.83 dB
# Simulation 64/76 | f = 952.00 MHz | S11 = -0.89 dB
# Simulation 65/76 | f = 956.00 MHz | S11 = -0.95 dB
# Simulation 66/76 | f = 960.00 MHz | S11 = -1.03 dB
# Simulation 67/76 | f = 964.00 MHz | S11 = -1.10 dB
# Simulation 68/76 | f = 968.00 MHz | S11 = -1.19 dB
# Simulation 69/76 | f = 972.00 MHz | S11 = -1.28 dB
# Simulation 70/76 | f = 976.00 MHz | S11 = -1.38 dB
# Simulation 71/76 | f = 980.00 MHz | S11 = -1.49 dB
# Simulation 72/76 | f = 984.00 MHz | S11 = -1.62 dB
# Simulation 73/76 | f = 988.00 MHz | S11 = -1.75 dB
# Simulation 74/76 | f = 992.00 MHz | S11 = -1.90 dB
# Simulation 75/76 | f = 996.00 MHz | S11 = -2.07 dB
# Simulation 76/76 | f = 1000.00 MHz | S11 = -2.25 dB
#
# 📡 Résultats de simulation :
# → Fréquence de résonance = 1000.00 MHz
# → Impédance à f_res      = 221.91+189.28j Ω
#
# ------------------------------------------------------Iteration N°11------------------------------------------------------
# distance meandres 1.5 mm
# Largeur de piste ifa 1.5 mm
# position feed = 21.841836734693874 mm
#
# Number of meanders 5
# New distance meandres 1.5 mm
# Simulation 1/76 | f = 700.00 MHz | S11 = -0.03 dB
# Simulation 2/76 | f = 704.00 MHz | S11 = -0.03 dB
# Simulation 3/76 | f = 708.00 MHz | S11 = -0.04 dB
# Simulation 4/76 | f = 712.00 MHz | S11 = -0.04 dB
# Simulation 5/76 | f = 716.00 MHz | S11 = -0.04 dB
# Simulation 6/76 | f = 720.00 MHz | S11 = -0.04 dB
# Simulation 7/76 | f = 724.00 MHz | S11 = -0.04 dB
# Simulation 8/76 | f = 728.00 MHz | S11 = -0.05 dB
# Simulation 9/76 | f = 732.00 MHz | S11 = -0.05 dB
# Simulation 10/76 | f = 736.00 MHz | S11 = -0.05 dB
# Simulation 11/76 | f = 740.00 MHz | S11 = -0.05 dB
# Simulation 12/76 | f = 744.00 MHz | S11 = -0.06 dB
# Simulation 13/76 | f = 748.00 MHz | S11 = -0.06 dB
# Simulation 14/76 | f = 752.00 MHz | S11 = -0.06 dB
# Simulation 15/76 | f = 756.00 MHz | S11 = -0.06 dB
# Simulation 16/76 | f = 760.00 MHz | S11 = -0.07 dB
# Simulation 17/76 | f = 764.00 MHz | S11 = -0.07 dB
# Simulation 18/76 | f = 768.00 MHz | S11 = -0.07 dB
# Simulation 19/76 | f = 772.00 MHz | S11 = -0.08 dB
# Simulation 20/76 | f = 776.00 MHz | S11 = -0.08 dB
# Simulation 21/76 | f = 780.00 MHz | S11 = -0.09 dB
# Simulation 22/76 | f = 784.00 MHz | S11 = -0.09 dB
# Simulation 23/76 | f = 788.00 MHz | S11 = -0.09 dB
# Simulation 24/76 | f = 792.00 MHz | S11 = -0.10 dB
# Simulation 25/76 | f = 796.00 MHz | S11 = -0.10 dB
# Simulation 26/76 | f = 800.00 MHz | S11 = -0.11 dB
# Simulation 27/76 | f = 804.00 MHz | S11 = -0.11 dB
# Simulation 28/76 | f = 808.00 MHz | S11 = -0.12 dB
# Simulation 29/76 | f = 812.00 MHz | S11 = -0.13 dB
# Simulation 30/76 | f = 816.00 MHz | S11 = -0.13 dB
# Simulation 31/76 | f = 820.00 MHz | S11 = -0.14 dB
# Simulation 32/76 | f = 824.00 MHz | S11 = -0.15 dB
# Simulation 33/76 | f = 828.00 MHz | S11 = -0.16 dB
# Simulation 34/76 | f = 832.00 MHz | S11 = -0.16 dB
# Simulation 35/76 | f = 836.00 MHz | S11 = -0.17 dB
# Simulation 36/76 | f = 840.00 MHz | S11 = -0.18 dB
# Simulation 37/76 | f = 844.00 MHz | S11 = -0.19 dB
# Simulation 38/76 | f = 848.00 MHz | S11 = -0.20 dB
# Simulation 39/76 | f = 852.00 MHz | S11 = -0.21 dB
# Simulation 40/76 | f = 856.00 MHz | S11 = -0.22 dB
# Simulation 41/76 | f = 860.00 MHz | S11 = -0.24 dB
# Simulation 42/76 | f = 864.00 MHz | S11 = -0.25 dB
# Simulation 43/76 | f = 868.00 MHz | S11 = -0.27 dB
# Simulation 44/76 | f = 872.00 MHz | S11 = -0.28 dB
# Simulation 45/76 | f = 876.00 MHz | S11 = -0.30 dB
# Simulation 46/76 | f = 880.00 MHz | S11 = -0.31 dB
# Simulation 47/76 | f = 884.00 MHz | S11 = -0.33 dB
# Simulation 48/76 | f = 888.00 MHz | S11 = -0.35 dB
# Simulation 49/76 | f = 892.00 MHz | S11 = -0.38 dB
# Simulation 50/76 | f = 896.00 MHz | S11 = -0.40 dB
# Simulation 51/76 | f = 900.00 MHz | S11 = -0.42 dB
# Simulation 52/76 | f = 904.00 MHz | S11 = -0.45 dB
# Simulation 53/76 | f = 908.00 MHz | S11 = -0.48 dB
# Simulation 54/76 | f = 912.00 MHz | S11 = -0.51 dB
# Simulation 55/76 | f = 916.00 MHz | S11 = -0.54 dB
# Simulation 56/76 | f = 920.00 MHz | S11 = -0.58 dB
# Simulation 57/76 | f = 924.00 MHz | S11 = -0.62 dB
# Simulation 58/76 | f = 928.00 MHz | S11 = -0.66 dB
# Simulation 59/76 | f = 932.00 MHz | S11 = -0.71 dB
# Simulation 60/76 | f = 936.00 MHz | S11 = -0.76 dB
# Simulation 61/76 | f = 940.00 MHz | S11 = -0.81 dB
# Simulation 62/76 | f = 944.00 MHz | S11 = -0.87 dB
# Simulation 63/76 | f = 948.00 MHz | S11 = -0.94 dB
# Simulation 64/76 | f = 952.00 MHz | S11 = -1.01 dB
# Simulation 65/76 | f = 956.00 MHz | S11 = -1.09 dB
# Simulation 66/76 | f = 960.00 MHz | S11 = -1.17 dB
# Simulation 67/76 | f = 964.00 MHz | S11 = -1.27 dB
# Simulation 68/76 | f = 968.00 MHz | S11 = -1.37 dB
# Simulation 69/76 | f = 972.00 MHz | S11 = -1.48 dB
# Simulation 70/76 | f = 976.00 MHz | S11 = -1.61 dB
# Simulation 71/76 | f = 980.00 MHz | S11 = -1.75 dB
# Simulation 72/76 | f = 984.00 MHz | S11 = -1.90 dB
# Simulation 73/76 | f = 988.00 MHz | S11 = -2.07 dB
# Simulation 74/76 | f = 992.00 MHz | S11 = -2.26 dB
# Simulation 75/76 | f = 996.00 MHz | S11 = -2.47 dB
# Simulation 76/76 | f = 1000.00 MHz | S11 = -2.70 dB
#
# 📡 Résultats de simulation :
# → Fréquence de résonance = 1000.00 MHz
# → Impédance à f_res      = 223.57+147.40j Ω
#
# ------------------------------------------------------Iteration N°12------------------------------------------------------
# distance meandres 1.5 mm
# Largeur de piste ifa 1.5 mm
# position feed = 21.301020408163264 mm
#
# Number of meanders 5
# New distance meandres 1.5 mm
# Simulation 1/76 | f = 700.00 MHz | S11 = -0.03 dB
# Simulation 2/76 | f = 704.00 MHz | S11 = -0.03 dB
# Simulation 3/76 | f = 708.00 MHz | S11 = -0.04 dB
# Simulation 4/76 | f = 712.00 MHz | S11 = -0.04 dB
# Simulation 5/76 | f = 716.00 MHz | S11 = -0.04 dB
# Simulation 6/76 | f = 720.00 MHz | S11 = -0.04 dB
# Simulation 7/76 | f = 724.00 MHz | S11 = -0.04 dB
# Simulation 8/76 | f = 728.00 MHz | S11 = -0.04 dB
# Simulation 9/76 | f = 732.00 MHz | S11 = -0.05 dB
# Simulation 10/76 | f = 736.00 MHz | S11 = -0.05 dB
# Simulation 11/76 | f = 740.00 MHz | S11 = -0.05 dB
# Simulation 12/76 | f = 744.00 MHz | S11 = -0.05 dB
# Simulation 13/76 | f = 748.00 MHz | S11 = -0.06 dB
# Simulation 14/76 | f = 752.00 MHz | S11 = -0.06 dB
# Simulation 15/76 | f = 756.00 MHz | S11 = -0.06 dB
# Simulation 16/76 | f = 760.00 MHz | S11 = -0.06 dB
# Simulation 17/76 | f = 764.00 MHz | S11 = -0.07 dB
# Simulation 18/76 | f = 768.00 MHz | S11 = -0.07 dB
# Simulation 19/76 | f = 772.00 MHz | S11 = -0.07 dB
# Simulation 20/76 | f = 776.00 MHz | S11 = -0.08 dB
# Simulation 21/76 | f = 780.00 MHz | S11 = -0.08 dB
# ...
# Simulation 15/76 | f = 756.00 MHz | S11 = -0.04 dB
# Simulation 16/76 | f = 760.00 MHz | S11 = -0.04 dB
# Simulation 17/76 | f = 764.00 MHz | S11 = -0.04 dB
# Simulation 18/76 | f = 768.00 MHz | S11 = -0.04 dB
# Simulation 19/76 | f = 772.00 MHz | S11 = -0.05 dB
# Simulation 20/76 | f = 776.00 MHz | S11 = -0.05 dB
# Simulation 21/76 | f = 780.00 MHz | S11 = -0.05 dB
# Simulation 22/76 | f = 784.00 MHz | S11 = -0.05 dB
# Simulation 23/76 | f = 788.00 MHz | S11 = -0.05 dB
# Simulation 24/76 | f = 792.00 MHz | S11 = -0.05 dB
# Simulation 25/76 | f = 796.00 MHz | S11 = -0.05 dB
# Simulation 26/76 | f = 800.00 MHz | S11 = -0.06 dB
# Simulation 27/76 | f = 804.00 MHz | S11 = -0.06 dB
# Simulation 28/76 | f = 808.00 MHz | S11 = -0.06 dB
# Simulation 29/76 | f = 812.00 MHz | S11 = -0.06 dB
# Simulation 30/76 | f = 816.00 MHz | S11 = -0.06 dB
# Simulation 31/76 | f = 820.00 MHz | S11 = -0.07 dB
# Simulation 32/76 | f = 824.00 MHz | S11 = -0.07 dB
# Simulation 33/76 | f = 828.00 MHz | S11 = -0.07 dB
# Simulation 34/76 | f = 832.00 MHz | S11 = -0.07 dB
# Simulation 35/76 | f = 836.00 MHz | S11 = -0.08 dB
# Simulation 36/76 | f = 840.00 MHz | S11 = -0.08 dB
# Simulation 37/76 | f = 844.00 MHz | S11 = -0.08 dB
# Simulation 38/76 | f = 848.00 MHz | S11 = -0.08 dB
# Simulation 39/76 | f = 852.00 MHz | S11 = -0.09 dB
# Simulation 40/76 | f = 856.00 MHz | S11 = -0.09 dB
# Simulation 41/76 | f = 860.00 MHz | S11 = -0.09 dB
# Simulation 42/76 | f = 864.00 MHz | S11 = -0.10 dB
# Simulation 43/76 | f = 868.00 MHz | S11 = -0.10 dB
# Simulation 44/76 | f = 872.00 MHz | S11 = -0.10 dB
# Simulation 45/76 | f = 876.00 MHz | S11 = -0.11 dB
# Simulation 46/76 | f = 880.00 MHz | S11 = -0.11 dB
# Simulation 47/76 | f = 884.00 MHz | S11 = -0.12 dB
# Simulation 48/76 | f = 888.00 MHz | S11 = -0.12 dB
# Simulation 49/76 | f = 892.00 MHz | S11 = -0.12 dB
# Simulation 50/76 | f = 896.00 MHz | S11 = -0.13 dB
# Simulation 51/76 | f = 900.00 MHz | S11 = -0.13 dB
# Simulation 52/76 | f = 904.00 MHz | S11 = -0.14 dB
# Simulation 53/76 | f = 908.00 MHz | S11 = -0.14 dB
# Simulation 54/76 | f = 912.00 MHz | S11 = -0.15 dB
# Simulation 55/76 | f = 916.00 MHz | S11 = -0.16 dB
# Simulation 56/76 | f = 920.00 MHz | S11 = -0.16 dB
# Simulation 57/76 | f = 924.00 MHz | S11 = -0.17 dB
# Simulation 58/76 | f = 928.00 MHz | S11 = -0.17 dB
# Simulation 59/76 | f = 932.00 MHz | S11 = -0.18 dB
# Simulation 60/76 | f = 936.00 MHz | S11 = -0.19 dB
# Simulation 61/76 | f = 940.00 MHz | S11 = -0.19 dB
# Simulation 62/76 | f = 944.00 MHz | S11 = -0.20 dB
# Simulation 63/76 | f = 948.00 MHz | S11 = -0.21 dB
# Simulation 64/76 | f = 952.00 MHz | S11 = -0.22 dB
# Simulation 65/76 | f = 956.00 MHz | S11 = -0.23 dB
# Simulation 66/76 | f = 960.00 MHz | S11 = -0.24 dB
# Simulation 67/76 | f = 964.00 MHz | S11 = -0.25 dB
# Simulation 68/76 | f = 968.00 MHz | S11 = -0.26 dB
# Simulation 69/76 | f = 972.00 MHz | S11 = -0.27 dB
# Simulation 70/76 | f = 976.00 MHz | S11 = -0.28 dB
# Simulation 71/76 | f = 980.00 MHz | S11 = -0.29 dB
# Simulation 72/76 | f = 984.00 MHz | S11 = -0.30 dB
# Simulation 73/76 | f = 988.00 MHz | S11 = -0.31 dB
# Simulation 74/76 | f = 992.00 MHz | S11 = -0.33 dB
# Simulation 75/76 | f = 996.00 MHz | S11 = -0.34 dB
# Simulation 76/76 | f = 1000.00 MHz | S11 = -0.36 dB
#
# 📡 Résultats de simulation :
# → Fréquence de résonance = 1000.00 MHz
# → Impédance à f_res      = 26.54+247.77j Ω
#
# ------------------------------------------------------Iteration N°48------------------------------------------------------
# distance meandres 1.5 mm
# Largeur de piste ifa 1.5 mm
# position feed = 1.8316326530612228 mm
#
# Number of meanders 5
# New distance meandres 1.5 mm
# Simulation 1/76 | f = 700.00 MHz | S11 = -0.02 dB
# Simulation 2/76 | f = 704.00 MHz | S11 = -0.03 dB
# Simulation 3/76 | f = 708.00 MHz | S11 = -0.03 dB
# Simulation 4/76 | f = 712.00 MHz | S11 = -0.03 dB
# Simulation 5/76 | f = 716.00 MHz | S11 = -0.03 dB
# Simulation 6/76 | f = 720.00 MHz | S11 = -0.03 dB
# Simulation 7/76 | f = 724.00 MHz | S11 = -0.03 dB
# Simulation 8/76 | f = 728.00 MHz | S11 = -0.03 dB
# Simulation 9/76 | f = 732.00 MHz | S11 = -0.03 dB
# Simulation 10/76 | f = 736.00 MHz | S11 = -0.03 dB
# Simulation 11/76 | f = 740.00 MHz | S11 = -0.03 dB
# Simulation 12/76 | f = 744.00 MHz | S11 = -0.04 dB
# Simulation 13/76 | f = 748.00 MHz | S11 = -0.04 dB
# Simulation 14/76 | f = 752.00 MHz | S11 = -0.04 dB
# Simulation 15/76 | f = 756.00 MHz | S11 = -0.04 dB
# Simulation 16/76 | f = 760.00 MHz | S11 = -0.04 dB
# Simulation 17/76 | f = 764.00 MHz | S11 = -0.04 dB
# Simulation 18/76 | f = 768.00 MHz | S11 = -0.04 dB
# Simulation 19/76 | f = 772.00 MHz | S11 = -0.04 dB
# Simulation 20/76 | f = 776.00 MHz | S11 = -0.05 dB
# Simulation 21/76 | f = 780.00 MHz | S11 = -0.05 dB
# Simulation 22/76 | f = 784.00 MHz | S11 = -0.05 dB
# Simulation 23/76 | f = 788.00 MHz | S11 = -0.05 dB
# Simulation 24/76 | f = 792.00 MHz | S11 = -0.05 dB
# Simulation 25/76 | f = 796.00 MHz | S11 = -0.05 dB
# Simulation 26/76 | f = 800.00 MHz | S11 = -0.06 dB
# Simulation 27/76 | f = 804.00 MHz | S11 = -0.06 dB
# Simulation 28/76 | f = 808.00 MHz | S11 = -0.06 dB
# Simulation 29/76 | f = 812.00 MHz | S11 = -0.06 dB
# Simulation 30/76 | f = 816.00 MHz | S11 = -0.06 dB
# Simulation 31/76 | f = 820.00 MHz | S11 = -0.07 dB
# Simulation 32/76 | f = 824.00 MHz | S11 = -0.07 dB
# Simulation 33/76 | f = 828.00 MHz | S11 = -0.07 dB
# Simulation 34/76 | f = 832.00 MHz | S11 = -0.07 dB
# Simulation 35/76 | f = 836.00 MHz | S11 = -0.08 dB
# Simulation 36/76 | f = 840.00 MHz | S11 = -0.08 dB
# Simulation 37/76 | f = 844.00 MHz | S11 = -0.08 dB
# Simulation 38/76 | f = 848.00 MHz | S11 = -0.08 dB
# Simulation 39/76 | f = 852.00 MHz | S11 = -0.09 dB
# Simulation 40/76 | f = 856.00 MHz | S11 = -0.09 dB
# Simulation 41/76 | f = 860.00 MHz | S11 = -0.09 dB
# Simulation 42/76 | f = 864.00 MHz | S11 = -0.10 dB
# Simulation 43/76 | f = 868.00 MHz | S11 = -0.10 dB
# Simulation 44/76 | f = 872.00 MHz | S11 = -0.10 dB
# Simulation 45/76 | f = 876.00 MHz | S11 = -0.11 dB
# Simulation 46/76 | f = 880.00 MHz | S11 = -0.11 dB
# Simulation 47/76 | f = 884.00 MHz | S11 = -0.11 dB
# Simulation 48/76 | f = 888.00 MHz | S11 = -0.12 dB
# Simulation 49/76 | f = 892.00 MHz | S11 = -0.12 dB
# Simulation 50/76 | f = 896.00 MHz | S11 = -0.13 dB
# Simulation 51/76 | f = 900.00 MHz | S11 = -0.13 dB
# Simulation 52/76 | f = 904.00 MHz | S11 = -0.14 dB
# Simulation 53/76 | f = 908.00 MHz | S11 = -0.14 dB
# Simulation 54/76 | f = 912.00 MHz | S11 = -0.15 dB
# Simulation 55/76 | f = 916.00 MHz | S11 = -0.15 dB
# Simulation 56/76 | f = 920.00 MHz | S11 = -0.16 dB
# Simulation 57/76 | f = 924.00 MHz | S11 = -0.16 dB
# Simulation 58/76 | f = 928.00 MHz | S11 = -0.17 dB
# Simulation 59/76 | f = 932.00 MHz | S11 = -0.18 dB
# Simulation 60/76 | f = 936.00 MHz | S11 = -0.18 dB
# Simulation 61/76 | f = 940.00 MHz | S11 = -0.19 dB
# Simulation 62/76 | f = 944.00 MHz | S11 = -0.20 dB
# Simulation 63/76 | f = 948.00 MHz | S11 = -0.20 dB
# Simulation 64/76 | f = 952.00 MHz | S11 = -0.21 dB
# Simulation 65/76 | f = 956.00 MHz | S11 = -0.22 dB
# Simulation 66/76 | f = 960.00 MHz | S11 = -0.23 dB
# Simulation 67/76 | f = 964.00 MHz | S11 = -0.24 dB
# Simulation 68/76 | f = 968.00 MHz | S11 = -0.25 dB
# Simulation 69/76 | f = 972.00 MHz | S11 = -0.26 dB
# Simulation 70/76 | f = 976.00 MHz | S11 = -0.27 dB
# Simulation 71/76 | f = 980.00 MHz | S11 = -0.28 dB
# Simulation 72/76 | f = 984.00 MHz | S11 = -0.29 dB
# Simulation 73/76 | f = 988.00 MHz | S11 = -0.30 dB
# Simulation 74/76 | f = 992.00 MHz | S11 = -0.32 dB
# Simulation 75/76 | f = 996.00 MHz | S11 = -0.33 dB
# Simulation 76/76 | f = 1000.00 MHz | S11 = -0.35 dB
#
# 📡 Résultats de simulation :
# → Fréquence de résonance = 1000.00 MHz
# → Impédance à f_res      = 25.57+247.43j Ω
#
# ------------------------------------------------------Iteration N°49------------------------------------------------------
# distance meandres 1.5 mm
# Largeur de piste ifa 1.5 mm
# position feed = 1.2908163265306118 mm
#
# Number of meanders 5
# New distance meandres 1.5 mm
# Simulation 1/76 | f = 700.00 MHz | S11 = -0.02 dB
# Simulation 2/76 | f = 704.00 MHz | S11 = -0.03 dB
# Simulation 3/76 | f = 708.00 MHz | S11 = -0.03 dB
# Simulation 4/76 | f = 712.00 MHz | S11 = -0.03 dB
# Simulation 5/76 | f = 716.00 MHz | S11 = -0.03 dB
# Simulation 6/76 | f = 720.00 MHz | S11 = -0.03 dB
# Simulation 7/76 | f = 724.00 MHz | S11 = -0.03 dB
# Simulation 8/76 | f = 728.00 MHz | S11 = -0.03 dB
# Simulation 9/76 | f = 732.00 MHz | S11 = -0.03 dB
# Simulation 10/76 | f = 736.00 MHz | S11 = -0.03 dB
# Simulation 11/76 | f = 740.00 MHz | S11 = -0.03 dB
# Simulation 12/76 | f = 744.00 MHz | S11 = -0.04 dB
# Simulation 13/76 | f = 748.00 MHz | S11 = -0.04 dB
# Simulation 14/76 | f = 752.00 MHz | S11 = -0.04 dB
# Simulation 15/76 | f = 756.00 MHz | S11 = -0.04 dB
# Simulation 16/76 | f = 760.00 MHz | S11 = -0.04 dB
# Simulation 17/76 | f = 764.00 MHz | S11 = -0.04 dB
# Simulation 18/76 | f = 768.00 MHz | S11 = -0.04 dB
# Simulation 19/76 | f = 772.00 MHz | S11 = -0.04 dB
# Simulation 20/76 | f = 776.00 MHz | S11 = -0.05 dB
# Simulation 21/76 | f = 780.00 MHz | S11 = -0.05 dB
# Simulation 22/76 | f = 784.00 MHz | S11 = -0.05 dB
# Simulation 23/76 | f = 788.00 MHz | S11 = -0.05 dB
# Simulation 24/76 | f = 792.00 MHz | S11 = -0.05 dB
# Simulation 25/76 | f = 796.00 MHz | S11 = -0.05 dB
# Simulation 26/76 | f = 800.00 MHz | S11 = -0.06 dB
# Simulation 27/76 | f = 804.00 MHz | S11 = -0.06 dB
# Simulation 28/76 | f = 808.00 MHz | S11 = -0.06 dB
# Simulation 29/76 | f = 812.00 MHz | S11 = -0.06 dB
# Simulation 30/76 | f = 816.00 MHz | S11 = -0.06 dB
# Simulation 31/76 | f = 820.00 MHz | S11 = -0.07 dB
# Simulation 32/76 | f = 824.00 MHz | S11 = -0.07 dB
# Simulation 33/76 | f = 828.00 MHz | S11 = -0.07 dB
# Simulation 34/76 | f = 832.00 MHz | S11 = -0.07 dB
# Simulation 35/76 | f = 836.00 MHz | S11 = -0.07 dB
# Simulation 36/76 | f = 840.00 MHz | S11 = -0.08 dB
# Simulation 37/76 | f = 844.00 MHz | S11 = -0.08 dB
# Simulation 38/76 | f = 848.00 MHz | S11 = -0.08 dB
# Simulation 39/76 | f = 852.00 MHz | S11 = -0.09 dB
# Simulation 40/76 | f = 856.00 MHz | S11 = -0.09 dB
# Simulation 41/76 | f = 860.00 MHz | S11 = -0.09 dB
# Simulation 42/76 | f = 864.00 MHz | S11 = -0.09 dB
# Simulation 43/76 | f = 868.00 MHz | S11 = -0.10 dB
# Simulation 44/76 | f = 872.00 MHz | S11 = -0.10 dB
# Simulation 45/76 | f = 876.00 MHz | S11 = -0.10 dB
# Simulation 46/76 | f = 880.00 MHz | S11 = -0.11 dB
# Simulation 47/76 | f = 884.00 MHz | S11 = -0.11 dB
# Simulation 48/76 | f = 888.00 MHz | S11 = -0.12 dB
# Simulation 49/76 | f = 892.00 MHz | S11 = -0.12 dB
# Simulation 50/76 | f = 896.00 MHz | S11 = -0.12 dB
# Simulation 51/76 | f = 900.00 MHz | S11 = -0.13 dB
# Simulation 52/76 | f = 904.00 MHz | S11 = -0.13 dB
# Simulation 53/76 | f = 908.00 MHz | S11 = -0.14 dB
# Simulation 54/76 | f = 912.00 MHz | S11 = -0.14 dB
# Simulation 55/76 | f = 916.00 MHz | S11 = -0.15 dB
# Simulation 56/76 | f = 920.00 MHz | S11 = -0.15 dB
# Simulation 57/76 | f = 924.00 MHz | S11 = -0.16 dB
# Simulation 58/76 | f = 928.00 MHz | S11 = -0.17 dB
# Simulation 59/76 | f = 932.00 MHz | S11 = -0.17 dB
# Simulation 60/76 | f = 936.00 MHz | S11 = -0.18 dB
# Simulation 61/76 | f = 940.00 MHz | S11 = -0.19 dB
# Simulation 62/76 | f = 944.00 MHz | S11 = -0.19 dB
# Simulation 63/76 | f = 948.00 MHz | S11 = -0.20 dB
# Simulation 64/76 | f = 952.00 MHz | S11 = -0.21 dB
# Simulation 65/76 | f = 956.00 MHz | S11 = -0.22 dB
# Simulation 66/76 | f = 960.00 MHz | S11 = -0.22 dB
# Simulation 67/76 | f = 964.00 MHz | S11 = -0.23 dB
# Simulation 68/76 | f = 968.00 MHz | S11 = -0.24 dB
# Simulation 69/76 | f = 972.00 MHz | S11 = -0.25 dB
# Simulation 70/76 | f = 976.00 MHz | S11 = -0.26 dB
# Simulation 71/76 | f = 980.00 MHz | S11 = -0.27 dB
# Simulation 72/76 | f = 984.00 MHz | S11 = -0.29 dB
# Simulation 73/76 | f = 988.00 MHz | S11 = -0.30 dB
# Simulation 74/76 | f = 992.00 MHz | S11 = -0.31 dB
# Simulation 75/76 | f = 996.00 MHz | S11 = -0.32 dB
# Simulation 76/76 | f = 1000.00 MHz | S11 = -0.34 dB
#
# 📡 Résultats de simulation :
# → Fréquence de résonance = 1000.00 MHz
# → Impédance à f_res      = 25.63+250.86j Ω
#
# ------------------------------------------------------Iteration N°50------------------------------------------------------
# distance meandres 1.5 mm
# Largeur de piste ifa 1.5 mm
# position feed = 0.75 mm
#
# Number of meanders 5
# New distance meandres 1.5 mm
# Simulation 1/76 | f = 700.00 MHz | S11 = -0.02 dB
# Simulation 2/76 | f = 704.00 MHz | S11 = -0.03 dB
# Simulation 3/76 | f = 708.00 MHz | S11 = -0.03 dB
# Simulation 4/76 | f = 712.00 MHz | S11 = -0.03 dB
# Simulation 5/76 | f = 716.00 MHz | S11 = -0.03 dB
# Simulation 6/76 | f = 720.00 MHz | S11 = -0.03 dB
# Simulation 7/76 | f = 724.00 MHz | S11 = -0.03 dB
# Simulation 8/76 | f = 728.00 MHz | S11 = -0.03 dB
# Simulation 9/76 | f = 732.00 MHz | S11 = -0.03 dB
# Simulation 10/76 | f = 736.00 MHz | S11 = -0.03 dB
# Simulation 11/76 | f = 740.00 MHz | S11 = -0.03 dB
# Simulation 12/76 | f = 744.00 MHz | S11 = -0.04 dB
# Simulation 13/76 | f = 748.00 MHz | S11 = -0.04 dB
# Simulation 14/76 | f = 752.00 MHz | S11 = -0.04 dB
# Simulation 15/76 | f = 756.00 MHz | S11 = -0.04 dB
# Simulation 16/76 | f = 760.00 MHz | S11 = -0.04 dB
# Simulation 17/76 | f = 764.00 MHz | S11 = -0.04 dB
# Simulation 18/76 | f = 768.00 MHz | S11 = -0.04 dB
# Simulation 19/76 | f = 772.00 MHz | S11 = -0.05 dB
# Simulation 20/76 | f = 776.00 MHz | S11 = -0.05 dB
# Simulation 21/76 | f = 780.00 MHz | S11 = -0.05 dB
# Simulation 22/76 | f = 784.00 MHz | S11 = -0.05 dB
# Simulation 23/76 | f = 788.00 MHz | S11 = -0.05 dB
# Simulation 24/76 | f = 792.00 MHz | S11 = -0.05 dB
# Simulation 25/76 | f = 796.00 MHz | S11 = -0.06 dB
# Simulation 26/76 | f = 800.00 MHz | S11 = -0.06 dB
# Simulation 27/76 | f = 804.00 MHz | S11 = -0.06 dB
# Simulation 28/76 | f = 808.00 MHz | S11 = -0.06 dB
# Simulation 29/76 | f = 812.00 MHz | S11 = -0.06 dB
# Simulation 30/76 | f = 816.00 MHz | S11 = -0.07 dB
# Simulation 31/76 | f = 820.00 MHz | S11 = -0.07 dB
# Simulation 32/76 | f = 824.00 MHz | S11 = -0.07 dB
# Simulation 33/76 | f = 828.00 MHz | S11 = -0.07 dB
# Simulation 34/76 | f = 832.00 MHz | S11 = -0.08 dB
# Simulation 35/76 | f = 836.00 MHz | S11 = -0.08 dB
# Simulation 36/76 | f = 840.00 MHz | S11 = -0.08 dB
# Simulation 37/76 | f = 844.00 MHz | S11 = -0.08 dB
# Simulation 38/76 | f = 848.00 MHz | S11 = -0.09 dB
# Simulation 39/76 | f = 852.00 MHz | S11 = -0.09 dB
# Simulation 40/76 | f = 856.00 MHz | S11 = -0.09 dB
# Simulation 41/76 | f = 860.00 MHz | S11 = -0.10 dB
# Simulation 42/76 | f = 864.00 MHz | S11 = -0.10 dB
# Simulation 43/76 | f = 868.00 MHz | S11 = -0.11 dB
# Simulation 44/76 | f = 872.00 MHz | S11 = -0.11 dB
# Simulation 45/76 | f = 876.00 MHz | S11 = -0.11 dB
# Simulation 46/76 | f = 880.00 MHz | S11 = -0.12 dB
# Simulation 47/76 | f = 884.00 MHz | S11 = -0.12 dB
# Simulation 48/76 | f = 888.00 MHz | S11 = -0.13 dB
# Simulation 49/76 | f = 892.00 MHz | S11 = -0.13 dB
# Simulation 50/76 | f = 896.00 MHz | S11 = -0.14 dB
# Simulation 51/76 | f = 900.00 MHz | S11 = -0.14 dB
# Simulation 52/76 | f = 904.00 MHz | S11 = -0.15 dB
# Simulation 53/76 | f = 908.00 MHz | S11 = -0.16 dB
# Simulation 54/76 | f = 912.00 MHz | S11 = -0.16 dB
# Simulation 55/76 | f = 916.00 MHz | S11 = -0.17 dB
# Simulation 56/76 | f = 920.00 MHz | S11 = -0.17 dB
# Simulation 57/76 | f = 924.00 MHz | S11 = -0.18 dB
# Simulation 58/76 | f = 928.00 MHz | S11 = -0.19 dB
# Simulation 59/76 | f = 932.00 MHz | S11 = -0.20 dB
# Simulation 60/76 | f = 936.00 MHz | S11 = -0.21 dB
# Simulation 61/76 | f = 940.00 MHz | S11 = -0.21 dB
# Simulation 62/76 | f = 944.00 MHz | S11 = -0.22 dB
# Simulation 63/76 | f = 948.00 MHz | S11 = -0.23 dB
# Simulation 64/76 | f = 952.00 MHz | S11 = -0.24 dB
# Simulation 65/76 | f = 956.00 MHz | S11 = -0.25 dB
# Simulation 66/76 | f = 960.00 MHz | S11 = -0.26 dB
# Simulation 67/76 | f = 964.00 MHz | S11 = -0.28 dB
# Simulation 68/76 | f = 968.00 MHz | S11 = -0.29 dB
# Simulation 69/76 | f = 972.00 MHz | S11 = -0.30 dB
# Simulation 70/76 | f = 976.00 MHz | S11 = -0.31 dB
# Simulation 71/76 | f = 980.00 MHz | S11 = -0.33 dB
# Simulation 72/76 | f = 984.00 MHz | S11 = -0.34 dB
# Simulation 73/76 | f = 988.00 MHz | S11 = -0.36 dB
# Simulation 74/76 | f = 992.00 MHz | S11 = -0.38 dB
# Simulation 75/76 | f = 996.00 MHz | S11 = -0.39 dB
# Simulation 76/76 | f = 1000.00 MHz | S11 = -0.41 dB
#
# 📡 Résultats de simulation :
# → Fréquence de résonance = 1000.00 MHz
# → Impédance à f_res      = 137.32-517.36j Ω

# %%
# Load and display feed_list.npy
loaded_feed_list = np.load('data/analyse_feed_position/feed_list.npy')
print("\nContents of loaded_feed_list.npy:", loaded_feed_list / b * 100)

# Load and display frequences_resonance.npy
loaded_frequences_resonance = np.load('data/analyse_feed_position/frequences_resonance.npy')
print("\nContents of frequences_resonance.npy:", loaded_frequences_resonance * 1e-6)
# Out:
# Contenu de loaded_largeur_piste_list.npy : [90.83333333 89.03061224 87.22789116 85.42517007 83.62244898 81.81972789
#  80.0170068  78.21428571 76.41156463 74.60884354 72.80612245 71.00340136
#  69.20068027 67.39795918 65.5952381  63.79251701 61.98979592 60.18707483
#  58.38435374 56.58163265 54.77891156 52.97619048 51.17346939 49.3707483
#  47.56802721 45.76530612 43.96258503 42.15986395 40.35714286 38.55442177
#  36.75170068 34.94897959 33.1462585  31.34353741 29.54081633 27.73809524
#  25.93537415 24.13265306 22.32993197 20.52721088 18.7244898  16.92176871
#  15.11904762 13.31632653 11.51360544  9.71088435  7.90816327  6.10544218
#   4.30272109  2.5       ]
#
# Contenu de frequences_resonance.npy : [1000. 1000. 1000. 1000. 1000. 1000. 1000. 1000. 1000. 1000. 1000. 1000.
#  1000. 1000. 1000. 1000. 1000. 1000. 1000. 1000. 1000. 1000. 1000. 1000.
#  1000. 1000. 1000. 1000. 1000. 1000. 1000. 1000. 1000. 1000. 1000. 1000.
#  1000. 1000. 1000. 1000. 1000. 1000. 1000. 1000. 1000. 1000. 1000. 1000.
#  1000. 1000.]

# %%
from matplotlib import pyplot as plt

# Convert data
frequences_resonance_mhz = np.array(loaded_frequences_resonance) * 1e-6
loaded_feed_list_mm = np.array(loaded_feed_list) * 1000  # Convert to mm

plt.figure(figsize=(10, 6))
plt.plot(loaded_feed_list_mm, frequences_resonance_mhz, marker='o', linestyle='-', color='b', label='frequences_resonance_mhz')

# Add a horizontal line for fC
plt.axhline(y=fC * 1e-6, color='r', linestyle='--', label=f'fC = {fC * 1e-6:.2f} MHz')

plt.xlabel('Feed list position (mm)')
plt.ylabel('Resonance frequency (MHz)')
plt.title('Resonance frequency as a function of feed position')
plt.legend(title=f"a = {a * 1000:.2f} mm, b = {b * 1000:.2f} mm, track width = {largeur_piste * 1000:.2f} mm, meander distance = {distance_meandre * 1000:.2f} mm")
plt.grid(True)
plt.show()
