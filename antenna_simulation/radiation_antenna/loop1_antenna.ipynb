# %%
from src.radiation_algorithm.radiation_algorithm import *
from rwg.rwg6 import plot_surface_current_distribution
from efield.efield1 import calculate_electric_magnetic_field_at_point
from efield.efield2 import radiation_intensity_distribution_over_sphere_surface
from efield.efield3 import antenna_directivity_pattern

# %%
filename_mesh = 'data/antennas_mesh/loop1.mat'

# %%
# Mesure du temps de début
start_time = time.time()

feed_point = np.array([-1, 0, 0])
frequency = 4.8e6

radiation_algorithm(filename_mesh, frequency, feed_point)

elapsed_time = time.time() - start_time
print(f"Temps écoulé pour le traitement de l'antenne étudiée : {elapsed_time:.6f} secondes")
print('\n')
# Out:
# La valeur de l'impédance d'entrée de l'antenne loop1 = 0.0228205 + 182.8968778i Ohm
# Gap current of loop1 = (6.822003929655045e-07-0.005467561812463635j)
# Gap voltage of loop1 = (1+0j)
# La valeur de feed_power  = 3.4110019648275227e-07
# Temps écoulé pour le traitement de l'antenne étudiée : 0.288332 secondes

# %%
# Maillage dense pour une sphère utilisée dans les calculs de rayonnement
filename_sphere_dense = '../../data/sphere_mesh/sphere_dense.mat'

mesh2_mat = 'data/antennas_mesh2/loop1_mesh2.mat'
current_mat = 'data/antennas_current/loop1_current.mat'
gain_power_mat = 'data/antennas_gain_power/loop1_gain_power.mat'

observationPoint = np.array([100, 0, 0])

calculate_electric_magnetic_field_at_point(mesh2_mat, current_mat, observationPoint, radiation=True)

print("Calculating radiation intensity distribution over sphere surface...")
radiation_intensity_distribution_over_sphere_surface(mesh2_mat, current_mat, filename_sphere_dense, radiation=True)

# Étape 3 : Génération du diagramme de directivité
print("Generating antenna directivity pattern...")
antenna_directivity_pattern(mesh2_mat, current_mat, gain_power_mat, radiation=True)
# Out:
# Frequency = 4800000.0 Hz
# Longueur d'onde lambda = 62.44840707929359 m
# Le point d'observation est : [100   0   0]
#
# e_field_total of loop1 at the observation point [100   0   0] is :
# -0.0000000 - 0.0000000i V/m
#  0.0000446 + 0.0000330i V/m
#  0.0000000 + 0.0000000i V/m
#
# h_field_total of loop1 at the observation point [100   0   0] is :
# -0.0000000 + 0.0000000i A/m
# -0.0000000 + 0.0000000i A/m
#  0.0000001 + 0.0000001i A/m
#
# Poynting vector is equal to :
#  0.000000 W/m^2
#  0.000000 W/m^2
# -0.000000 W/m^2
#
# w = 4.041373987784925e-12 W/m^2
#
# u = 4.041373987784925e-08 W/unit solid angle
# Calculating radiation intensity distribution over sphere surface...
#
# Frequency = 4800000.0 Hz
# Longueur d'onde lambda = 62.44840707929359 m
#
# Total Power :  0.000000
# Gain Linear :  1.420354
# Gain Logarithmic :  1.523967 dB
#
# gap_curent = (6.822003929655045e-07-0.005467561812463635j)
# Radiation Resistance :  0.023932 Ohms
# Data saved successfully to data/antennas_gain_power/loop1_gain_power.mat
# Generating antenna directivity pattern...
# Data loaded from data/antennas_gain_power/loop1_gain_power.mat
