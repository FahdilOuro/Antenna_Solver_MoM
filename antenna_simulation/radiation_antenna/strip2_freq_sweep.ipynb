# %%
from src.radiation_algorithm.radiation_algorithm import *
from efield.efield1 import calculate_electric_magnetic_field_at_point
from efield.efield2 import radiation_intensity_distribution_over_sphere_surface
from efield.efield3 import antenna_directivity_pattern
from utils.frequency_sweep import *

# %%
filename_mesh = 'data/antennas_mesh/strip2.mat'
result_freq_sweep = 'data/antennas_sweep/strip2_freq_sweep.mat'

# %%
start_frequency = 25e6
stop_frequency = 500e6

# %%
frequencies = generate_freq_step(start_frequency, stop_frequency)

# Mesure du temps de début
start_time = time.time()

feed_point = np.array([-1, 0, 0])

frequency_sweep(filename_mesh, frequencies, feed_point)

elapsed_time = time.time() - start_time
print(f"Temps écoulé pour le traitement de l'antenne étudiée : {elapsed_time:.6f} secondes")
print('\n')
# Out:
# Simulation 1/238 | f = 25.00 MHz | S11 = -0.01 dB
# Simulation 2/238 | f = 27.00 MHz | S11 = -0.01 dB
# Simulation 3/238 | f = 29.00 MHz | S11 = -0.01 dB
# Simulation 4/238 | f = 31.00 MHz | S11 = -0.02 dB
# Simulation 5/238 | f = 33.00 MHz | S11 = -0.02 dB
# Simulation 6/238 | f = 35.00 MHz | S11 = -0.03 dB
# Simulation 7/238 | f = 37.00 MHz | S11 = -0.04 dB
# Simulation 8/238 | f = 39.00 MHz | S11 = -0.06 dB
# Simulation 9/238 | f = 41.00 MHz | S11 = -0.07 dB
# Simulation 10/238 | f = 43.00 MHz | S11 = -0.10 dB
# Simulation 11/238 | f = 45.00 MHz | S11 = -0.13 dB
# Simulation 12/238 | f = 47.00 MHz | S11 = -0.18 dB
# Simulation 13/238 | f = 49.00 MHz | S11 = -0.25 dB
# Simulation 14/238 | f = 51.00 MHz | S11 = -0.34 dB
# Simulation 15/238 | f = 53.00 MHz | S11 = -0.46 dB
# Simulation 16/238 | f = 55.00 MHz | S11 = -0.65 dB
# Simulation 17/238 | f = 57.00 MHz | S11 = -0.92 dB
# Simulation 18/238 | f = 59.00 MHz | S11 = -1.33 dB
# Simulation 19/238 | f = 61.00 MHz | S11 = -1.97 dB
# ...

# %%
frequencies, impedances, s11_db = load_freq_sweep_data(result_freq_sweep)
# plot_smith_chart(impedances, frequencies)
plot_impedance_curve(impedances, start_frequency, stop_frequency)
plot_s11_curve(s11_db, start_frequency, stop_frequency)
