# %%
from src.radiation_algorithm.radiation_algorithm import *
from efield.efield1 import calculate_electric_magnetic_field_at_point
from efield.efield2 import radiation_intensity_distribution_over_sphere_surface
from efield.efield3 import antenna_directivity_pattern

# %%
filename_mesh = 'data/antennas_mesh/array_linear_1.mat'

# %%
# Mesure du temps de début
start_time = time.time()

feed_point = np.array([[-1, 0, 0],
                      [1, 0, 0]])
frequency = 75e6

radiation_algorithm(filename_mesh, frequency, feed_point, simulate_array_antenna=True)

elapsed_time = time.time() - start_time
print(f"Temps écoulé pour le traitement de l'antenne étudiée : {elapsed_time:.6f} secondes")
print('\n')
# Out:
# voltage[index_feeding_edges] =  [0.02+0.j 0.02+0.j]
#
# La valeur de l'impédance d'entrée de l'antenne array_linear_1 = [67.0101028 + 13.2360266i, 67.0101004 + 13.2360729i] Ohm
# Gap current of array_linear_1 = [(0.014362755998511258-0.0028369725309308094j), (0.014362752710961189-0.002836981911655871j)]
# Gap voltage of array_linear_1 = [(1+0j), (1+0j)]
# La valeur de feed_power  = [0.007181377999255629, 0.007181376355480594]
#
#
# Surface current density of array_linear_1: min = 0.0180927 [A/m], max = 0.7338195 [A/m]
# Temps écoulé pour le traitement de l'antenne étudiée : 0.208172 secondes

# %%
# Maillage dense pour une sphère utilisée dans les calculs de rayonnement
filename_sphere_dense = '../../data/sphere_mesh/sphere_dense.mat'

mesh2_mat = 'data/antennas_mesh2/array_linear_1_mesh2.mat'
current_mat = 'data/antennas_current/array_linear_1_current.mat'
gain_power_mat = 'data/antennas_gain_power/array_linear_1_gain_power.mat'

observationPoint = np.array([100, 0, 0])

calculate_electric_magnetic_field_at_point(mesh2_mat, current_mat, observationPoint, radiation=True)

print("Calculating radiation intensity distribution over sphere surface...")
radiation_intensity_distribution_over_sphere_surface(mesh2_mat, current_mat, filename_sphere_dense, radiation=True)

# Étape 3 : Génération du diagramme de directivité
print("Generating antenna directivity pattern...")
antenna_directivity_pattern(mesh2_mat, current_mat, gain_power_mat, radiation=True)
# Out:
# Frequency = 75000000.0 Hz
# Longueur d'onde lambda = 3.9966980530747898 m
# Le point d'observation est : [100   0   0]
#
# e_field_total of array_linear_1 at the observation point [100   0   0] is :
# -0.0000000 - 0.0000000i V/m
#  0.0000000 + 0.0000000i V/m
#  0.0001791 + 0.0000532i V/m
#
# h_field_total of array_linear_1 at the observation point [100   0   0] is :
#  0.0000000 + 0.0000000i A/m
# -0.0000005 + 0.0000001i A/m
#  0.0000000 + 0.0000000i A/m
#
# Poynting vector is equal to :
#  0.000000 W/m^2
#  0.000000 W/m^2
#  0.000000 W/m^2
#
# w = 4.633917150763915e-11 W/m^2
#
# u = 4.633917150763915e-07 W/unit solid angle
# Calculating radiation intensity distribution over sphere surface...
#
# Frequency = 75000000.0 Hz
# Longueur d'onde lambda = 3.9966980530747898 m
#
# Total Power :  0.015044
# Gain Linear :  3.811531
# Gain Logarithmic :  5.810994 dB
#
# gap_current = [0.01436276-0.00283697j 0.01436275-0.00283698j]
# Radiation Resistance :  70.188343 Ohms
# Data saved successfully to data/antennas_gain_power/array_linear_1_gain_power.mat
# Generating antenna directivity pattern...
# Data loaded from data/antennas_gain_power/array_linear_1_gain_power.mat
