# %%
from utils.frequency_sweep import *
from efield.efield4 import *

# %%
filename_mesh = 'data/antennas_mesh/strip.mat'

# %%
start_frequency = 25e6
stop_frequency = 500e6

LoadPoint = np.array([
    [0.0,  0.50, 0.0],   # point 1
    [0.0, -0.50, 0.0]    # point 2
])

LoadValue = np.array([
    [0.0, 1e64, 100.0],  # LCR pour point 1
    [0.0, 1e64, 100.0]   # LCR pour point 2
])

LoadDir = np.array([
    [0.0, 1.0, 0.0],     # direction pour point 1
    [0.0, 1.0, 0.0]      # direction pour point 2
])

""" LoadPoint = np.array([
    [0.0,  0.0, 0.0]
])

LoadValue = np.array([
    [0.0, 0.0, 500.0],  # LCR pour point 1
])

LoadDir = np.array([
    [0.0, 1.0, 0.0],     # direction pour point 1
]) """

feed_point = np.array([0, 0, 0])

# %%
frequencies = generate_freq_step(start_frequency, stop_frequency)

result_freq_sweep = frequency_sweep(filename_mesh, frequencies, feed_point, load_lumped_elements=True, LoadPoint=LoadPoint, LoadValue=LoadValue, LoadDir=LoadDir)
# Out:
# Simulation 1/238 | f = 25.00 MHz | S11 = -0.01 dB
# Simulation 2/238 | f = 27.00 MHz | S11 = -0.01 dB
# Simulation 3/238 | f = 29.00 MHz | S11 = -0.01 dB
# Simulation 4/238 | f = 31.00 MHz | S11 = -0.02 dB
# Simulation 5/238 | f = 33.00 MHz | S11 = -0.02 dB
# Simulation 6/238 | f = 35.00 MHz | S11 = -0.03 dB
# Simulation 7/238 | f = 37.00 MHz | S11 = -0.05 dB
# Simulation 8/238 | f = 39.00 MHz | S11 = -0.06 dB
# Simulation 9/238 | f = 41.00 MHz | S11 = -0.08 dB
# Simulation 10/238 | f = 43.00 MHz | S11 = -0.11 dB
# Simulation 11/238 | f = 45.00 MHz | S11 = -0.15 dB
# Simulation 12/238 | f = 47.00 MHz | S11 = -0.20 dB
# Simulation 13/238 | f = 49.00 MHz | S11 = -0.27 dB
# Simulation 14/238 | f = 51.00 MHz | S11 = -0.37 dB
# Simulation 15/238 | f = 53.00 MHz | S11 = -0.51 dB
# Simulation 16/238 | f = 55.00 MHz | S11 = -0.71 dB
# Simulation 17/238 | f = 57.00 MHz | S11 = -1.00 dB
# Simulation 18/238 | f = 59.00 MHz | S11 = -1.44 dB
# Simulation 19/238 | f = 61.00 MHz | S11 = -2.13 dB
# Simulation 20/238 | f = 63.00 MHz | S11 = -3.21 dB
# Simulation 21/238 | f = 65.00 MHz | S11 = -4.95 dB
# Simulation 22/238 | f = 67.00 MHz | S11 = -7.79 dB
# Simulation 23/238 | f = 69.00 MHz | S11 = -12.21 dB
# Simulation 24/238 | f = 71.00 MHz | S11 = -14.99 dB
# Simulation 25/238 | f = 73.00 MHz | S11 = -11.21 dB
# Simulation 26/238 | f = 75.00 MHz | S11 = -7.92 dB
# Simulation 27/238 | f = 77.00 MHz | S11 = -5.86 dB
# Simulation 28/238 | f = 79.00 MHz | S11 = -4.54 dB
# Simulation 29/238 | f = 81.00 MHz | S11 = -3.64 dB
# Simulation 30/238 | f = 83.00 MHz | S11 = -3.01 dB
# Simulation 31/238 | f = 85.00 MHz | S11 = -2.56 dB
# Simulation 32/238 | f = 87.00 MHz | S11 = -2.21 dB
# Simulation 33/238 | f = 89.00 MHz | S11 = -1.95 dB
# Simulation 34/238 | f = 91.00 MHz | S11 = -1.74 dB
# Simulation 35/238 | f = 93.00 MHz | S11 = -1.57 dB
# Simulation 36/238 | f = 95.00 MHz | S11 = -1.44 dB
# Simulation 37/238 | f = 97.00 MHz | S11 = -1.33 dB
# Simulation 38/238 | f = 99.00 MHz | S11 = -1.23 dB
# Simulation 39/238 | f = 101.00 MHz | S11 = -1.15 dB
# Simulation 40/238 | f = 103.00 MHz | S11 = -1.08 dB
# Simulation 41/238 | f = 105.00 MHz | S11 = -1.02 dB
# Simulation 42/238 | f = 107.00 MHz | S11 = -0.97 dB
# Simulation 43/238 | f = 109.00 MHz | S11 = -0.93 dB
# Simulation 44/238 | f = 111.00 MHz | S11 = -0.89 dB
# Simulation 45/238 | f = 113.00 MHz | S11 = -0.85 dB
# Simulation 46/238 | f = 115.00 MHz | S11 = -0.82 dB
# Simulation 47/238 | f = 117.00 MHz | S11 = -0.80 dB
# Simulation 48/238 | f = 119.00 MHz | S11 = -0.77 dB
# Simulation 49/238 | f = 121.00 MHz | S11 = -0.75 dB
# Simulation 50/238 | f = 123.00 MHz | S11 = -0.73 dB
# Simulation 51/238 | f = 125.00 MHz | S11 = -0.71 dB
# Simulation 52/238 | f = 127.00 MHz | S11 = -0.69 dB
# Simulation 53/238 | f = 129.00 MHz | S11 = -0.68 dB
# Simulation 54/238 | f = 131.00 MHz | S11 = -0.66 dB
# Simulation 55/238 | f = 133.00 MHz | S11 = -0.65 dB
# Simulation 56/238 | f = 135.00 MHz | S11 = -0.64 dB
# Simulation 57/238 | f = 137.00 MHz | S11 = -0.63 dB
# Simulation 58/238 | f = 139.00 MHz | S11 = -0.62 dB
# Simulation 59/238 | f = 141.00 MHz | S11 = -0.61 dB
# Simulation 60/238 | f = 143.00 MHz | S11 = -0.61 dB
# Simulation 61/238 | f = 145.00 MHz | S11 = -0.60 dB
# Simulation 62/238 | f = 147.00 MHz | S11 = -0.59 dB
# Simulation 63/238 | f = 149.00 MHz | S11 = -0.59 dB
# Simulation 64/238 | f = 151.00 MHz | S11 = -0.59 dB
# Simulation 65/238 | f = 153.00 MHz | S11 = -0.58 dB
# Simulation 66/238 | f = 155.00 MHz | S11 = -0.58 dB
# Simulation 67/238 | f = 157.00 MHz | S11 = -0.58 dB
# Simulation 68/238 | f = 159.00 MHz | S11 = -0.58 dB
# Simulation 69/238 | f = 161.00 MHz | S11 = -0.58 dB
# Simulation 70/238 | f = 163.00 MHz | S11 = -0.58 dB
# Simulation 71/238 | f = 165.00 MHz | S11 = -0.59 dB
# Simulation 72/238 | f = 167.00 MHz | S11 = -0.59 dB
# Simulation 73/238 | f = 169.00 MHz | S11 = -0.60 dB
# Simulation 74/238 | f = 171.00 MHz | S11 = -0.61 dB
# Simulation 75/238 | f = 173.00 MHz | S11 = -0.62 dB
# Simulation 76/238 | f = 175.00 MHz | S11 = -0.64 dB
# Simulation 77/238 | f = 177.00 MHz | S11 = -0.65 dB
# Simulation 78/238 | f = 179.00 MHz | S11 = -0.68 dB
# Simulation 79/238 | f = 181.00 MHz | S11 = -0.70 dB
# Simulation 80/238 | f = 183.00 MHz | S11 = -0.74 dB
# Simulation 81/238 | f = 185.00 MHz | S11 = -0.78 dB
# Simulation 82/238 | f = 187.00 MHz | S11 = -0.83 dB
# Simulation 83/238 | f = 189.00 MHz | S11 = -0.89 dB
# Simulation 84/238 | f = 191.00 MHz | S11 = -0.97 dB
# Simulation 85/238 | f = 193.00 MHz | S11 = -1.07 dB
# Simulation 86/238 | f = 195.00 MHz | S11 = -1.19 dB
# Simulation 87/238 | f = 197.00 MHz | S11 = -1.35 dB
# Simulation 88/238 | f = 199.00 MHz | S11 = -1.55 dB
# Simulation 89/238 | f = 201.00 MHz | S11 = -1.80 dB
# Simulation 90/238 | f = 203.00 MHz | S11 = -2.14 dB
# Simulation 91/238 | f = 205.00 MHz | S11 = -2.57 dB
# Simulation 92/238 | f = 207.00 MHz | S11 = -3.15 dB
# Simulation 93/238 | f = 209.00 MHz | S11 = -3.90 dB
# Simulation 94/238 | f = 211.00 MHz | S11 = -4.86 dB
# Simulation 95/238 | f = 213.00 MHz | S11 = -6.06 dB
# Simulation 96/238 | f = 215.00 MHz | S11 = -7.41 dB
# Simulation 97/238 | f = 217.00 MHz | S11 = -8.64 dB
# Simulation 98/238 | f = 219.00 MHz | S11 = -9.21 dB
# Simulation 99/238 | f = 221.00 MHz | S11 = -8.83 dB
# Simulation 100/238 | f = 223.00 MHz | S11 = -7.84 dB
# Simulation 101/238 | f = 225.00 MHz | S11 = -6.73 dB
# Simulation 102/238 | f = 227.00 MHz | S11 = -5.74 dB
# Simulation 103/238 | f = 229.00 MHz | S11 = -4.91 dB
# Simulation 104/238 | f = 231.00 MHz | S11 = -4.25 dB
# Simulation 105/238 | f = 233.00 MHz | S11 = -3.72 dB
# Simulation 106/238 | f = 235.00 MHz | S11 = -3.30 dB
# Simulation 107/238 | f = 237.00 MHz | S11 = -2.95 dB
# Simulation 108/238 | f = 239.00 MHz | S11 = -2.67 dB
# Simulation 109/238 | f = 241.00 MHz | S11 = -2.44 dB
# Simulation 110/238 | f = 243.00 MHz | S11 = -2.25 dB
# Simulation 111/238 | f = 245.00 MHz | S11 = -2.08 dB
# Simulation 112/238 | f = 247.00 MHz | S11 = -1.95 dB
# Simulation 113/238 | f = 249.00 MHz | S11 = -1.83 dB
# Simulation 114/238 | f = 251.00 MHz | S11 = -1.73 dB
# Simulation 115/238 | f = 253.00 MHz | S11 = -1.64 dB
# Simulation 116/238 | f = 255.00 MHz | S11 = -1.56 dB
# Simulation 117/238 | f = 257.00 MHz | S11 = -1.50 dB
# Simulation 118/238 | f = 259.00 MHz | S11 = -1.44 dB
# Simulation 119/238 | f = 261.00 MHz | S11 = -1.38 dB
# Simulation 120/238 | f = 263.00 MHz | S11 = -1.34 dB
# Simulation 121/238 | f = 265.00 MHz | S11 = -1.29 dB
# Simulation 122/238 | f = 267.00 MHz | S11 = -1.26 dB
# Simulation 123/238 | f = 269.00 MHz | S11 = -1.22 dB
# Simulation 124/238 | f = 271.00 MHz | S11 = -1.19 dB
# Simulation 125/238 | f = 273.00 MHz | S11 = -1.16 dB
# Simulation 126/238 | f = 275.00 MHz | S11 = -1.14 dB
# Simulation 127/238 | f = 277.00 MHz | S11 = -1.12 dB
# Simulation 128/238 | f = 279.00 MHz | S11 = -1.09 dB
# Simulation 129/238 | f = 281.00 MHz | S11 = -1.08 dB
# Simulation 130/238 | f = 283.00 MHz | S11 = -1.06 dB
# Simulation 131/238 | f = 285.00 MHz | S11 = -1.04 dB
# Simulation 132/238 | f = 287.00 MHz | S11 = -1.03 dB
# Simulation 133/238 | f = 289.00 MHz | S11 = -1.02 dB
# Simulation 134/238 | f = 291.00 MHz | S11 = -1.01 dB
# Simulation 135/238 | f = 293.00 MHz | S11 = -1.00 dB
# Simulation 136/238 | f = 295.00 MHz | S11 = -0.99 dB
# Simulation 137/238 | f = 297.00 MHz | S11 = -0.98 dB
# Simulation 138/238 | f = 299.00 MHz | S11 = -0.97 dB
# Simulation 139/238 | f = 301.00 MHz | S11 = -0.97 dB
# Simulation 140/238 | f = 303.00 MHz | S11 = -0.97 dB
# Simulation 141/238 | f = 305.00 MHz | S11 = -0.96 dB
# Simulation 142/238 | f = 307.00 MHz | S11 = -0.96 dB
# Simulation 143/238 | f = 309.00 MHz | S11 = -0.96 dB
# Simulation 144/238 | f = 311.00 MHz | S11 = -0.97 dB
# Simulation 145/238 | f = 313.00 MHz | S11 = -0.97 dB
# Simulation 146/238 | f = 315.00 MHz | S11 = -0.98 dB
# Simulation 147/238 | f = 317.00 MHz | S11 = -0.99 dB
# Simulation 148/238 | f = 319.00 MHz | S11 = -1.00 dB
# Simulation 149/238 | f = 321.00 MHz | S11 = -1.01 dB
# Simulation 150/238 | f = 323.00 MHz | S11 = -1.03 dB
# Simulation 151/238 | f = 325.00 MHz | S11 = -1.05 dB
# Simulation 152/238 | f = 327.00 MHz | S11 = -1.08 dB
# Simulation 153/238 | f = 329.00 MHz | S11 = -1.11 dB
# Simulation 154/238 | f = 331.00 MHz | S11 = -1.15 dB
# Simulation 155/238 | f = 333.00 MHz | S11 = -1.19 dB
# Simulation 156/238 | f = 335.00 MHz | S11 = -1.25 dB
# Simulation 157/238 | f = 337.00 MHz | S11 = -1.32 dB
# Simulation 158/238 | f = 339.00 MHz | S11 = -1.40 dB
# Simulation 159/238 | f = 341.00 MHz | S11 = -1.50 dB
# Simulation 160/238 | f = 343.00 MHz | S11 = -1.62 dB
# Simulation 161/238 | f = 345.00 MHz | S11 = -1.76 dB
# Simulation 162/238 | f = 347.00 MHz | S11 = -1.94 dB
# Simulation 163/238 | f = 349.00 MHz | S11 = -2.16 dB
# Simulation 164/238 | f = 351.00 MHz | S11 = -2.44 dB
# Simulation 165/238 | f = 353.00 MHz | S11 = -2.78 dB
# Simulation 166/238 | f = 355.00 MHz | S11 = -3.20 dB
# Simulation 167/238 | f = 357.00 MHz | S11 = -3.72 dB
# Simulation 168/238 | f = 359.00 MHz | S11 = -4.35 dB
# Simulation 169/238 | f = 361.00 MHz | S11 = -5.09 dB
# Simulation 170/238 | f = 363.00 MHz | S11 = -5.93 dB
# Simulation 171/238 | f = 365.00 MHz | S11 = -6.78 dB
# Simulation 172/238 | f = 367.00 MHz | S11 = -7.51 dB
# Simulation 173/238 | f = 369.00 MHz | S11 = -7.92 dB
# Simulation 174/238 | f = 371.00 MHz | S11 = -7.91 dB
# Simulation 175/238 | f = 373.00 MHz | S11 = -7.50 dB
# Simulation 176/238 | f = 375.00 MHz | S11 = -6.88 dB
# Simulation 177/238 | f = 377.00 MHz | S11 = -6.19 dB
# Simulation 178/238 | f = 379.00 MHz | S11 = -5.53 dB
# Simulation 179/238 | f = 381.00 MHz | S11 = -4.94 dB
# Simulation 180/238 | f = 383.00 MHz | S11 = -4.43 dB
# Simulation 181/238 | f = 385.00 MHz | S11 = -4.00 dB
# Simulation 182/238 | f = 387.00 MHz | S11 = -3.64 dB
# Simulation 183/238 | f = 389.00 MHz | S11 = -3.33 dB
# Simulation 184/238 | f = 391.00 MHz | S11 = -3.07 dB
# Simulation 185/238 | f = 393.00 MHz | S11 = -2.85 dB
# Simulation 186/238 | f = 395.00 MHz | S11 = -2.66 dB
# Simulation 187/238 | f = 397.00 MHz | S11 = -2.50 dB
# Simulation 188/238 | f = 399.00 MHz | S11 = -2.36 dB
# Simulation 189/238 | f = 401.00 MHz | S11 = -2.23 dB
# Simulation 190/238 | f = 403.00 MHz | S11 = -2.13 dB
# Simulation 191/238 | f = 405.00 MHz | S11 = -2.03 dB
# Simulation 192/238 | f = 407.00 MHz | S11 = -1.95 dB
# Simulation 193/238 | f = 409.00 MHz | S11 = -1.88 dB
# Simulation 194/238 | f = 411.00 MHz | S11 = -1.81 dB
# Simulation 195/238 | f = 413.00 MHz | S11 = -1.75 dB
# Simulation 196/238 | f = 415.00 MHz | S11 = -1.70 dB
# Simulation 197/238 | f = 417.00 MHz | S11 = -1.65 dB
# Simulation 198/238 | f = 419.00 MHz | S11 = -1.61 dB
# Simulation 199/238 | f = 421.00 MHz | S11 = -1.57 dB
# Simulation 200/238 | f = 423.00 MHz | S11 = -1.54 dB
# Simulation 201/238 | f = 425.00 MHz | S11 = -1.51 dB
# Simulation 202/238 | f = 427.00 MHz | S11 = -1.48 dB
# Simulation 203/238 | f = 429.00 MHz | S11 = -1.45 dB
# Simulation 204/238 | f = 431.00 MHz | S11 = -1.43 dB
# Simulation 205/238 | f = 433.00 MHz | S11 = -1.41 dB
# Simulation 206/238 | f = 435.00 MHz | S11 = -1.39 dB
# Simulation 207/238 | f = 437.00 MHz | S11 = -1.37 dB
# Simulation 208/238 | f = 439.00 MHz | S11 = -1.35 dB
# Simulation 209/238 | f = 441.00 MHz | S11 = -1.34 dB
# Simulation 210/238 | f = 443.00 MHz | S11 = -1.33 dB
# Simulation 211/238 | f = 445.00 MHz | S11 = -1.31 dB
# Simulation 212/238 | f = 447.00 MHz | S11 = -1.30 dB
# Simulation 213/238 | f = 449.00 MHz | S11 = -1.30 dB
# Simulation 214/238 | f = 451.00 MHz | S11 = -1.29 dB
# Simulation 215/238 | f = 453.00 MHz | S11 = -1.29 dB
# Simulation 216/238 | f = 455.00 MHz | S11 = -1.28 dB
# Simulation 217/238 | f = 457.00 MHz | S11 = -1.28 dB
# Simulation 218/238 | f = 459.00 MHz | S11 = -1.28 dB
# Simulation 219/238 | f = 461.00 MHz | S11 = -1.28 dB
# Simulation 220/238 | f = 463.00 MHz | S11 = -1.29 dB
# Simulation 221/238 | f = 465.00 MHz | S11 = -1.29 dB
# Simulation 222/238 | f = 467.00 MHz | S11 = -1.30 dB
# Simulation 223/238 | f = 469.00 MHz | S11 = -1.31 dB
# Simulation 224/238 | f = 471.00 MHz | S11 = -1.32 dB
# Simulation 225/238 | f = 473.00 MHz | S11 = -1.34 dB
# Simulation 226/238 | f = 475.00 MHz | S11 = -1.36 dB
# Simulation 227/238 | f = 477.00 MHz | S11 = -1.39 dB
# Simulation 228/238 | f = 479.00 MHz | S11 = -1.42 dB
# Simulation 229/238 | f = 481.00 MHz | S11 = -1.46 dB
# Simulation 230/238 | f = 483.00 MHz | S11 = -1.50 dB
# Simulation 231/238 | f = 485.00 MHz | S11 = -1.55 dB
# Simulation 232/238 | f = 487.00 MHz | S11 = -1.61 dB
# Simulation 233/238 | f = 489.00 MHz | S11 = -1.69 dB
# Simulation 234/238 | f = 491.00 MHz | S11 = -1.77 dB
# Simulation 235/238 | f = 493.00 MHz | S11 = -1.88 dB
# Simulation 236/238 | f = 495.00 MHz | S11 = -2.00 dB
# Simulation 237/238 | f = 497.00 MHz | S11 = -2.15 dB
# Simulation 238/238 | f = 499.00 MHz | S11 = -2.33 dB

# %%
frequencies, impedances, s11_db, currents, *_ = load_freq_sweep_data(result_freq_sweep)
# plot_smith_chart(impedances, frequencies)
plot_impedance_curve(impedances, start_frequency, stop_frequency)
plot_s11_curve(s11_db, start_frequency, stop_frequency)
