# %%
from mesh.uniform_mesh.create_antenna import bowtie_gmsh
from utils.gmsh_function import *
from src.scattering_algorithm.scattering_algorithm import *

# %%
def traitement_de_(filename):
    base_name = os.path.splitext(os.path.basename(filename))[0]
    print(f"Traitement de l'antenne {base_name}")

# %%
# Paramètres de l'antenne Bowtie
width = 2   # Largeur totale
hight = 4   # Hauteur totale
width_finite = 20 / 100   # Largeur de la ligne d'alimentation
mesh_size = 0.03
mesh_name = "bowtie_gmsh.msh"
save_mesh_folder = 'data/gmsh_files/'

# %%
bowtie_msh_gmsh = bowtie_gmsh(width, hight, width_finite, mesh_name, save_mesh_folder, mesh_size)
open_mesh(bowtie_msh_gmsh)
# Out:
# bowtie_gmsh.msh saved in data/gmsh_files/bowtie_gmsh.msh successfully

# %%
bowtie_mat_gmsh = 'data/antennas_mesh/bowtie_gmsh.mat'
extract_msh_to_msh(bowtie_msh_gmsh, bowtie_mat_gmsh)
# Out:
# matlab file stored in data/antennas_mesh/bowtie_gmsh.mat successfully

# %%
wave_incident_direction = np.array([0, 0, -1])
polarization=np.array([1, 0, 0])

# %%
traitement_de_(bowtie_mat_gmsh)
print("\n")

start_time = time.time()

scattering_algorithm(bowtie_mat_gmsh, 75e6, wave_incident_direction, polarization, load_from_matlab=True)

elapsed_time = time.time() - start_time
print(f"\nTemps écoulé pour le traitement de l'antenne étudiée : {elapsed_time:.6f} secondes")
print('\n')
# Out:
# Traitement de l'antenne bowtie_gmsh
#
#
# length of antenna bowtie_gmsh = 2.0 meter
# width of antenna bowtie_gmsh = 4.0 meter
# height of antenna bowtie_gmsh = 0.0 meter
#
# Aucune jonction complexe trouvée....
#
# Nombre d'elements de maillage (edges) = 1247
#
# Data saved successfully to data/antennas_mesh1/bowtie_gmsh_mesh1.mat
# Data saved successfully to data/antennas_mesh2/bowtie_gmsh_mesh2.mat
# Temps écoulé pour le calcul de la matrice Z : 4.830157 secondes
# Data saved successfully to data/antennas_impedance/bowtie_gmsh_impedance.mat
# Data loaded from data/antennas_mesh2/bowtie_gmsh_mesh2.mat
# Data loaded from data/antennas_impedance/bowtie_gmsh_impedance.mat
# Temps écoulé pour le calcul du courant : 0.290130 secondes
# Data saved successfully to data/antennas_current/bowtie_gmsh_current.mat
#
# Sauvegarde du fichier : bowtie_gmsh_current.mat effectué avec succès !
#
# Fréquence de l'onde incidente : 75000000.0 Hz
# Max Current value = 0.061783094870462095 [A/m]
#
# ...
