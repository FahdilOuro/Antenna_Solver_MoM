# %%
"Project for EUCap"
# Out:
# 'Project for EUCap'

# %%
from utils.ifa_meander_project_v2.geometry import *
from utils.ifa_meander_project_v2.frequency import *
from utils.ifa_meander_project_v2.algorithms import *

# %%
fLow = 363e6
fHigh = 500e6
fC = 433e6
step = 0.5e6

"""fLow = 373e6
fHigh = 490e6
fC = 433e6
step = 10e6"""

"""fLow = 430e6
fHigh = 436e6
fC = 433e6
step = 1e6"""


frequencies, fc_index, nPoints = generate_frequencies(fLow, fHigh, fC, step)

print(f"Number of frequencies (nPoints): {nPoints}")
print(f"Index of fC: {fc_index}")
# Out:
# Number of frequencies (nPoints): 275
# Index of fC: 140

# %%
mesh_name = "Meander_ifa_optim_433.msh"
save_mesh_folder = 'data/gmsh_files/'
ifa_meander_mat = 'data/antennas_mesh/Meander_ifa_optim_433.mat'
ifa_meander_msh = save_mesh_folder + mesh_name

# %%
terminal_a = 90 / 1000
terminal_b = 60 / 1000  # width of the free space

ratio = 0.42222

a = ratio * terminal_a
b = terminal_b

x_t = np.array([-terminal_a + a, 0, 0, -terminal_a + a])
y_t = np.array([terminal_b, terminal_b, 0, 0])

"""# Fix the short feed and the track width
if b / a > 2:
    largeur_piste    = a / 15          # Minimum value    
    distance_meandre = a / 15          # Value chosen based on the result from analyse_dist_meandre.ipynb
else:
    largeur_piste    = a / 25         # Minimum value    
    distance_meandre = a / 25         # Value chosen based on the result from analyse_dist_meandre.ipynb"""

"""largeur_piste    = a / 12
distance_meandre = a / 12"""

"""largeur_piste    = a / 18
distance_meandre = a / 18"""

largeur_piste    = a / 14
distance_meandre = a / 14

"""largeur_piste = 0.735 / 1000
distance_meandre = largeur_piste"""

feed = 0.88 * b
feed_point = np.array([0, feed, 0])
mesh_size = largeur_piste * 3                # ratio if ratio <= 0.33
# mesh_size = (2.2 + b / a) * largeur_piste  # ratio if ratio > 0.33

# mesh_size = 2.5 / 1000

# Display values
print(f"Terminal a = {terminal_a * 1000:.2f} mm")
print(f"Terminal b = {terminal_b * 1000:.2f} mm")
print(f"ratio = {ratio:.2f}")
print(f"a = {a * 1000:.2f} mm")
print(f"b = {b * 1000:.2f} mm")
print(f"Track width = {largeur_piste * 1000:.2f} mm")
print(f"Meander distance = {distance_meandre * 1000:.2f} mm")
print(f"Feed = {feed * 1000:.2f} mm")
print(f"Mesh size = {mesh_size * 1000:.2f} mm")
# Out:
# Terminal a = 90.00 mm
# Terminal b = 60.00 mm
# ratio = 0.42
# a = 38.00 mm
# b = 60.00 mm
# Track width = 2.71 mm
# Meander distance = 2.71 mm
# Feed = 52.80 mm
# Mesh size = 8.14 mm

# %%
filename_log = f"data/log_optimization/optimization_results_{ratio}.json"

# %%
Z_adapt = 25 # Ohms

# %%
last_impedances = optimize_ifa_input_impedance(ifa_meander_msh, ifa_meander_mat,
             frequencies, fC, fLow, fHigh, nPoints, fc_index,
             a, b, largeur_piste, distance_meandre, feed, feed_point, x_t, y_t, save_mesh_folder, mesh_name, mesh_size, Z0=Z_adapt, filename=filename_log)
# Out:
# ------------------------------------------------------Iteration N°1------------------------------------------------------
#
# distance meanders = 2.714 mm
#
# Number of meanders = 7
#
# New distance meanders = 2.714 mm
# IFA track width = 2.714 mm
# feed position = 52.800 mm
#
# Simulation 1/275 | f = 363.00 MHz | S11 = -0.02 dB
# Simulation 2/275 | f = 363.50 MHz | S11 = -0.02 dB
# Simulation 3/275 | f = 364.00 MHz | S11 = -0.02 dB
# Simulation 4/275 | f = 364.50 MHz | S11 = -0.02 dB
# Simulation 5/275 | f = 365.00 MHz | S11 = -0.02 dB
# Simulation 6/275 | f = 365.50 MHz | S11 = -0.02 dB
# Simulation 7/275 | f = 366.00 MHz | S11 = -0.02 dB
# Simulation 8/275 | f = 366.50 MHz | S11 = -0.02 dB
# Simulation 9/275 | f = 367.00 MHz | S11 = -0.02 dB
# Simulation 10/275 | f = 367.50 MHz | S11 = -0.02 dB
# Simulation 11/275 | f = 368.00 MHz | S11 = -0.02 dB
# Simulation 12/275 | f = 368.50 MHz | S11 = -0.02 dB
# Simulation 13/275 | f = 369.00 MHz | S11 = -0.02 dB
# Simulation 14/275 | f = 369.50 MHz | S11 = -0.02 dB
# Simulation 15/275 | f = 370.00 MHz | S11 = -0.02 dB
# Simulation 16/275 | f = 370.50 MHz | S11 = -0.02 dB
# Simulation 17/275 | f = 371.00 MHz | S11 = -0.02 dB
# Simulation 18/275 | f = 371.50 MHz | S11 = -0.02 dB
# Simulation 19/275 | f = 372.00 MHz | S11 = -0.02 dB
# Simulation 20/275 | f = 372.50 MHz | S11 = -0.02 dB
# Simulation 21/275 | f = 373.00 MHz | S11 = -0.02 dB
# Simulation 22/275 | f = 373.50 MHz | S11 = -0.02 dB
# Simulation 23/275 | f = 374.00 MHz | S11 = -0.02 dB
# Simulation 24/275 | f = 374.50 MHz | S11 = -0.02 dB
# Simulation 25/275 | f = 375.00 MHz | S11 = -0.02 dB
# Simulation 26/275 | f = 375.50 MHz | S11 = -0.02 dB
# Simulation 27/275 | f = 376.00 MHz | S11 = -0.03 dB
# Simulation 28/275 | f = 376.50 MHz | S11 = -0.03 dB
# Simulation 29/275 | f = 377.00 MHz | S11 = -0.03 dB
# Simulation 30/275 | f = 377.50 MHz | S11 = -0.03 dB
# Simulation 31/275 | f = 378.00 MHz | S11 = -0.03 dB
# Simulation 32/275 | f = 378.50 MHz | S11 = -0.03 dB
# Simulation 33/275 | f = 379.00 MHz | S11 = -0.03 dB
# Simulation 34/275 | f = 379.50 MHz | S11 = -0.03 dB
# Simulation 35/275 | f = 380.00 MHz | S11 = -0.03 dB
# Simulation 36/275 | f = 380.50 MHz | S11 = -0.03 dB
# Simulation 37/275 | f = 381.00 MHz | S11 = -0.03 dB
# Simulation 38/275 | f = 381.50 MHz | S11 = -0.03 dB
# Simulation 39/275 | f = 382.00 MHz | S11 = -0.03 dB
# Simulation 40/275 | f = 382.50 MHz | S11 = -0.03 dB
# Simulation 41/275 | f = 383.00 MHz | S11 = -0.03 dB
# Simulation 42/275 | f = 383.50 MHz | S11 = -0.04 dB
# Simulation 43/275 | f = 384.00 MHz | S11 = -0.04 dB
# Simulation 44/275 | f = 384.50 MHz | S11 = -0.04 dB
# Simulation 45/275 | f = 385.00 MHz | S11 = -0.04 dB
# Simulation 46/275 | f = 385.50 MHz | S11 = -0.04 dB
# Simulation 47/275 | f = 386.00 MHz | S11 = -0.04 dB
# Simulation 48/275 | f = 386.50 MHz | S11 = -0.04 dB
# Simulation 49/275 | f = 387.00 MHz | S11 = -0.04 dB
# Simulation 50/275 | f = 387.50 MHz | S11 = -0.04 dB
# Simulation 51/275 | f = 388.00 MHz | S11 = -0.04 dB
# Simulation 52/275 | f = 388.50 MHz | S11 = -0.05 dB
# Simulation 53/275 | f = 389.00 MHz | S11 = -0.05 dB
# Simulation 54/275 | f = 389.50 MHz | S11 = -0.05 dB
# Simulation 55/275 | f = 390.00 MHz | S11 = -0.05 dB
# Simulation 56/275 | f = 390.50 MHz | S11 = -0.05 dB
# Simulation 57/275 | f = 391.00 MHz | S11 = -0.05 dB
# Simulation 58/275 | f = 391.50 MHz | S11 = -0.05 dB
# Simulation 59/275 | f = 392.00 MHz | S11 = -0.05 dB
# Simulation 60/275 | f = 392.50 MHz | S11 = -0.06 dB
# Simulation 61/275 | f = 393.00 MHz | S11 = -0.06 dB
# Simulation 62/275 | f = 393.50 MHz | S11 = -0.06 dB
# Simulation 63/275 | f = 394.00 MHz | S11 = -0.06 dB
# Simulation 64/275 | f = 394.50 MHz | S11 = -0.06 dB
# Simulation 65/275 | f = 395.00 MHz | S11 = -0.06 dB
# Simulation 66/275 | f = 395.50 MHz | S11 = -0.07 dB
# Simulation 67/275 | f = 396.00 MHz | S11 = -0.07 dB
# Simulation 68/275 | f = 396.50 MHz | S11 = -0.07 dB
# Simulation 69/275 | f = 397.00 MHz | S11 = -0.07 dB
# Simulation 70/275 | f = 397.50 MHz | S11 = -0.07 dB
# Simulation 71/275 | f = 398.00 MHz | S11 = -0.08 dB
# Simulation 72/275 | f = 398.50 MHz | S11 = -0.08 dB
# Simulation 73/275 | f = 399.00 MHz | S11 = -0.08 dB
# Simulation 74/275 | f = 399.50 MHz | S11 = -0.08 dB
# Simulation 75/275 | f = 400.00 MHz | S11 = -0.09 dB
# Simulation 76/275 | f = 400.50 MHz | S11 = -0.09 dB
# Simulation 77/275 | f = 401.00 MHz | S11 = -0.09 dB
# Simulation 78/275 | f = 401.50 MHz | S11 = -0.09 dB
# Simulation 79/275 | f = 402.00 MHz | S11 = -0.10 dB
# Simulation 80/275 | f = 402.50 MHz | S11 = -0.10 dB
# Simulation 81/275 | f = 403.00 MHz | S11 = -0.10 dB
# Simulation 82/275 | f = 403.50 MHz | S11 = -0.11 dB
# Simulation 83/275 | f = 404.00 MHz | S11 = -0.11 dB
# Simulation 84/275 | f = 404.50 MHz | S11 = -0.12 dB
# Simulation 85/275 | f = 405.00 MHz | S11 = -0.12 dB
# Simulation 86/275 | f = 405.50 MHz | S11 = -0.12 dB
# Simulation 87/275 | f = 406.00 MHz | S11 = -0.13 dB
# Simulation 88/275 | f = 406.50 MHz | S11 = -0.13 dB
# Simulation 89/275 | f = 407.00 MHz | S11 = -0.14 dB
# Simulation 90/275 | f = 407.50 MHz | S11 = -0.14 dB
# Simulation 91/275 | f = 408.00 MHz | S11 = -0.15 dB
# Simulation 92/275 | f = 408.50 MHz | S11 = -0.15 dB
# Simulation 93/275 | f = 409.00 MHz | S11 = -0.16 dB
# Simulation 94/275 | f = 409.50 MHz | S11 = -0.17 dB
# Simulation 95/275 | f = 410.00 MHz | S11 = -0.17 dB
# Simulation 96/275 | f = 410.50 MHz | S11 = -0.18 dB
# Simulation 97/275 | f = 411.00 MHz | S11 = -0.19 dB
# Simulation 98/275 | f = 411.50 MHz | S11 = -0.20 dB
# Simulation 99/275 | f = 412.00 MHz | S11 = -0.21 dB
# Simulation 100/275 | f = 412.50 MHz | S11 = -0.21 dB
# Simulation 101/275 | f = 413.00 MHz | S11 = -0.22 dB
# Simulation 102/275 | f = 413.50 MHz | S11 = -0.23 dB
# Simulation 103/275 | f = 414.00 MHz | S11 = -0.25 dB
# Simulation 104/275 | f = 414.50 MHz | S11 = -0.26 dB
# Simulation 105/275 | f = 415.00 MHz | S11 = -0.27 dB
# Simulation 106/275 | f = 415.50 MHz | S11 = -0.28 dB
# Simulation 107/275 | f = 416.00 MHz | S11 = -0.30 dB
# Simulation 108/275 | f = 416.50 MHz | S11 = -0.31 dB
# Simulation 109/275 | f = 417.00 MHz | S11 = -0.33 dB
# Simulation 110/275 | f = 417.50 MHz | S11 = -0.35 dB
# Simulation 111/275 | f = 418.00 MHz | S11 = -0.36 dB
# Simulation 112/275 | f = 418.50 MHz | S11 = -0.39 dB
# Simulation 113/275 | f = 419.00 MHz | S11 = -0.41 dB
# Simulation 114/275 | f = 419.50 MHz | S11 = -0.43 dB
# Simulation 115/275 | f = 420.00 MHz | S11 = -0.46 dB
# Simulation 116/275 | f = 420.50 MHz | S11 = -0.49 dB
# Simulation 117/275 | f = 421.00 MHz | S11 = -0.52 dB
# Simulation 118/275 | f = 421.50 MHz | S11 = -0.55 dB
# Simulation 119/275 | f = 422.00 MHz | S11 = -0.59 dB
# Simulation 120/275 | f = 422.50 MHz | S11 = -0.63 dB
# Simulation 121/275 | f = 423.00 MHz | S11 = -0.67 dB
# Simulation 122/275 | f = 423.50 MHz | S11 = -0.72 dB
# Simulation 123/275 | f = 424.00 MHz | S11 = -0.77 dB
# Simulation 124/275 | f = 424.50 MHz | S11 = -0.83 dB
# Simulation 125/275 | f = 425.00 MHz | S11 = -0.90 dB
# Simulation 126/275 | f = 425.50 MHz | S11 = -0.97 dB
# Simulation 127/275 | f = 426.00 MHz | S11 = -1.05 dB
# Simulation 128/275 | f = 426.50 MHz | S11 = -1.14 dB
# Simulation 129/275 | f = 427.00 MHz | S11 = -1.25 dB
# Simulation 130/275 | f = 427.50 MHz | S11 = -1.36 dB
# Simulation 131/275 | f = 428.00 MHz | S11 = -1.50 dB
# Simulation 132/275 | f = 428.50 MHz | S11 = -1.65 dB
# Simulation 133/275 | f = 429.00 MHz | S11 = -1.82 dB
# Simulation 134/275 | f = 429.50 MHz | S11 = -2.02 dB
# Simulation 135/275 | f = 430.00 MHz | S11 = -2.25 dB
# Simulation 136/275 | f = 430.50 MHz | S11 = -2.52 dB
# Simulation 137/275 | f = 431.00 MHz | S11 = -2.83 dB
# Simulation 138/275 | f = 431.50 MHz | S11 = -3.20 dB
# Simulation 139/275 | f = 432.00 MHz | S11 = -3.64 dB
# Simulation 140/275 | f = 432.50 MHz | S11 = -4.16 dB
# Simulation 141/275 | f = 433.00 MHz | S11 = -4.78 dB
# Simulation 142/275 | f = 433.50 MHz | S11 = -5.54 dB
# Simulation 143/275 | f = 434.00 MHz | S11 = -6.46 dB
# Simulation 144/275 | f = 434.50 MHz | S11 = -7.60 dB
# Simulation 145/275 | f = 435.00 MHz | S11 = -9.03 dB
# Simulation 146/275 | f = 435.50 MHz | S11 = -10.87 dB
# Simulation 147/275 | f = 436.00 MHz | S11 = -13.28 dB
# Simulation 148/275 | f = 436.50 MHz | S11 = -16.48 dB
# Simulation 149/275 | f = 437.00 MHz | S11 = -19.94 dB
# Simulation 150/275 | f = 437.50 MHz | S11 = -19.73 dB
# Simulation 151/275 | f = 438.00 MHz | S11 = -16.22 dB
# Simulation 152/275 | f = 438.50 MHz | S11 = -13.13 dB
# Simulation 153/275 | f = 439.00 MHz | S11 = -10.80 dB
# Simulation 154/275 | f = 439.50 MHz | S11 = -9.03 dB
# Simulation 155/275 | f = 440.00 MHz | S11 = -7.64 dB
# Simulation 156/275 | f = 440.50 MHz | S11 = -6.54 dB
# Simulation 157/275 | f = 441.00 MHz | S11 = -5.65 dB
# Simulation 158/275 | f = 441.50 MHz | S11 = -4.91 dB
# Simulation 159/275 | f = 442.00 MHz | S11 = -4.30 dB
# Simulation 160/275 | f = 442.50 MHz | S11 = -3.80 dB
# Simulation 161/275 | f = 443.00 MHz | S11 = -3.37 dB
# Simulation 162/275 | f = 443.50 MHz | S11 = -3.01 dB
# Simulation 163/275 | f = 444.00 MHz | S11 = -2.69 dB
# Simulation 164/275 | f = 444.50 MHz | S11 = -2.43 dB
# Simulation 165/275 | f = 445.00 MHz | S11 = -2.20 dB
# Simulation 166/275 | f = 445.50 MHz | S11 = -2.00 dB
# Simulation 167/275 | f = 446.00 MHz | S11 = -1.82 dB
# Simulation 168/275 | f = 446.50 MHz | S11 = -1.67 dB
# Simulation 169/275 | f = 447.00 MHz | S11 = -1.53 dB
# Simulation 170/275 | f = 447.50 MHz | S11 = -1.41 dB
# Simulation 171/275 | f = 448.00 MHz | S11 = -1.31 dB
# Simulation 172/275 | f = 448.50 MHz | S11 = -1.21 dB
# Simulation 173/275 | f = 449.00 MHz | S11 = -1.13 dB
# Simulation 174/275 | f = 449.50 MHz | S11 = -1.05 dB
# Simulation 175/275 | f = 450.00 MHz | S11 = -0.98 dB
# Simulation 176/275 | f = 450.50 MHz | S11 = -0.92 dB
# Simulation 177/275 | f = 451.00 MHz | S11 = -0.86 dB
# Simulation 178/275 | f = 451.50 MHz | S11 = -0.81 dB
# Simulation 179/275 | f = 452.00 MHz | S11 = -0.76 dB
# Simulation 180/275 | f = 452.50 MHz | S11 = -0.72 dB
# Simulation 181/275 | f = 453.00 MHz | S11 = -0.68 dB
# Simulation 182/275 | f = 453.50 MHz | S11 = -0.65 dB
# Simulation 183/275 | f = 454.00 MHz | S11 = -0.61 dB
# Simulation 184/275 | f = 454.50 MHz | S11 = -0.58 dB
# Simulation 185/275 | f = 455.00 MHz | S11 = -0.55 dB
# Simulation 186/275 | f = 455.50 MHz | S11 = -0.53 dB
# Simulation 187/275 | f = 456.00 MHz | S11 = -0.50 dB
# Simulation 188/275 | f = 456.50 MHz | S11 = -0.48 dB
# Simulation 189/275 | f = 457.00 MHz | S11 = -0.46 dB
# Simulation 190/275 | f = 457.50 MHz | S11 = -0.44 dB
# Simulation 191/275 | f = 458.00 MHz | S11 = -0.42 dB
# Simulation 192/275 | f = 458.50 MHz | S11 = -0.40 dB
# Simulation 193/275 | f = 459.00 MHz | S11 = -0.39 dB
# Simulation 194/275 | f = 459.50 MHz | S11 = -0.37 dB
# Simulation 195/275 | f = 460.00 MHz | S11 = -0.36 dB
# Simulation 196/275 | f = 460.50 MHz | S11 = -0.34 dB
# Simulation 197/275 | f = 461.00 MHz | S11 = -0.33 dB
# Simulation 198/275 | f = 461.50 MHz | S11 = -0.32 dB
# Simulation 199/275 | f = 462.00 MHz | S11 = -0.31 dB
# Simulation 200/275 | f = 462.50 MHz | S11 = -0.30 dB
# Simulation 201/275 | f = 463.00 MHz | S11 = -0.29 dB
# Simulation 202/275 | f = 463.50 MHz | S11 = -0.28 dB
# Simulation 203/275 | f = 464.00 MHz | S11 = -0.27 dB
# Simulation 204/275 | f = 464.50 MHz | S11 = -0.26 dB
# Simulation 205/275 | f = 465.00 MHz | S11 = -0.25 dB
# Simulation 206/275 | f = 465.50 MHz | S11 = -0.24 dB
# Simulation 207/275 | f = 466.00 MHz | S11 = -0.24 dB
# Simulation 208/275 | f = 466.50 MHz | S11 = -0.23 dB
# Simulation 209/275 | f = 467.00 MHz | S11 = -0.22 dB
# Simulation 210/275 | f = 467.50 MHz | S11 = -0.22 dB
# Simulation 211/275 | f = 468.00 MHz | S11 = -0.21 dB
# Simulation 212/275 | f = 468.50 MHz | S11 = -0.20 dB
# Simulation 213/275 | f = 469.00 MHz | S11 = -0.20 dB
# Simulation 214/275 | f = 469.50 MHz | S11 = -0.19 dB
# Simulation 215/275 | f = 470.00 MHz | S11 = -0.19 dB
# Simulation 216/275 | f = 470.50 MHz | S11 = -0.18 dB
# Simulation 217/275 | f = 471.00 MHz | S11 = -0.18 dB
# Simulation 218/275 | f = 471.50 MHz | S11 = -0.17 dB
# Simulation 219/275 | f = 472.00 MHz | S11 = -0.17 dB
# Simulation 220/275 | f = 472.50 MHz | S11 = -0.16 dB
# Simulation 221/275 | f = 473.00 MHz | S11 = -0.16 dB
# Simulation 222/275 | f = 473.50 MHz | S11 = -0.16 dB
# Simulation 223/275 | f = 474.00 MHz | S11 = -0.15 dB
# Simulation 224/275 | f = 474.50 MHz | S11 = -0.15 dB
# Simulation 225/275 | f = 475.00 MHz | S11 = -0.15 dB
# Simulation 226/275 | f = 475.50 MHz | S11 = -0.14 dB
# Simulation 227/275 | f = 476.00 MHz | S11 = -0.14 dB
# Simulation 228/275 | f = 476.50 MHz | S11 = -0.14 dB
# Simulation 229/275 | f = 477.00 MHz | S11 = -0.13 dB
# Simulation 230/275 | f = 477.50 MHz | S11 = -0.13 dB
# Simulation 231/275 | f = 478.00 MHz | S11 = -0.13 dB
# Simulation 232/275 | f = 478.50 MHz | S11 = -0.13 dB
# Simulation 233/275 | f = 479.00 MHz | S11 = -0.12 dB
# Simulation 234/275 | f = 479.50 MHz | S11 = -0.12 dB
# Simulation 235/275 | f = 480.00 MHz | S11 = -0.12 dB
# Simulation 236/275 | f = 480.50 MHz | S11 = -0.12 dB
# Simulation 237/275 | f = 481.00 MHz | S11 = -0.11 dB
# Simulation 238/275 | f = 481.50 MHz | S11 = -0.11 dB
# Simulation 239/275 | f = 482.00 MHz | S11 = -0.11 dB
# Simulation 240/275 | f = 482.50 MHz | S11 = -0.11 dB
# Simulation 241/275 | f = 483.00 MHz | S11 = -0.10 dB
# Simulation 242/275 | f = 483.50 MHz | S11 = -0.10 dB
# Simulation 243/275 | f = 484.00 MHz | S11 = -0.10 dB
# Simulation 244/275 | f = 484.50 MHz | S11 = -0.10 dB
# Simulation 245/275 | f = 485.00 MHz | S11 = -0.10 dB
# Simulation 246/275 | f = 485.50 MHz | S11 = -0.10 dB
# Simulation 247/275 | f = 486.00 MHz | S11 = -0.09 dB
# Simulation 248/275 | f = 486.50 MHz | S11 = -0.09 dB
# Simulation 249/275 | f = 487.00 MHz | S11 = -0.09 dB
# Simulation 250/275 | f = 487.50 MHz | S11 = -0.09 dB
# Simulation 251/275 | f = 488.00 MHz | S11 = -0.09 dB
# Simulation 252/275 | f = 488.50 MHz | S11 = -0.09 dB
# Simulation 253/275 | f = 489.00 MHz | S11 = -0.08 dB
# Simulation 254/275 | f = 489.50 MHz | S11 = -0.08 dB
# Simulation 255/275 | f = 490.00 MHz | S11 = -0.08 dB
# Simulation 256/275 | f = 490.50 MHz | S11 = -0.08 dB
# Simulation 257/275 | f = 491.00 MHz | S11 = -0.08 dB
# Simulation 258/275 | f = 491.50 MHz | S11 = -0.08 dB
# Simulation 259/275 | f = 492.00 MHz | S11 = -0.08 dB
# Simulation 260/275 | f = 492.50 MHz | S11 = -0.08 dB
# Simulation 261/275 | f = 493.00 MHz | S11 = -0.07 dB
# Simulation 262/275 | f = 493.50 MHz | S11 = -0.07 dB
# Simulation 263/275 | f = 494.00 MHz | S11 = -0.07 dB
# Simulation 264/275 | f = 494.50 MHz | S11 = -0.07 dB
# Simulation 265/275 | f = 495.00 MHz | S11 = -0.07 dB
# Simulation 266/275 | f = 495.50 MHz | S11 = -0.07 dB
# Simulation 267/275 | f = 496.00 MHz | S11 = -0.07 dB
# Simulation 268/275 | f = 496.50 MHz | S11 = -0.07 dB
# Simulation 269/275 | f = 497.00 MHz | S11 = -0.07 dB
# Simulation 270/275 | f = 497.50 MHz | S11 = -0.07 dB
# Simulation 271/275 | f = 498.00 MHz | S11 = -0.06 dB
# Simulation 272/275 | f = 498.50 MHz | S11 = -0.06 dB
# Simulation 273/275 | f = 499.00 MHz | S11 = -0.06 dB
# Simulation 274/275 | f = 499.50 MHz | S11 = -0.06 dB
# Simulation 275/275 | f = 500.00 MHz | S11 = -0.06 dB
# 📡 Simulation results:
# → Resonance frequency = 437.00 MHz
# → Impedance at f_res  = 24.98+5.06j Ω
# frequency resonance / S11 min = 437.00 MHz / -19.94 dB
# s
# --- Input Impedance at resonance ---
# R_res = 24.98 Ohm
# X_res = 5.06 Ohm
# --- Input Impedance at resonance ---
# Ratio = 1.0092378752886837
#
#
# Looking for matching!!!
#
# feed result = 53.429 mm
#
# ------------------------------------------------------Iteration N°2------------------------------------------------------
#
# distance meanders = 2.665 mm
#
# Number of meanders = 7
#
# New distance meanders = 2.764 mm
# IFA track width = 2.665 mm
# feed position = 53.429 mm
#
# Simulation 1/275 | f = 363.00 MHz | S11 = -0.02 dB
# Simulation 2/275 | f = 363.50 MHz | S11 = -0.02 dB
# Simulation 3/275 | f = 364.00 MHz | S11 = -0.02 dB
# Simulation 4/275 | f = 364.50 MHz | S11 = -0.02 dB
# Simulation 5/275 | f = 365.00 MHz | S11 = -0.02 dB
# Simulation 6/275 | f = 365.50 MHz | S11 = -0.02 dB
# Simulation 7/275 | f = 366.00 MHz | S11 = -0.02 dB
# Simulation 8/275 | f = 366.50 MHz | S11 = -0.02 dB
# Simulation 9/275 | f = 367.00 MHz | S11 = -0.02 dB
# Simulation 10/275 | f = 367.50 MHz | S11 = -0.02 dB
# Simulation 11/275 | f = 368.00 MHz | S11 = -0.02 dB
# Simulation 12/275 | f = 368.50 MHz | S11 = -0.02 dB
# Simulation 13/275 | f = 369.00 MHz | S11 = -0.02 dB
# Simulation 14/275 | f = 369.50 MHz | S11 = -0.02 dB
# Simulation 15/275 | f = 370.00 MHz | S11 = -0.02 dB
# Simulation 16/275 | f = 370.50 MHz | S11 = -0.02 dB
# Simulation 17/275 | f = 371.00 MHz | S11 = -0.02 dB
# Simulation 18/275 | f = 371.50 MHz | S11 = -0.02 dB
# Simulation 19/275 | f = 372.00 MHz | S11 = -0.02 dB
# Simulation 20/275 | f = 372.50 MHz | S11 = -0.02 dB
# Simulation 21/275 | f = 373.00 MHz | S11 = -0.02 dB
# Simulation 22/275 | f = 373.50 MHz | S11 = -0.02 dB
# Simulation 23/275 | f = 374.00 MHz | S11 = -0.02 dB
# Simulation 24/275 | f = 374.50 MHz | S11 = -0.02 dB
# Simulation 25/275 | f = 375.00 MHz | S11 = -0.02 dB
# Simulation 26/275 | f = 375.50 MHz | S11 = -0.03 dB
# Simulation 27/275 | f = 376.00 MHz | S11 = -0.03 dB
# Simulation 28/275 | f = 376.50 MHz | S11 = -0.03 dB
# Simulation 29/275 | f = 377.00 MHz | S11 = -0.03 dB
# Simulation 30/275 | f = 377.50 MHz | S11 = -0.03 dB
# Simulation 31/275 | f = 378.00 MHz | S11 = -0.03 dB
# Simulation 32/275 | f = 378.50 MHz | S11 = -0.03 dB
# Simulation 33/275 | f = 379.00 MHz | S11 = -0.03 dB
# Simulation 34/275 | f = 379.50 MHz | S11 = -0.03 dB
# Simulation 35/275 | f = 380.00 MHz | S11 = -0.03 dB
# Simulation 36/275 | f = 380.50 MHz | S11 = -0.03 dB
# Simulation 37/275 | f = 381.00 MHz | S11 = -0.03 dB
# Simulation 38/275 | f = 381.50 MHz | S11 = -0.03 dB
# Simulation 39/275 | f = 382.00 MHz | S11 = -0.03 dB
# Simulation 40/275 | f = 382.50 MHz | S11 = -0.03 dB
# Simulation 41/275 | f = 383.00 MHz | S11 = -0.04 dB
# Simulation 42/275 | f = 383.50 MHz | S11 = -0.04 dB
# Simulation 43/275 | f = 384.00 MHz | S11 = -0.04 dB
# Simulation 44/275 | f = 384.50 MHz | S11 = -0.04 dB
# Simulation 45/275 | f = 385.00 MHz | S11 = -0.04 dB
# Simulation 46/275 | f = 385.50 MHz | S11 = -0.04 dB
# Simulation 47/275 | f = 386.00 MHz | S11 = -0.04 dB
# Simulation 48/275 | f = 386.50 MHz | S11 = -0.04 dB
# Simulation 49/275 | f = 387.00 MHz | S11 = -0.04 dB
# Simulation 50/275 | f = 387.50 MHz | S11 = -0.04 dB
# Simulation 51/275 | f = 388.00 MHz | S11 = -0.05 dB
# Simulation 52/275 | f = 388.50 MHz | S11 = -0.05 dB
# Simulation 53/275 | f = 389.00 MHz | S11 = -0.05 dB
# Simulation 54/275 | f = 389.50 MHz | S11 = -0.05 dB
# Simulation 55/275 | f = 390.00 MHz | S11 = -0.05 dB
# Simulation 56/275 | f = 390.50 MHz | S11 = -0.05 dB
# Simulation 57/275 | f = 391.00 MHz | S11 = -0.05 dB
# Simulation 58/275 | f = 391.50 MHz | S11 = -0.05 dB
# Simulation 59/275 | f = 392.00 MHz | S11 = -0.06 dB
# Simulation 60/275 | f = 392.50 MHz | S11 = -0.06 dB
# Simulation 61/275 | f = 393.00 MHz | S11 = -0.06 dB
# Simulation 62/275 | f = 393.50 MHz | S11 = -0.06 dB
# Simulation 63/275 | f = 394.00 MHz | S11 = -0.06 dB
# Simulation 64/275 | f = 394.50 MHz | S11 = -0.06 dB
# Simulation 65/275 | f = 395.00 MHz | S11 = -0.07 dB
# Simulation 66/275 | f = 395.50 MHz | S11 = -0.07 dB
# Simulation 67/275 | f = 396.00 MHz | S11 = -0.07 dB
# Simulation 68/275 | f = 396.50 MHz | S11 = -0.07 dB
# Simulation 69/275 | f = 397.00 MHz | S11 = -0.07 dB
# Simulation 70/275 | f = 397.50 MHz | S11 = -0.08 dB
# Simulation 71/275 | f = 398.00 MHz | S11 = -0.08 dB
# Simulation 72/275 | f = 398.50 MHz | S11 = -0.08 dB
# Simulation 73/275 | f = 399.00 MHz | S11 = -0.08 dB
# Simulation 74/275 | f = 399.50 MHz | S11 = -0.09 dB
# Simulation 75/275 | f = 400.00 MHz | S11 = -0.09 dB
# Simulation 76/275 | f = 400.50 MHz | S11 = -0.09 dB
# Simulation 77/275 | f = 401.00 MHz | S11 = -0.10 dB
# Simulation 78/275 | f = 401.50 MHz | S11 = -0.10 dB
# Simulation 79/275 | f = 402.00 MHz | S11 = -0.10 dB
# Simulation 80/275 | f = 402.50 MHz | S11 = -0.11 dB
# Simulation 81/275 | f = 403.00 MHz | S11 = -0.11 dB
# Simulation 82/275 | f = 403.50 MHz | S11 = -0.11 dB
# Simulation 83/275 | f = 404.00 MHz | S11 = -0.12 dB
# Simulation 84/275 | f = 404.50 MHz | S11 = -0.12 dB
# Simulation 85/275 | f = 405.00 MHz | S11 = -0.13 dB
# Simulation 86/275 | f = 405.50 MHz | S11 = -0.13 dB
# Simulation 87/275 | f = 406.00 MHz | S11 = -0.14 dB
# Simulation 88/275 | f = 406.50 MHz | S11 = -0.14 dB
# Simulation 89/275 | f = 407.00 MHz | S11 = -0.15 dB
# Simulation 90/275 | f = 407.50 MHz | S11 = -0.16 dB
# Simulation 91/275 | f = 408.00 MHz | S11 = -0.16 dB
# Simulation 92/275 | f = 408.50 MHz | S11 = -0.17 dB
# Simulation 93/275 | f = 409.00 MHz | S11 = -0.18 dB
# Simulation 94/275 | f = 409.50 MHz | S11 = -0.18 dB
# Simulation 95/275 | f = 410.00 MHz | S11 = -0.19 dB
# Simulation 96/275 | f = 410.50 MHz | S11 = -0.20 dB
# Simulation 97/275 | f = 411.00 MHz | S11 = -0.21 dB
# Simulation 98/275 | f = 411.50 MHz | S11 = -0.22 dB
# Simulation 99/275 | f = 412.00 MHz | S11 = -0.23 dB
# Simulation 100/275 | f = 412.50 MHz | S11 = -0.24 dB
# Simulation 101/275 | f = 413.00 MHz | S11 = -0.25 dB
# Simulation 102/275 | f = 413.50 MHz | S11 = -0.26 dB
# Simulation 103/275 | f = 414.00 MHz | S11 = -0.28 dB
# Simulation 104/275 | f = 414.50 MHz | S11 = -0.29 dB
# Simulation 105/275 | f = 415.00 MHz | S11 = -0.31 dB
# Simulation 106/275 | f = 415.50 MHz | S11 = -0.32 dB
# Simulation 107/275 | f = 416.00 MHz | S11 = -0.34 dB
# Simulation 108/275 | f = 416.50 MHz | S11 = -0.36 dB
# Simulation 109/275 | f = 417.00 MHz | S11 = -0.38 dB
# Simulation 110/275 | f = 417.50 MHz | S11 = -0.40 dB
# Simulation 111/275 | f = 418.00 MHz | S11 = -0.43 dB
# Simulation 112/275 | f = 418.50 MHz | S11 = -0.45 dB
# Simulation 113/275 | f = 419.00 MHz | S11 = -0.48 dB
# Simulation 114/275 | f = 419.50 MHz | S11 = -0.51 dB
# Simulation 115/275 | f = 420.00 MHz | S11 = -0.55 dB
# Simulation 116/275 | f = 420.50 MHz | S11 = -0.58 dB
# Simulation 117/275 | f = 421.00 MHz | S11 = -0.63 dB
# Simulation 118/275 | f = 421.50 MHz | S11 = -0.67 dB
# Simulation 119/275 | f = 422.00 MHz | S11 = -0.72 dB
# Simulation 120/275 | f = 422.50 MHz | S11 = -0.78 dB
# Simulation 121/275 | f = 423.00 MHz | S11 = -0.84 dB
# Simulation 122/275 | f = 423.50 MHz | S11 = -0.91 dB
# Simulation 123/275 | f = 424.00 MHz | S11 = -0.99 dB
# Simulation 124/275 | f = 424.50 MHz | S11 = -1.07 dB
# Simulation 125/275 | f = 425.00 MHz | S11 = -1.17 dB
# Simulation 126/275 | f = 425.50 MHz | S11 = -1.28 dB
# Simulation 127/275 | f = 426.00 MHz | S11 = -1.41 dB
# Simulation 128/275 | f = 426.50 MHz | S11 = -1.55 dB
# Simulation 129/275 | f = 427.00 MHz | S11 = -1.72 dB
# Simulation 130/275 | f = 427.50 MHz | S11 = -1.91 dB
# Simulation 131/275 | f = 428.00 MHz | S11 = -2.13 dB
# Simulation 132/275 | f = 428.50 MHz | S11 = -2.39 dB
# Simulation 133/275 | f = 429.00 MHz | S11 = -2.69 dB
# Simulation 134/275 | f = 429.50 MHz | S11 = -3.05 dB
# Simulation 135/275 | f = 430.00 MHz | S11 = -3.47 dB
# Simulation 136/275 | f = 430.50 MHz | S11 = -3.97 dB
# Simulation 137/275 | f = 431.00 MHz | S11 = -4.58 dB
# Simulation 138/275 | f = 431.50 MHz | S11 = -5.32 dB
# Simulation 139/275 | f = 432.00 MHz | S11 = -6.22 dB
# Simulation 140/275 | f = 432.50 MHz | S11 = -7.34 dB
# Simulation 141/275 | f = 433.00 MHz | S11 = -8.75 dB
# Simulation 142/275 | f = 433.50 MHz | S11 = -10.54 dB
# Simulation 143/275 | f = 434.00 MHz | S11 = -12.86 dB
# Simulation 144/275 | f = 434.50 MHz | S11 = -15.81 dB
# Simulation 145/275 | f = 435.00 MHz | S11 = -18.64 dB
# Simulation 146/275 | f = 435.50 MHz | S11 = -18.27 dB
# Simulation 147/275 | f = 436.00 MHz | S11 = -15.29 dB
# Simulation 148/275 | f = 436.50 MHz | S11 = -12.48 dB
# Simulation 149/275 | f = 437.00 MHz | S11 = -10.29 dB
# Simulation 150/275 | f = 437.50 MHz | S11 = -8.60 dB
# Simulation 151/275 | f = 438.00 MHz | S11 = -7.27 dB
# Simulation 152/275 | f = 438.50 MHz | S11 = -6.21 dB
# Simulation 153/275 | f = 439.00 MHz | S11 = -5.35 dB
# Simulation 154/275 | f = 439.50 MHz | S11 = -4.65 dB
# Simulation 155/275 | f = 440.00 MHz | S11 = -4.07 dB
# Simulation 156/275 | f = 440.50 MHz | S11 = -3.58 dB
# Simulation 157/275 | f = 441.00 MHz | S11 = -3.17 dB
# Simulation 158/275 | f = 441.50 MHz | S11 = -2.83 dB
# Simulation 159/275 | f = 442.00 MHz | S11 = -2.53 dB
# Simulation 160/275 | f = 442.50 MHz | S11 = -2.28 dB
# Simulation 161/275 | f = 443.00 MHz | S11 = -2.06 dB
# Simulation 162/275 | f = 443.50 MHz | S11 = -1.87 dB
# Simulation 163/275 | f = 444.00 MHz | S11 = -1.71 dB
# Simulation 164/275 | f = 444.50 MHz | S11 = -1.56 dB
# Simulation 165/275 | f = 445.00 MHz | S11 = -1.43 dB
# Simulation 166/275 | f = 445.50 MHz | S11 = -1.32 dB
# Simulation 167/275 | f = 446.00 MHz | S11 = -1.22 dB
# Simulation 168/275 | f = 446.50 MHz | S11 = -1.13 dB
# Simulation 169/275 | f = 447.00 MHz | S11 = -1.05 dB
# Simulation 170/275 | f = 447.50 MHz | S11 = -0.98 dB
# Simulation 171/275 | f = 448.00 MHz | S11 = -0.92 dB
# Simulation 172/275 | f = 448.50 MHz | S11 = -0.86 dB
# Simulation 173/275 | f = 449.00 MHz | S11 = -0.80 dB
# Simulation 174/275 | f = 449.50 MHz | S11 = -0.76 dB
# Simulation 175/275 | f = 450.00 MHz | S11 = -0.71 dB
# Simulation 176/275 | f = 450.50 MHz | S11 = -0.67 dB
# Simulation 177/275 | f = 451.00 MHz | S11 = -0.63 dB
# Simulation 178/275 | f = 451.50 MHz | S11 = -0.60 dB
# Simulation 179/275 | f = 452.00 MHz | S11 = -0.57 dB
# Simulation 180/275 | f = 452.50 MHz | S11 = -0.54 dB
# Simulation 181/275 | f = 453.00 MHz | S11 = -0.51 dB
# Simulation 182/275 | f = 453.50 MHz | S11 = -0.49 dB
# Simulation 183/275 | f = 454.00 MHz | S11 = -0.47 dB
# Simulation 184/275 | f = 454.50 MHz | S11 = -0.45 dB
# Simulation 185/275 | f = 455.00 MHz | S11 = -0.43 dB
# Simulation 186/275 | f = 455.50 MHz | S11 = -0.41 dB
# Simulation 187/275 | f = 456.00 MHz | S11 = -0.39 dB
# Simulation 188/275 | f = 456.50 MHz | S11 = -0.37 dB
# Simulation 189/275 | f = 457.00 MHz | S11 = -0.36 dB
# Simulation 190/275 | f = 457.50 MHz | S11 = -0.34 dB
# Simulation 191/275 | f = 458.00 MHz | S11 = -0.33 dB
# Simulation 192/275 | f = 458.50 MHz | S11 = -0.32 dB
# Simulation 193/275 | f = 459.00 MHz | S11 = -0.31 dB
# Simulation 194/275 | f = 459.50 MHz | S11 = -0.30 dB
# Simulation 195/275 | f = 460.00 MHz | S11 = -0.29 dB
# Simulation 196/275 | f = 460.50 MHz | S11 = -0.28 dB
# Simulation 197/275 | f = 461.00 MHz | S11 = -0.27 dB
# Simulation 198/275 | f = 461.50 MHz | S11 = -0.26 dB
# Simulation 199/275 | f = 462.00 MHz | S11 = -0.25 dB
# Simulation 200/275 | f = 462.50 MHz | S11 = -0.24 dB
# Simulation 201/275 | f = 463.00 MHz | S11 = -0.23 dB
# Simulation 202/275 | f = 463.50 MHz | S11 = -0.23 dB
# Simulation 203/275 | f = 464.00 MHz | S11 = -0.22 dB
# Simulation 204/275 | f = 464.50 MHz | S11 = -0.21 dB
# Simulation 205/275 | f = 465.00 MHz | S11 = -0.21 dB
# Simulation 206/275 | f = 465.50 MHz | S11 = -0.20 dB
# Simulation 207/275 | f = 466.00 MHz | S11 = -0.19 dB
# Simulation 208/275 | f = 466.50 MHz | S11 = -0.19 dB
# Simulation 209/275 | f = 467.00 MHz | S11 = -0.18 dB
# Simulation 210/275 | f = 467.50 MHz | S11 = -0.18 dB
# Simulation 211/275 | f = 468.00 MHz | S11 = -0.17 dB
# Simulation 212/275 | f = 468.50 MHz | S11 = -0.17 dB
# Simulation 213/275 | f = 469.00 MHz | S11 = -0.17 dB
# Simulation 214/275 | f = 469.50 MHz | S11 = -0.16 dB
# Simulation 215/275 | f = 470.00 MHz | S11 = -0.16 dB
# Simulation 216/275 | f = 470.50 MHz | S11 = -0.15 dB
# Simulation 217/275 | f = 471.00 MHz | S11 = -0.15 dB
# Simulation 218/275 | f = 471.50 MHz | S11 = -0.15 dB
# Simulation 219/275 | f = 472.00 MHz | S11 = -0.14 dB
# Simulation 220/275 | f = 472.50 MHz | S11 = -0.14 dB
# Simulation 221/275 | f = 473.00 MHz | S11 = -0.14 dB
# Simulation 222/275 | f = 473.50 MHz | S11 = -0.13 dB
# Simulation 223/275 | f = 474.00 MHz | S11 = -0.13 dB
# Simulation 224/275 | f = 474.50 MHz | S11 = -0.13 dB
# Simulation 225/275 | f = 475.00 MHz | S11 = -0.12 dB
# Simulation 226/275 | f = 475.50 MHz | S11 = -0.12 dB
# Simulation 227/275 | f = 476.00 MHz | S11 = -0.12 dB
# Simulation 228/275 | f = 476.50 MHz | S11 = -0.12 dB
# Simulation 229/275 | f = 477.00 MHz | S11 = -0.11 dB
# Simulation 230/275 | f = 477.50 MHz | S11 = -0.11 dB
# Simulation 231/275 | f = 478.00 MHz | S11 = -0.11 dB
# Simulation 232/275 | f = 478.50 MHz | S11 = -0.11 dB
# Simulation 233/275 | f = 479.00 MHz | S11 = -0.11 dB
# Simulation 234/275 | f = 479.50 MHz | S11 = -0.10 dB
# Simulation 235/275 | f = 480.00 MHz | S11 = -0.10 dB
# Simulation 236/275 | f = 480.50 MHz | S11 = -0.10 dB
# Simulation 237/275 | f = 481.00 MHz | S11 = -0.10 dB
# Simulation 238/275 | f = 481.50 MHz | S11 = -0.10 dB
# Simulation 239/275 | f = 482.00 MHz | S11 = -0.09 dB
# Simulation 240/275 | f = 482.50 MHz | S11 = -0.09 dB
# Simulation 241/275 | f = 483.00 MHz | S11 = -0.09 dB
# Simulation 242/275 | f = 483.50 MHz | S11 = -0.09 dB
# Simulation 243/275 | f = 484.00 MHz | S11 = -0.09 dB
# Simulation 244/275 | f = 484.50 MHz | S11 = -0.09 dB
# Simulation 245/275 | f = 485.00 MHz | S11 = -0.08 dB
# Simulation 246/275 | f = 485.50 MHz | S11 = -0.08 dB
# Simulation 247/275 | f = 486.00 MHz | S11 = -0.08 dB
# Simulation 248/275 | f = 486.50 MHz | S11 = -0.08 dB
# Simulation 249/275 | f = 487.00 MHz | S11 = -0.08 dB
# Simulation 250/275 | f = 487.50 MHz | S11 = -0.08 dB
# Simulation 251/275 | f = 488.00 MHz | S11 = -0.08 dB
# Simulation 252/275 | f = 488.50 MHz | S11 = -0.08 dB
# Simulation 253/275 | f = 489.00 MHz | S11 = -0.07 dB
# Simulation 254/275 | f = 489.50 MHz | S11 = -0.07 dB
# Simulation 255/275 | f = 490.00 MHz | S11 = -0.07 dB
# Simulation 256/275 | f = 490.50 MHz | S11 = -0.07 dB
# Simulation 257/275 | f = 491.00 MHz | S11 = -0.07 dB
# Simulation 258/275 | f = 491.50 MHz | S11 = -0.07 dB
# Simulation 259/275 | f = 492.00 MHz | S11 = -0.07 dB
# Simulation 260/275 | f = 492.50 MHz | S11 = -0.07 dB
# Simulation 261/275 | f = 493.00 MHz | S11 = -0.07 dB
# Simulation 262/275 | f = 493.50 MHz | S11 = -0.06 dB
# Simulation 263/275 | f = 494.00 MHz | S11 = -0.06 dB
# Simulation 264/275 | f = 494.50 MHz | S11 = -0.06 dB
# Simulation 265/275 | f = 495.00 MHz | S11 = -0.06 dB
# Simulation 266/275 | f = 495.50 MHz | S11 = -0.06 dB
# Simulation 267/275 | f = 496.00 MHz | S11 = -0.06 dB
# Simulation 268/275 | f = 496.50 MHz | S11 = -0.06 dB
# Simulation 269/275 | f = 497.00 MHz | S11 = -0.06 dB
# Simulation 270/275 | f = 497.50 MHz | S11 = -0.06 dB
# Simulation 271/275 | f = 498.00 MHz | S11 = -0.06 dB
# Simulation 272/275 | f = 498.50 MHz | S11 = -0.06 dB
# Simulation 273/275 | f = 499.00 MHz | S11 = -0.06 dB
# Simulation 274/275 | f = 499.50 MHz | S11 = -0.05 dB
# Simulation 275/275 | f = 500.00 MHz | S11 = -0.05 dB
# 📡 Simulation results:
# → Resonance frequency = 435.00 MHz
# → Impedance at f_res  = 24.30+5.76j Ω
# frequency resonance / S11 min = 435.00 MHz / -18.64 dB
# s
# --- Input Impedance at resonance ---
# R_res = 24.30 Ohm
# X_res = 5.76 Ohm
# --- Input Impedance at resonance ---
# Ratio = 1.0046189376443417
#
#
# Looking for matching!!!
#
# feed result = 53.503 mm
#
# ------------------------------------------------------Iteration N°3------------------------------------------------------
#
# distance meanders = 2.640 mm
#
# Number of meanders = 7
#
# New distance meanders = 2.788 mm
# IFA track width = 2.640 mm
# feed position = 53.503 mm
#
# Simulation 1/275 | f = 363.00 MHz | S11 = -0.02 dB
# Simulation 2/275 | f = 363.50 MHz | S11 = -0.02 dB
# Simulation 3/275 | f = 364.00 MHz | S11 = -0.02 dB
# Simulation 4/275 | f = 364.50 MHz | S11 = -0.02 dB
# Simulation 5/275 | f = 365.00 MHz | S11 = -0.02 dB
# Simulation 6/275 | f = 365.50 MHz | S11 = -0.02 dB
# Simulation 7/275 | f = 366.00 MHz | S11 = -0.02 dB
# Simulation 8/275 | f = 366.50 MHz | S11 = -0.02 dB
# Simulation 9/275 | f = 367.00 MHz | S11 = -0.02 dB
# Simulation 10/275 | f = 367.50 MHz | S11 = -0.02 dB
# Simulation 11/275 | f = 368.00 MHz | S11 = -0.02 dB
# Simulation 12/275 | f = 368.50 MHz | S11 = -0.02 dB
# Simulation 13/275 | f = 369.00 MHz | S11 = -0.02 dB
# Simulation 14/275 | f = 369.50 MHz | S11 = -0.02 dB
# Simulation 15/275 | f = 370.00 MHz | S11 = -0.02 dB
# Simulation 16/275 | f = 370.50 MHz | S11 = -0.02 dB
# Simulation 17/275 | f = 371.00 MHz | S11 = -0.02 dB
# Simulation 18/275 | f = 371.50 MHz | S11 = -0.02 dB
# Simulation 19/275 | f = 372.00 MHz | S11 = -0.02 dB
# Simulation 20/275 | f = 372.50 MHz | S11 = -0.02 dB
# Simulation 21/275 | f = 373.00 MHz | S11 = -0.02 dB
# Simulation 22/275 | f = 373.50 MHz | S11 = -0.02 dB
# Simulation 23/275 | f = 374.00 MHz | S11 = -0.02 dB
# Simulation 24/275 | f = 374.50 MHz | S11 = -0.02 dB
# Simulation 25/275 | f = 375.00 MHz | S11 = -0.02 dB
# Simulation 26/275 | f = 375.50 MHz | S11 = -0.03 dB
# Simulation 27/275 | f = 376.00 MHz | S11 = -0.03 dB
# Simulation 28/275 | f = 376.50 MHz | S11 = -0.03 dB
# Simulation 29/275 | f = 377.00 MHz | S11 = -0.03 dB
# Simulation 30/275 | f = 377.50 MHz | S11 = -0.03 dB
# Simulation 31/275 | f = 378.00 MHz | S11 = -0.03 dB
# Simulation 32/275 | f = 378.50 MHz | S11 = -0.03 dB
# Simulation 33/275 | f = 379.00 MHz | S11 = -0.03 dB
# Simulation 34/275 | f = 379.50 MHz | S11 = -0.03 dB
# Simulation 35/275 | f = 380.00 MHz | S11 = -0.03 dB
# Simulation 36/275 | f = 380.50 MHz | S11 = -0.03 dB
# Simulation 37/275 | f = 381.00 MHz | S11 = -0.03 dB
# Simulation 38/275 | f = 381.50 MHz | S11 = -0.03 dB
# Simulation 39/275 | f = 382.00 MHz | S11 = -0.03 dB
# Simulation 40/275 | f = 382.50 MHz | S11 = -0.04 dB
# Simulation 41/275 | f = 383.00 MHz | S11 = -0.04 dB
# Simulation 42/275 | f = 383.50 MHz | S11 = -0.04 dB
# Simulation 43/275 | f = 384.00 MHz | S11 = -0.04 dB
# Simulation 44/275 | f = 384.50 MHz | S11 = -0.04 dB
# Simulation 45/275 | f = 385.00 MHz | S11 = -0.04 dB
# Simulation 46/275 | f = 385.50 MHz | S11 = -0.04 dB
# Simulation 47/275 | f = 386.00 MHz | S11 = -0.04 dB
# Simulation 48/275 | f = 386.50 MHz | S11 = -0.04 dB
# Simulation 49/275 | f = 387.00 MHz | S11 = -0.04 dB
# Simulation 50/275 | f = 387.50 MHz | S11 = -0.05 dB
# Simulation 51/275 | f = 388.00 MHz | S11 = -0.05 dB
# Simulation 52/275 | f = 388.50 MHz | S11 = -0.05 dB
# Simulation 53/275 | f = 389.00 MHz | S11 = -0.05 dB
# Simulation 54/275 | f = 389.50 MHz | S11 = -0.05 dB
# Simulation 55/275 | f = 390.00 MHz | S11 = -0.05 dB
# Simulation 56/275 | f = 390.50 MHz | S11 = -0.05 dB
# Simulation 57/275 | f = 391.00 MHz | S11 = -0.05 dB
# Simulation 58/275 | f = 391.50 MHz | S11 = -0.06 dB
# Simulation 59/275 | f = 392.00 MHz | S11 = -0.06 dB
# Simulation 60/275 | f = 392.50 MHz | S11 = -0.06 dB
# Simulation 61/275 | f = 393.00 MHz | S11 = -0.06 dB
# Simulation 62/275 | f = 393.50 MHz | S11 = -0.06 dB
# Simulation 63/275 | f = 394.00 MHz | S11 = -0.06 dB
# Simulation 64/275 | f = 394.50 MHz | S11 = -0.07 dB
# Simulation 65/275 | f = 395.00 MHz | S11 = -0.07 dB
# Simulation 66/275 | f = 395.50 MHz | S11 = -0.07 dB
# Simulation 67/275 | f = 396.00 MHz | S11 = -0.07 dB
# Simulation 68/275 | f = 396.50 MHz | S11 = -0.08 dB
# Simulation 69/275 | f = 397.00 MHz | S11 = -0.08 dB
# Simulation 70/275 | f = 397.50 MHz | S11 = -0.08 dB
# Simulation 71/275 | f = 398.00 MHz | S11 = -0.08 dB
# Simulation 72/275 | f = 398.50 MHz | S11 = -0.09 dB
# Simulation 73/275 | f = 399.00 MHz | S11 = -0.09 dB
# Simulation 74/275 | f = 399.50 MHz | S11 = -0.09 dB
# Simulation 75/275 | f = 400.00 MHz | S11 = -0.09 dB
# Simulation 76/275 | f = 400.50 MHz | S11 = -0.10 dB
# Simulation 77/275 | f = 401.00 MHz | S11 = -0.10 dB
# Simulation 78/275 | f = 401.50 MHz | S11 = -0.10 dB
# Simulation 79/275 | f = 402.00 MHz | S11 = -0.11 dB
# Simulation 80/275 | f = 402.50 MHz | S11 = -0.11 dB
# Simulation 81/275 | f = 403.00 MHz | S11 = -0.12 dB
# Simulation 82/275 | f = 403.50 MHz | S11 = -0.12 dB
# Simulation 83/275 | f = 404.00 MHz | S11 = -0.12 dB
# Simulation 84/275 | f = 404.50 MHz | S11 = -0.13 dB
# Simulation 85/275 | f = 405.00 MHz | S11 = -0.13 dB
# Simulation 86/275 | f = 405.50 MHz | S11 = -0.14 dB
# Simulation 87/275 | f = 406.00 MHz | S11 = -0.15 dB
# Simulation 88/275 | f = 406.50 MHz | S11 = -0.15 dB
# Simulation 89/275 | f = 407.00 MHz | S11 = -0.16 dB
# Simulation 90/275 | f = 407.50 MHz | S11 = -0.16 dB
# Simulation 91/275 | f = 408.00 MHz | S11 = -0.17 dB
# Simulation 92/275 | f = 408.50 MHz | S11 = -0.18 dB
# Simulation 93/275 | f = 409.00 MHz | S11 = -0.19 dB
# Simulation 94/275 | f = 409.50 MHz | S11 = -0.19 dB
# Simulation 95/275 | f = 410.00 MHz | S11 = -0.20 dB
# Simulation 96/275 | f = 410.50 MHz | S11 = -0.21 dB
# Simulation 97/275 | f = 411.00 MHz | S11 = -0.22 dB
# Simulation 98/275 | f = 411.50 MHz | S11 = -0.23 dB
# Simulation 99/275 | f = 412.00 MHz | S11 = -0.24 dB
# Simulation 100/275 | f = 412.50 MHz | S11 = -0.26 dB
# Simulation 101/275 | f = 413.00 MHz | S11 = -0.27 dB
# Simulation 102/275 | f = 413.50 MHz | S11 = -0.28 dB
# Simulation 103/275 | f = 414.00 MHz | S11 = -0.30 dB
# Simulation 104/275 | f = 414.50 MHz | S11 = -0.31 dB
# Simulation 105/275 | f = 415.00 MHz | S11 = -0.33 dB
# Simulation 106/275 | f = 415.50 MHz | S11 = -0.35 dB
# Simulation 107/275 | f = 416.00 MHz | S11 = -0.37 dB
# Simulation 108/275 | f = 416.50 MHz | S11 = -0.39 dB
# Simulation 109/275 | f = 417.00 MHz | S11 = -0.41 dB
# Simulation 110/275 | f = 417.50 MHz | S11 = -0.44 dB
# Simulation 111/275 | f = 418.00 MHz | S11 = -0.47 dB
# Simulation 112/275 | f = 418.50 MHz | S11 = -0.50 dB
# Simulation 113/275 | f = 419.00 MHz | S11 = -0.53 dB
# Simulation 114/275 | f = 419.50 MHz | S11 = -0.57 dB
# Simulation 115/275 | f = 420.00 MHz | S11 = -0.61 dB
# Simulation 116/275 | f = 420.50 MHz | S11 = -0.65 dB
# Simulation 117/275 | f = 421.00 MHz | S11 = -0.70 dB
# Simulation 118/275 | f = 421.50 MHz | S11 = -0.75 dB
# Simulation 119/275 | f = 422.00 MHz | S11 = -0.81 dB
# Simulation 120/275 | f = 422.50 MHz | S11 = -0.88 dB
# Simulation 121/275 | f = 423.00 MHz | S11 = -0.95 dB
# Simulation 122/275 | f = 423.50 MHz | S11 = -1.04 dB
# Simulation 123/275 | f = 424.00 MHz | S11 = -1.13 dB
# Simulation 124/275 | f = 424.50 MHz | S11 = -1.24 dB
# Simulation 125/275 | f = 425.00 MHz | S11 = -1.36 dB
# Simulation 126/275 | f = 425.50 MHz | S11 = -1.50 dB
# Simulation 127/275 | f = 426.00 MHz | S11 = -1.66 dB
# Simulation 128/275 | f = 426.50 MHz | S11 = -1.84 dB
# Simulation 129/275 | f = 427.00 MHz | S11 = -2.06 dB
# Simulation 130/275 | f = 427.50 MHz | S11 = -2.30 dB
# Simulation 131/275 | f = 428.00 MHz | S11 = -2.59 dB
# Simulation 132/275 | f = 428.50 MHz | S11 = -2.94 dB
# Simulation 133/275 | f = 429.00 MHz | S11 = -3.34 dB
# Simulation 134/275 | f = 429.50 MHz | S11 = -3.83 dB
# Simulation 135/275 | f = 430.00 MHz | S11 = -4.41 dB
# Simulation 136/275 | f = 430.50 MHz | S11 = -5.12 dB
# Simulation 137/275 | f = 431.00 MHz | S11 = -5.99 dB
# Simulation 138/275 | f = 431.50 MHz | S11 = -7.06 dB
# Simulation 139/275 | f = 432.00 MHz | S11 = -8.40 dB
# Simulation 140/275 | f = 432.50 MHz | S11 = -10.11 dB
# Simulation 141/275 | f = 433.00 MHz | S11 = -12.33 dB
# Simulation 142/275 | f = 433.50 MHz | S11 = -15.17 dB
# Simulation 143/275 | f = 434.00 MHz | S11 = -18.18 dB
# Simulation 144/275 | f = 434.50 MHz | S11 = -18.56 dB
# Simulation 145/275 | f = 435.00 MHz | S11 = -15.75 dB
# Simulation 146/275 | f = 435.50 MHz | S11 = -12.84 dB
# Simulation 147/275 | f = 436.00 MHz | S11 = -10.56 dB
# Simulation 148/275 | f = 436.50 MHz | S11 = -8.79 dB
# Simulation 149/275 | f = 437.00 MHz | S11 = -7.41 dB
# Simulation 150/275 | f = 437.50 MHz | S11 = -6.31 dB
# Simulation 151/275 | f = 438.00 MHz | S11 = -5.43 dB
# Simulation 152/275 | f = 438.50 MHz | S11 = -4.70 dB
# Simulation 153/275 | f = 439.00 MHz | S11 = -4.11 dB
# Simulation 154/275 | f = 439.50 MHz | S11 = -3.61 dB
# Simulation 155/275 | f = 440.00 MHz | S11 = -3.19 dB
# Simulation 156/275 | f = 440.50 MHz | S11 = -2.84 dB
# Simulation 157/275 | f = 441.00 MHz | S11 = -2.54 dB
# Simulation 158/275 | f = 441.50 MHz | S11 = -2.28 dB
# Simulation 159/275 | f = 442.00 MHz | S11 = -2.06 dB
# Simulation 160/275 | f = 442.50 MHz | S11 = -1.87 dB
# Simulation 161/275 | f = 443.00 MHz | S11 = -1.70 dB
# Simulation 162/275 | f = 443.50 MHz | S11 = -1.56 dB
# Simulation 163/275 | f = 444.00 MHz | S11 = -1.43 dB
# Simulation 164/275 | f = 444.50 MHz | S11 = -1.32 dB
# Simulation 165/275 | f = 445.00 MHz | S11 = -1.22 dB
# Simulation 166/275 | f = 445.50 MHz | S11 = -1.13 dB
# Simulation 167/275 | f = 446.00 MHz | S11 = -1.05 dB
# Simulation 168/275 | f = 446.50 MHz | S11 = -0.97 dB
# Simulation 169/275 | f = 447.00 MHz | S11 = -0.91 dB
# Simulation 170/275 | f = 447.50 MHz | S11 = -0.85 dB
# Simulation 171/275 | f = 448.00 MHz | S11 = -0.80 dB
# Simulation 172/275 | f = 448.50 MHz | S11 = -0.75 dB
# Simulation 173/275 | f = 449.00 MHz | S11 = -0.71 dB
# Simulation 174/275 | f = 449.50 MHz | S11 = -0.67 dB
# Simulation 175/275 | f = 450.00 MHz | S11 = -0.63 dB
# Simulation 176/275 | f = 450.50 MHz | S11 = -0.60 dB
# Simulation 177/275 | f = 451.00 MHz | S11 = -0.56 dB
# Simulation 178/275 | f = 451.50 MHz | S11 = -0.54 dB
# Simulation 179/275 | f = 452.00 MHz | S11 = -0.51 dB
# Simulation 180/275 | f = 452.50 MHz | S11 = -0.48 dB
# Simulation 181/275 | f = 453.00 MHz | S11 = -0.46 dB
# Simulation 182/275 | f = 453.50 MHz | S11 = -0.44 dB
# Simulation 183/275 | f = 454.00 MHz | S11 = -0.42 dB
# Simulation 184/275 | f = 454.50 MHz | S11 = -0.40 dB
# Simulation 185/275 | f = 455.00 MHz | S11 = -0.39 dB
# Simulation 186/275 | f = 455.50 MHz | S11 = -0.37 dB
# Simulation 187/275 | f = 456.00 MHz | S11 = -0.35 dB
# Simulation 188/275 | f = 456.50 MHz | S11 = -0.34 dB
# Simulation 189/275 | f = 457.00 MHz | S11 = -0.33 dB
# Simulation 190/275 | f = 457.50 MHz | S11 = -0.32 dB
# Simulation 191/275 | f = 458.00 MHz | S11 = -0.30 dB
# Simulation 192/275 | f = 458.50 MHz | S11 = -0.29 dB
# Simulation 193/275 | f = 459.00 MHz | S11 = -0.28 dB
# Simulation 194/275 | f = 459.50 MHz | S11 = -0.27 dB
# Simulation 195/275 | f = 460.00 MHz | S11 = -0.26 dB
# Simulation 196/275 | f = 460.50 MHz | S11 = -0.25 dB
# Simulation 197/275 | f = 461.00 MHz | S11 = -0.25 dB
# Simulation 198/275 | f = 461.50 MHz | S11 = -0.24 dB
# Simulation 199/275 | f = 462.00 MHz | S11 = -0.23 dB
# Simulation 200/275 | f = 462.50 MHz | S11 = -0.22 dB
# Simulation 201/275 | f = 463.00 MHz | S11 = -0.22 dB
# Simulation 202/275 | f = 463.50 MHz | S11 = -0.21 dB
# Simulation 203/275 | f = 464.00 MHz | S11 = -0.20 dB
# Simulation 204/275 | f = 464.50 MHz | S11 = -0.20 dB
# Simulation 205/275 | f = 465.00 MHz | S11 = -0.19 dB
# Simulation 206/275 | f = 465.50 MHz | S11 = -0.19 dB
# Simulation 207/275 | f = 466.00 MHz | S11 = -0.18 dB
# Simulation 208/275 | f = 466.50 MHz | S11 = -0.18 dB
# Simulation 209/275 | f = 467.00 MHz | S11 = -0.17 dB
# Simulation 210/275 | f = 467.50 MHz | S11 = -0.17 dB
# Simulation 211/275 | f = 468.00 MHz | S11 = -0.16 dB
# Simulation 212/275 | f = 468.50 MHz | S11 = -0.16 dB
# Simulation 213/275 | f = 469.00 MHz | S11 = -0.15 dB
# Simulation 214/275 | f = 469.50 MHz | S11 = -0.15 dB
# Simulation 215/275 | f = 470.00 MHz | S11 = -0.15 dB
# Simulation 216/275 | f = 470.50 MHz | S11 = -0.14 dB
# Simulation 217/275 | f = 471.00 MHz | S11 = -0.14 dB
# Simulation 218/275 | f = 471.50 MHz | S11 = -0.14 dB
# Simulation 219/275 | f = 472.00 MHz | S11 = -0.13 dB
# Simulation 220/275 | f = 472.50 MHz | S11 = -0.13 dB
# Simulation 221/275 | f = 473.00 MHz | S11 = -0.13 dB
# Simulation 222/275 | f = 473.50 MHz | S11 = -0.13 dB
# Simulation 223/275 | f = 474.00 MHz | S11 = -0.12 dB
# Simulation 224/275 | f = 474.50 MHz | S11 = -0.12 dB
# Simulation 225/275 | f = 475.00 MHz | S11 = -0.12 dB
# Simulation 226/275 | f = 475.50 MHz | S11 = -0.11 dB
# Simulation 227/275 | f = 476.00 MHz | S11 = -0.11 dB
# Simulation 228/275 | f = 476.50 MHz | S11 = -0.11 dB
# Simulation 229/275 | f = 477.00 MHz | S11 = -0.11 dB
# Simulation 230/275 | f = 477.50 MHz | S11 = -0.11 dB
# Simulation 231/275 | f = 478.00 MHz | S11 = -0.10 dB
# Simulation 232/275 | f = 478.50 MHz | S11 = -0.10 dB
# Simulation 233/275 | f = 479.00 MHz | S11 = -0.10 dB
# Simulation 234/275 | f = 479.50 MHz | S11 = -0.10 dB
# Simulation 235/275 | f = 480.00 MHz | S11 = -0.10 dB
# Simulation 236/275 | f = 480.50 MHz | S11 = -0.09 dB
# Simulation 237/275 | f = 481.00 MHz | S11 = -0.09 dB
# Simulation 238/275 | f = 481.50 MHz | S11 = -0.09 dB
# Simulation 239/275 | f = 482.00 MHz | S11 = -0.09 dB
# Simulation 240/275 | f = 482.50 MHz | S11 = -0.09 dB
# Simulation 241/275 | f = 483.00 MHz | S11 = -0.09 dB
# Simulation 242/275 | f = 483.50 MHz | S11 = -0.08 dB
# Simulation 243/275 | f = 484.00 MHz | S11 = -0.08 dB
# Simulation 244/275 | f = 484.50 MHz | S11 = -0.08 dB
# Simulation 245/275 | f = 485.00 MHz | S11 = -0.08 dB
# Simulation 246/275 | f = 485.50 MHz | S11 = -0.08 dB
# Simulation 247/275 | f = 486.00 MHz | S11 = -0.08 dB
# Simulation 248/275 | f = 486.50 MHz | S11 = -0.08 dB
# Simulation 249/275 | f = 487.00 MHz | S11 = -0.08 dB
# Simulation 250/275 | f = 487.50 MHz | S11 = -0.07 dB
# Simulation 251/275 | f = 488.00 MHz | S11 = -0.07 dB
# Simulation 252/275 | f = 488.50 MHz | S11 = -0.07 dB
# Simulation 253/275 | f = 489.00 MHz | S11 = -0.07 dB
# Simulation 254/275 | f = 489.50 MHz | S11 = -0.07 dB
# Simulation 255/275 | f = 490.00 MHz | S11 = -0.07 dB
# Simulation 256/275 | f = 490.50 MHz | S11 = -0.07 dB
# Simulation 257/275 | f = 491.00 MHz | S11 = -0.07 dB
# Simulation 258/275 | f = 491.50 MHz | S11 = -0.07 dB
# Simulation 259/275 | f = 492.00 MHz | S11 = -0.06 dB
# Simulation 260/275 | f = 492.50 MHz | S11 = -0.06 dB
# Simulation 261/275 | f = 493.00 MHz | S11 = -0.06 dB
# Simulation 262/275 | f = 493.50 MHz | S11 = -0.06 dB
# Simulation 263/275 | f = 494.00 MHz | S11 = -0.06 dB
# Simulation 264/275 | f = 494.50 MHz | S11 = -0.06 dB
# Simulation 265/275 | f = 495.00 MHz | S11 = -0.06 dB
# Simulation 266/275 | f = 495.50 MHz | S11 = -0.06 dB
# Simulation 267/275 | f = 496.00 MHz | S11 = -0.06 dB
# Simulation 268/275 | f = 496.50 MHz | S11 = -0.06 dB
# Simulation 269/275 | f = 497.00 MHz | S11 = -0.06 dB
# Simulation 270/275 | f = 497.50 MHz | S11 = -0.06 dB
# Simulation 271/275 | f = 498.00 MHz | S11 = -0.05 dB
# Simulation 272/275 | f = 498.50 MHz | S11 = -0.05 dB
# Simulation 273/275 | f = 499.00 MHz | S11 = -0.05 dB
# Simulation 274/275 | f = 499.50 MHz | S11 = -0.05 dB
# Simulation 275/275 | f = 500.00 MHz | S11 = -0.05 dB
# 📡 Simulation results:
# → Resonance frequency = 434.50 MHz
# → Impedance at f_res  = 21.71+4.46j Ω
# frequency resonance / S11 min = 434.50 MHz / -18.56 dB
# s
# --- Input Impedance at resonance ---
# R_res = 21.71 Ohm
# X_res = 4.46 Ohm
# --- Input Impedance at resonance ---
# Ratio = 1.0034642032332564
#
#
# Required accuracy is met!
# Simulation time: 2 minutes and 54.49 seconds
# Convergence reached at iteration 3
# Optimization parameters saved to data/log_optimization/optimization_results_0.42222.json
