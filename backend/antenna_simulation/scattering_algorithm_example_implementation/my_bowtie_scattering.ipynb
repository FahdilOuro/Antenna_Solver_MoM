# %%
from src.scattering_algorithm.scattering_algorithm import *

# %%
def process_antenna(filename):
    base_name = os.path.splitext(os.path.basename(filename))[0]
    print(f"Processing antenna {base_name}")

# %%
filename_mesh_bowtie = 'data/antennas_mesh/BOWTIE_by_TRI.mat'

# %%
wave_incident_direction = np.array([0, 0, -1])

# %%
start_time = time.time()

process_antenna(filename_mesh_bowtie)
scattering_algorithm(filename_mesh_bowtie, 75e7, wave_incident_direction, polarization=np.array([0, 1, 0]), load_from_matlab=False)

elapsed_time = time.time() - start_time
print(f"Elapsed time for processing the studied antenna: {elapsed_time:.6f} seconds")
print('\n')
# Out:
# Traitement de l'antenne BOWTIE_by_TRI
# length of antenna BOWTIE_by_TRI = 0.12 meter
# width of antenna BOWTIE_by_TRI = 0.2 meter
# height of antenna BOWTIE_by_TRI = 0.0 meter
# Aucune jonction complexe trouvée....
# Data saved successfully to data/antennas_mesh1/BOWTIE_by_TRI_mesh1.mat
# Data saved successfully to data/antennas_mesh2/BOWTIE_by_TRI_mesh2.mat
# Temps écoulé pour le calcul de la matrice Z : 0.160250 secondes
# Data saved successfully to data/antennas_impedance/BOWTIE_by_TRI_impedance.mat
# Data loaded from data/antennas_mesh2/BOWTIE_by_TRI_mesh2.mat
# Data loaded from data/antennas_impedance/BOWTIE_by_TRI_impedance.mat
# Temps écoulé pour le calcul du courant : 0.006343 secondes
# Data saved successfully to data/antennas_current/BOWTIE_by_TRI_current.mat
# Sauvegarde du fichier : BOWTIE_by_TRI_current.mat effectué avec succès !
# Fréquence de l'onde incidente : 750000000.0 Hz
# Max Current = 0.08920113749092014 [A/m]
# BOWTIE_by_TRI antenna surface current in receiving mode view is successfully created at frequency 750000000.0 Hz
# <div>                            <div id="fe7de2bd-c305-4dd6-9bef-451cfa68f92b" class="plotly-graph-div" style="height:800px; width:800px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("fe7de2bd-c305-4dd6-9bef-451cfa68f92b")) {                    Plotly.newPlot(                        "fe7de2bd-c305-4dd6-9bef-451cfa68f92b",                        [{"facecolor":["rgb(86, 0, 137)","rgb(62, 0, 155)","rgb(255, 0, 0)","rgb(255, 46, 0)","rgb(22, 0, 184)","rgb(0, 18, 240)","rgb(136, 0, 100)","rgb(22, 0, 184)","rgb(255, 0, 0)","rgb(62, 0, 155)","rgb(86, 0, 137)","rgb(37, 0, 173)","rgb(0, 7, 216)","rgb(136, 0, 100)","rgb(103, 0, 124)","rgb(37, 0, 173)","rgb(103, 0, 124)","rgb(54, 0, 160)","rgb(0, 7, 216)","rgb(54, 0, 160)","rgb(0, 8, 218)","rgb(7, 0, 195)","rgb(88, 0, 136)","rgb(96, 0, 130)","rgb(88, 0, 136)","rgb(96, 0, 130)","rgb(0, 8, 218)","rgb(7, 0, 195)","rgb(0, 18, 240)","rgb(255, 45, 0)","rgb(29, 221, 185)","rgb(0, 18, 239)","rgb(0, 7, 216)","rgb(0, 18, 239)","rgb(0, 7, 216)","rgb(141, 255, 14)","rgb(29, 221, 185)","rgb(141, 255, 14)","rgb(0, 5, 210)","rgb(176, 250, 0)","rgb(10, 174, 232)","rgb(172, 251, 0)","rgb(14, 0, 190)","rgb(0, 5, 210)","rgb(176, 250, 0)","rgb(10, 174, 232)","rgb(172, 251, 0)","rgb(14, 0, 190)","rgb(0, 14, 231)","rgb(39, 242, 163)","rgb(0, 1, 202)","rgb(0, 14, 231)","rgb(39, 242, 163)","rgb(0, 1, 202)","rgb(62, 0, 155)","rgb(59, 255, 129)","rgb(51, 0, 163)","rgb(72, 0, 147)","rgb(62