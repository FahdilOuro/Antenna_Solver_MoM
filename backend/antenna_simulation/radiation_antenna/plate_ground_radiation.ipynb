# %%
from backend.src.radiation_algorithm.radiation_algorithm import *
from backend.rwg.rwg6 import plot_surface_current_distribution

# %%
def process_antenna(filename):
    base_name = os.path.splitext(os.path.basename(filename))[0]
    print(f"Processing antenna {base_name}")

# %%
filename_mesh_plate_ground = 'data/antennas_mesh/plate_ground.mat'

# %%
# Start time measurement
start_time = time.time()

feed_point_strip2 = [0, 0, 0]
voltage_amplitude = 1  # Amplitude value equal to 1 volt

process_antenna(filename_mesh_plate_ground)
radiation_algorithm(filename_mesh_plate_ground, 75e6, feed_point_strip2, voltage_amplitude, load_from_matlab=False)

elapsed_time = time.time() - start_time
print(f"Elapsed time for the processing of the studied antenna: {elapsed_time:.6f} seconds")
print('\n')
# Out:
# Traitement de l'antenne plate_ground
# length of antenna plate_ground = 2.0 meter
# width of antenna plate_ground = 2.000002 meter
# height of antenna plate_ground = 0.0 meter
# Total numbers of Edges is = 353
# Aucune jonction complexe trouvée....
# Data saved successfully to data/antennas_mesh1/plate_ground_mesh1.mat
# Data saved successfully to data/antennas_mesh2/plate_ground_mesh2.mat
# Temps écoulé pour le calcul de la matrice Z : 0.211605 secondes
# Data saved successfully to data/antennas_impedance/plate_ground_impedance.mat
# Data loaded from data/antennas_mesh2/plate_ground_mesh2.mat
# Data loaded from data/antennas_impedance/plate_ground_impedance.mat
# La valeur de l'impédance d'entrée de l'antenne plate_ground =  0.0006049 + 12.3640259i Ohm
# La valeur de feed_power  = 1.978478303228913e-06
# Data saved successfully to data/antennas_current/plate_ground_current.mat
# Sauvegarde du fichier : plate_ground_current.mat effectué avec succès !
# ...

# %%
filename_mesh2_plate_ground = 'data/antennas_mesh2/plate_ground_mesh2.mat'
filename_current_plate_ground = 'data/antennas_current/plate_ground_current.mat'

plot_surface_current_distribution(filename_mesh2_plate_ground, filename_current_plate_ground)
# Out:
# Data loaded from data/antennas_mesh2/plate_ground_mesh2.mat
