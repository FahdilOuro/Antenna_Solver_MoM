# %%
from backend.src.radiation_algorithm.radiation_algorithm import *
from backend.efield.efield1 import calculate_electric_magnetic_field_at_point
from backend.efield.efield2 import radiation_intensity_distribution_over_sphere_surface
from backend.efield.efield3 import antenna_directivity_pattern

# %%
filename_mesh = 'data/antennas_mesh/array_linear_2.mat'

# %%
# Measure start time
start_time = time.time()

feed_point = np.array([[-3.5, 0, 0],
                      [-2.5, 0, 0],
                      [-1.5, 0, 0],
                      [-0.5, 0, 0],
                      [0.5, 0, 0],
                      [1.5, 0, 0],
                      [2.5, 0, 0],
                      [3.5, 0, 0]])
frequency = 75e6

radiation_algorithm(filename_mesh, frequency, feed_point, simulate_array_antenna=True)

elapsed_time = time.time() - start_time
print(f"Elapsed time for processing the studied antenna: {elapsed_time:.6f} seconds")
print('\n')
# Out:
# Nombre de triangles = 640
#
# Nombre d'elements de maillage (edges) = 632
#
# Aucune jonction complexe trouvée.
#
# Nombre d'elements de maillage (edges) = 632
#
# index_feeding_edges = [ 39 118 197 276 355 434 513 592]
# voltage[index_feeding_edges] =  [0.02+0.j 0.02+0.j 0.02+0.j 0.02+0.j 0.02+0.j 0.02+0.j 0.02+0.j 0.02+0.j]
#
# La valeur de l'impédance d'entrée de l'antenne array_linear_2 = [120.6831304 + 9.5294317i, 99.0373299 - 59.1949034i, 99.3552735 - 51.5718399i, 106.3495157 - 50.7272877i, 106.3495224 - 50.7272817i, 99.3552759 - 51.5718270i, 99.0372717 - 59.1949347i, 120.6830386 + 9.5295613i] Ohm
# Gap current of array_linear_2 = [(0.00823481764873554-0.0006502411081084152j), (0.007439463350209893+0.00444658912912507j), (0.007928679440878654+0.004115499582756257j), (0.00766014984095627+0.003653788382365417j), (0.007660149874556567+0.0036537877355670803j), (0.007928680169553063+0.004115498833779469j), (0.007439463346370865+0.004446594089985426j), (0.008234822443929063-0.0006502508237457031j)]
# Gap voltage of array_linear_2 = [(1+0j), (1+0j), (1+0j), (1+0j), (1+0j), (1+0j), (1+0j), (1+0j)]
# La valeur de feed_power  = [0.00411740882436777, 0.0037197316751049463, 0.003964339720439327, 0.003830074920478135, 0.0038300749372782834, 0.0039643400847765315, 0.0037197316731854323, 0.0041174112219645315]
#
#
# Surface current density of array_linear_2: min = 0.0093892 [A/m], max = 0.4446984 [A/m]
# Temps écoulé pour le traitement de l'antenne étudiée : 0.749790 secondes

# %%
# Dense mesh for a sphere used in radiation calculations
filename_sphere_dense = '../../data/sphere_mesh/sphere_dense.mat'

mesh2_mat = 'data/antennas_mesh2/array_linear_2_mesh2.mat'
current_mat = 'data/antennas_current/array_linear_2_current.mat'
gain_power_mat = 'data/antennas_gain_power/array_linear_2_gain_power.mat'

observationPoint = np.array([100, 0, 0])

calculate_electric_magnetic_field_at_point(mesh2_mat, current_mat, observationPoint, radiation=True)

print("Calculating radiation intensity distribution over sphere surface...")
radiation_intensity_distribution_over_sphere_surface(mesh2_mat, current_mat, filename_sphere_dense, radiation=True)

# Step 3: Generating the directivity pattern
print("Generating antenna directivity pattern...")
antenna_directivity_pattern(mesh2_mat, current_mat, gain_power_mat, radiation=True)
# Out:
# Frequency = 75000000.0 Hz
# Longueur d'onde lambda = 3.9966980530747898 m
# Le point d'observation est : [100   0   0]
#
# e_field_total of array_linear_2 at the observation point [100   0   0] is :
#  0.0000000 + 0.0000000i V/m
#  0.0000000 + 0.0000000i V/m
# -0.0051884 + 0.0002562i V/m
#
# h_field_total of array_linear_2 at the observation point [100   0   0] is :
#  0.0000000 + 0.0000000i A/m
#  0.0000138 - 0.0000007i A/m
#  0.0000000 + 0.0000000i A/m
#
# Poynting vector is equal to :
#  0.000000 W/m^2
#  0.000000 W/m^2
#  0.000000 W/m^2
#
# w = 3.5810734992110934e-08 W/m^2
#
# u = 0.0003581073499211093 W/unit solid angle
# Calculating radiation intensity distribution over sphere surface...
#
# Frequency = 75000000.0 Hz
# Longueur d'onde lambda = 3.9966980530747898 m
#
# Total Power :  0.032755
# Gain Linear :  7.975221
# Gain Logarithmic :  9.017427 dB
#
# gap_current = [0.00823482-0.00065024j 0.00743946+0.00444659j 0.00792868+0.0041155j
#  0.00766015+0.00365379j 0.00766015+0.00365379j 0.00792868+0.0041155j
#  0.00743946+0.00444659j 0.00823482-0.00065025j]
# Radiation Resistance :  110.966748 Ohms
# Data saved successfully to data/antennas_gain_power/array_linear_2_gain_power.mat
# Generating antenna directivity pattern...
# Data loaded from data/antennas_gain_power/array_linear_2_gain_power.mat
