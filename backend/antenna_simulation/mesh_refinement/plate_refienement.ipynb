# %% [markdown]
# # import library

# %%
from backend.utils.gmsh_function        import *
from backend.utils.file_path            import *
from backend.utils.h_refinement_loop    import *

# %% [markdown]
# # create filename

# %%
name = "plate"
# Define the path to save the file
path = setup_save_file_paths(name)

# %%
length = 2
width = 1

light_speed = 3e8
frequency = light_speed / (4 * length)
print(f"frequency = {frequency * 1e-06} MHz")
wavelength = light_speed / frequency
print(f"wavelength = {wavelength}")

initial_mesh_size = wavelength / 10
print(f"initial_mesh_size = {initial_mesh_size}")

# %%
# Initialize Gmsh
gmsh.initialize()
gmsh.model.add("plate_gmsh")
setup_performance_config()

# Use Open Cascade to create a rectangle (x, y, z, width, width)
plate = gmsh.model.occ.addRectangle(0, 0, 0, length, width)
gmsh.model.occ.synchronize()

generate_and_save_mesh(path, initial_mesh_size)

# Close Gmsh
gmsh.finalize()

# %%
wave_incident_direction = np.array([0, 0, -1])
polarization=np.array([0, 1, 0])

# %% [markdown]
# # Refinement mesh

# %%
# Mesh refinement setup
grid_points, radius_vicinity = generate_embedded_grid(path.geo, 0.15)
config = initialize_refinement_config(initial_mesh_size)

# view_grid_point(path.geo, grid_points)

# %%
run_scattering_refinement(config, grid_points, radius_vicinity, path, frequency, wave_incident_direction, polarization)
